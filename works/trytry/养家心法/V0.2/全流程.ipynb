# %%
import pandas as pd
import numpy as np
import talib as ta
import os
from datetime import datetime

# --------------------------
# 配置参数（关键：factors_switch 和 代码引用完全一致）
# --------------------------
CONFIG = {
    "widetable_path": r'D:\workspace\xiaoyao\data\widetable.parquet',  # 你的宽表路径
    "factor_output_path": r'./custom_factors.parquet',  # 因子输出路径
    "log_path": r'./factor_calc_log.txt',
    # 重点：键名用 "factors_switch"（和代码里的引用保持一致，之前少了s）
    "factors_switch": {
        "trend_factors": True,    # 趋势类因子
        "volume_factors": True,   # 量能类因子
        "volatility_factors": True, # 波动类因子
        "industry_factors": True  # 行业类因子
    }
}

# --------------------------
# 工具函数
# --------------------------
def init_log():
    with open(CONFIG["log_path"], 'w', encoding='utf-8') as f:
        f.write(f"【指标计算启动】{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

def log_msg(msg):
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    log_line = f"[{timestamp}] {msg}"
    print(log_line)
    with open(CONFIG["log_path"], 'a', encoding='utf-8') as f:
        f.write(log_line + "\n")

# --------------------------
# 加载基础数据
# --------------------------
def load_base_data():
    log_msg("加载基础数据...")
    core_cols = [
        'date', 'stock_code', 'stock_name', 'open', 'close', 'high', 'low',
        'pre_close', 'volume', 'money', 'sw_l1_industry_name', 'paused'
    ]
    df = pd.read_parquet(CONFIG["widetable_path"], columns=core_cols)
    df["date"] = pd.to_datetime(df["date"])
    df = df[df['paused'] == 0].copy()  # 过滤停牌
    df = df.sort_values(['stock_code', 'date']).reset_index(drop=True)
    log_msg(f"基础数据加载完成：{len(df)}条记录，{df['stock_code'].nunique()}只股票")
    return df

# --------------------------
# 按需计算因子（引用配置时用 "factors_switch"，和配置键名一致）
# --------------------------
def calculate_factors(df):
    log_msg("开始计算因子（按需选择）...")
    df = df.copy()
    # 关键修正：这里用 CONFIG["factors_switch"]（带s），和配置里的键名完全一致
    switch = CONFIG["factors_switch"]
    
    # 1. 趋势类因子
    if switch["trend_factors"]:
        log_msg("计算趋势类因子...")
        df['close_change'] = (df['close'] / df['pre_close'] - 1) * 100  # 日涨跌幅(%)
        df['ma5'] = df.groupby('stock_code')['close'].transform(lambda x: ta.SMA(x, 5))
        df['ma20'] = df.groupby('stock_code')['close'].transform(lambda x: ta.SMA(x, 20))
        df['ma5_above_ma20'] = (df['ma5'] >= df['ma20']).astype(int)
    
    # 2. 量能类因子
    if switch["volume_factors"]:
        log_msg("计算量能类因子...")
        df['volume_ratio_5d'] = df.groupby('stock_code')['volume'].transform(
            lambda x: x / x.rolling(5, min_periods=1).mean().shift(1).replace(0, 0.0001)
        )
        df['turnover'] = df['money'] / (df['close'] * 100)  # 估算换手率
    
    # 3. 波动类因子
    if switch["volatility_factors"]:
        log_msg("计算波动类因子...")
        df['amplitude'] = (df['high'] / df['low'] - 1) * 100  # 振幅(%)
        df['atr'] = df.groupby('stock_code').apply(
            lambda x: ta.ATR(x['high'], x['low'], x['close'], timeperiod=14)
        ).reset_index(level=0, drop=True)
    
    # 4. 行业类因子
    if switch["industry_factors"]:
        log_msg("计算行业类因子...")
        df['industry_rise_rank'] = df.groupby(['date', 'sw_l1_industry_name'])['close_change'].transform(
            lambda x: x.rank(ascending=False, method='min').astype(int)
        )
    
    log_msg("因子计算完成")
    return df

# --------------------------
# 保存因子数据
# --------------------------
def save_factors(df):
    df.to_parquet(CONFIG["factor_output_path"], index=False)
    log_msg(f"因子数据保存至：{CONFIG['factor_output_path']}")
    return df

# --------------------------
# 主函数
# --------------------------
def run_factor_calc():
    try:
        init_log()
        base_df = load_base_data()
        factor_df = calculate_factors(base_df)
        factor_df = save_factors(factor_df)
        return factor_df
    except Exception as e:
        log_msg(f"因子计算失败：{str(e)}")
        raise

# 执行指标计算
if __name__ == "__main__":
    factors = run_factor_calc()
# Out:
# [2025-10-26 16:23:50] 加载基础数据...
# [2025-10-26 16:23:58] 基础数据加载完成：3438070条记录，5284只股票
# [2025-10-26 16:23:58] 开始计算因子（按需选择）...
# [2025-10-26 16:23:58] 计算趋势类因子...
# [2025-10-26 16:24:02] 计算量能类因子...
# [2025-10-26 16:24:07] 计算波动类因子...
# C:\Users\user\AppData\Local\Temp\ipykernel_16948\2449074275.py:82: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df['atr'] = df.groupby('stock_code').apply(
# [2025-10-26 16:24:11] 计算行业类因子...
# [2025-10-26 16:24:22] 因子计算完成
# [2025-10-26 16:24:29] 因子数据保存至：./custom_factors.parquet

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# --------------------------
# 配置参数
# --------------------------
CONFIG = {
    "factor_input_path": r'./custom_factors.parquet',  # 上一步生成的因子
    "selection_output_path": r'./daily_selection.csv',  # 选股结果
    "log_path": r'./selection_log.txt',
    # 选股宽松条件（确保每日有票可交易）
    "filters": {
        "min_close_change": -5,  # 当日涨跌幅≥-5%（不选暴跌股）
        "max_amplitude": 15,     # 振幅≤15%（不选极端波动）
        "min_volume_ratio": 0.8, # 量能比≥0.8（有量能）
        "top_n": 10              # 每日选前10只（确保有交易标的）
    }
}

# --------------------------
# 工具函数
# --------------------------
def init_log():
    with open(CONFIG["log_path"], 'w', encoding='utf-8') as f:
        f.write(f"【选股启动】{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

def log_msg(msg):
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    log_line = f"[{timestamp}] {msg}"
    print(log_line)
    with open(CONFIG["log_path"], 'a', encoding='utf-8') as f:
        f.write(log_line + "\n")

# --------------------------
# 加载因子数据
# --------------------------
def load_factors():
    log_msg("加载因子数据...")
    df = pd.read_parquet(CONFIG["factor_input_path"])
    df["date"] = pd.to_datetime(df["date"])
    # 确保必要字段存在
    required_cols = ['date', 'stock_code', 'stock_name', 'close_change', 'volume_ratio_5d', 'amplitude']
    assert all(col in df.columns for col in required_cols), f"缺少必要字段：{[col for col in required_cols if col not in df.columns]}"
    log_msg(f"因子数据加载完成：{df['date'].nunique()}个交易日")
    return df

# --------------------------
# 每日选股（确保有交易）
# --------------------------
def select_daily(df):
    log_msg("开始每日选股（确保每日有票）...")
    all_dates = sorted(df['date'].unique())
    selection_results = []
    
    for date in all_dates:
        daily_df = df[df['date'] == date].copy()
        if len(daily_df) < 100:  # 过滤数据过少的日期
            log_msg(f"日期{date.date()}数据不足，跳过")
            continue
        
        # 宽松过滤条件（确保有足够标的）
        filtered = daily_df[
            (daily_df['close_change'] >= CONFIG['filters']['min_close_change']) &
            (daily_df['amplitude'] <= CONFIG['filters']['max_amplitude']) &
            (daily_df['volume_ratio_5d'] >= CONFIG['filters']['min_volume_ratio'])
        ].copy()
        
        # 若过滤后不足，放宽条件（确保每日有票）
        if len(filtered) < CONFIG['filters']['top_n']:
            log_msg(f"日期{date.date()}严格过滤后不足，放宽条件")
            filtered = daily_df.sort_values('volume_ratio_5d', ascending=False).head(CONFIG['filters']['top_n'] * 2)
        
        # 按量能比排序，取前N只
        selected = filtered.sort_values('volume_ratio_5d', ascending=False).head(CONFIG['filters']['top_n']).copy()
        selected['selection_date'] = date  # 标记选股日
        selection_results.append(selected)
        log_msg(f"日期{date.date()}选入{len(selected)}只股票")
    
    # 合并结果
    final = pd.concat(selection_results, ignore_index=True)
    final.to_csv(CONFIG["selection_output_path"], index=False, encoding='utf-8-sig')
    log_msg(f"选股完成，共{len(final)}条记录，保存至{CONFIG['selection_output_path']}")
    return final

# --------------------------
# 主函数
# --------------------------
def run_selection():
    try:
        init_log()
        factor_df = load_factors()
        selection = select_daily(factor_df)
        return selection
    except Exception as e:
        log_msg(f"选股失败：{str(e)}")
        raise

# 执行选股
if __name__ == "__main__":
    daily_picks = run_selection()
# Out:
# [2025-10-26 16:25:08] 加载因子数据...
# [2025-10-26 16:25:11] 因子数据加载完成：678个交易日
# [2025-10-26 16:25:11] 开始每日选股（确保每日有票）...
# [2025-10-26 16:25:11] 日期2023-01-03严格过滤后不足，放宽条件
# [2025-10-26 16:25:11] 日期2023-01-03选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-04选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-05选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-06选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-09选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-10选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-11选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-12选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-13选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-16选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-17选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-18选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-19选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-20选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-30选入10只股票
# [2025-10-26 16:25:11] 日期2023-01-31选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-01选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-02选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-03选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-06选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-07选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-08选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-09选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-10选入10只股票
# [2025-10-26 16:25:11] 日期2023-02-13选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-14选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-15选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-16选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-17选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-20选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-21选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-22选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-23选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-24选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-27选入10只股票
# [2025-10-26 16:25:12] 日期2023-02-28选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-01选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-02选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-03选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-06选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-07选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-08选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-09选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-10选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-13选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-14选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-15选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-16选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-17选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-20选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-21选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-22选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-23选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-24选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-27选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-28选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-29选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-30选入10只股票
# [2025-10-26 16:25:12] 日期2023-03-31选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-03选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-04选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-06选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-07选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-10选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-11选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-12选入10只股票
# [2025-10-26 16:25:12] 日期2023-04-13选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-14选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-17选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-18选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-19选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-20选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-21选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-24选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-25选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-26选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-27选入10只股票
# [2025-10-26 16:25:13] 日期2023-04-28选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-04选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-05选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-08选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-09选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-10选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-11选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-12选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-15选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-16选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-17选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-18选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-19选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-22选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-23选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-24选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-25选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-26选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-29选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-30选入10只股票
# [2025-10-26 16:25:13] 日期2023-05-31选入10只股票
# [2025-10-26 16:25:13] 日期2023-06-01选入10只股票
# [2025-10-26 16:25:13] 日期2023-06-02选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-05选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-06选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-07选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-08选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-09选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-12选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-13选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-14选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-15选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-16选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-19选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-20选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-21选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-26选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-27选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-28选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-29选入10只股票
# [2025-10-26 16:25:14] 日期2023-06-30选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-03选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-04选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-05选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-06选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-07选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-10选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-11选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-12选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-13选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-14选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-17选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-18选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-19选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-20选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-21选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-24选入10只股票
# [2025-10-26 16:25:14] 日期2023-07-25选入10只股票
# [2025-10-26 16:25:15] 日期2023-07-26选入10只股票
# [2025-10-26 16:25:15] 日期2023-07-27选入10只股票
# [2025-10-26 16:25:15] 日期2023-07-28选入10只股票
# [2025-10-26 16:25:15] 日期2023-07-31选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-01选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-02选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-03选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-04选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-07选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-08选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-09选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-10选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-11选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-14选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-15选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-16选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-17选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-18选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-21选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-22选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-23选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-24选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-25选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-28选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-29选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-30选入10只股票
# [2025-10-26 16:25:15] 日期2023-08-31选入10只股票
# [2025-10-26 16:25:15] 日期2023-09-01选入10只股票
# [2025-10-26 16:25:15] 日期2023-09-04选入10只股票
# [2025-10-26 16:25:15] 日期2023-09-05选入10只股票
# [2025-10-26 16:25:15] 日期2023-09-06选入10只股票
# [2025-10-26 16:25:15] 日期2023-09-07选入10只股票
# [2025-10-26 16:25:15] 日期2023-09-08选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-11选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-12选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-13选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-14选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-15选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-18选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-19选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-20选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-21选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-22选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-25选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-26选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-27选入10只股票
# [2025-10-26 16:25:16] 日期2023-09-28选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-09选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-10选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-11选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-12选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-13选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-16选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-17选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-18选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-19选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-20选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-23选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-24选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-25选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-26选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-27选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-30选入10只股票
# [2025-10-26 16:25:16] 日期2023-10-31选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-01选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-02选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-03选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-06选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-07选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-08选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-09选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-10选入10只股票
# [2025-10-26 16:25:16] 日期2023-11-13选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-14选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-15选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-16选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-17选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-20选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-21选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-22选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-23选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-24选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-27选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-28选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-29选入10只股票
# [2025-10-26 16:25:17] 日期2023-11-30选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-01选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-04选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-05选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-06选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-07选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-08选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-11选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-12选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-13选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-14选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-15选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-18选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-19选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-20选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-21选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-22选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-25选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-26选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-27选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-28选入10只股票
# [2025-10-26 16:25:17] 日期2023-12-29选入10只股票
# [2025-10-26 16:25:17] 日期2024-01-02选入10只股票
# [2025-10-26 16:25:17] 日期2024-01-03选入10只股票
# [2025-10-26 16:25:17] 日期2024-01-04选入10只股票
# [2025-10-26 16:25:17] 日期2024-01-05选入10只股票
# [2025-10-26 16:25:17] 日期2024-01-08选入10只股票
# [2025-10-26 16:25:17] 日期2024-01-09选入10只股票
# [2025-10-26 16:25:17] 日期2024-01-10选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-11选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-12选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-15选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-16选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-17选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-18选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-19选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-22选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-23选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-24选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-25选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-26选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-29选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-30选入10只股票
# [2025-10-26 16:25:18] 日期2024-01-31选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-01选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-02选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-05选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-06选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-07选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-08选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-19选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-20选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-21选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-22选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-23选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-26选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-27选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-28选入10只股票
# [2025-10-26 16:25:18] 日期2024-02-29选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-01选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-04选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-05选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-06选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-07选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-08选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-11选入10只股票
# [2025-10-26 16:25:18] 日期2024-03-12选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-13选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-14选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-15选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-18选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-19选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-20选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-21选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-22选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-25选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-26选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-27选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-28选入10只股票
# [2025-10-26 16:25:19] 日期2024-03-29选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-01选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-02选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-03选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-08选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-09选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-10选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-11选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-12选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-15选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-16选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-17选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-18选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-19选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-22选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-23选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-24选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-25选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-26选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-29选入10只股票
# [2025-10-26 16:25:19] 日期2024-04-30选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-06选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-07选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-08选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-09选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-10选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-13选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-14选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-15选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-16选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-17选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-20选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-21选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-22选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-23选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-24选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-27选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-28选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-29选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-30选入10只股票
# [2025-10-26 16:25:20] 日期2024-05-31选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-03选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-04选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-05选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-06选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-07选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-11选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-12选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-13选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-14选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-17选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-18选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-19选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-20选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-21选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-24选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-25选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-26选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-27选入10只股票
# [2025-10-26 16:25:20] 日期2024-06-28选入10只股票
# [2025-10-26 16:25:20] 日期2024-07-01选入10只股票
# [2025-10-26 16:25:20] 日期2024-07-02选入10只股票
# [2025-10-26 16:25:20] 日期2024-07-03选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-04选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-05选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-08选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-09选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-10选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-11选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-12选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-15选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-16选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-17选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-18选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-19选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-22选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-23选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-24选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-25选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-26选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-29选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-30选入10只股票
# [2025-10-26 16:25:21] 日期2024-07-31选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-01选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-02选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-05选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-06选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-07选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-08选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-09选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-12选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-13选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-14选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-15选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-16选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-19选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-20选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-21选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-22选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-23选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-26选入10只股票
# [2025-10-26 16:25:21] 日期2024-08-27选入10只股票
# [2025-10-26 16:25:22] 日期2024-08-28选入10只股票
# [2025-10-26 16:25:22] 日期2024-08-29选入10只股票
# [2025-10-26 16:25:22] 日期2024-08-30选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-02选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-03选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-04选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-05选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-06选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-09选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-10选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-11选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-12选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-13选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-18选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-19选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-20选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-23选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-24选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-25选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-26选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-27选入10只股票
# [2025-10-26 16:25:22] 日期2024-09-30选入10只股票
# [2025-10-26 16:25:22] 日期2024-10-08选入10只股票
# [2025-10-26 16:25:22] 日期2024-10-09选入10只股票
# [2025-10-26 16:25:22] 日期2024-10-10选入10只股票
# [2025-10-26 16:25:22] 日期2024-10-11选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-14选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-15选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-16选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-17选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-18选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-21选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-22选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-23选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-24选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-25选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-28选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-29选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-30选入10只股票
# [2025-10-26 16:25:23] 日期2024-10-31选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-01选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-04选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-05选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-06选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-07选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-08选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-11选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-12选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-13选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-14选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-15选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-18选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-19选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-20选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-21选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-22选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-25选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-26选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-27选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-28选入10只股票
# [2025-10-26 16:25:23] 日期2024-11-29选入10只股票
# [2025-10-26 16:25:23] 日期2024-12-02选入10只股票
# [2025-10-26 16:25:23] 日期2024-12-03选入10只股票
# [2025-10-26 16:25:23] 日期2024-12-04选入10只股票
# [2025-10-26 16:25:23] 日期2024-12-05选入10只股票
# [2025-10-26 16:25:23] 日期2024-12-06选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-09选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-10选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-11选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-12选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-13选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-16选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-17选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-18选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-19选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-20选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-23选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-24选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-25选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-26选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-27选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-30选入10只股票
# [2025-10-26 16:25:24] 日期2024-12-31选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-02选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-03选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-06选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-07选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-08选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-09选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-10选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-13选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-14选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-15选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-16选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-17选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-20选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-21选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-22选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-23选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-24选入10只股票
# [2025-10-26 16:25:24] 日期2025-01-27选入10只股票
# [2025-10-26 16:25:24] 日期2025-02-05选入10只股票
# [2025-10-26 16:25:24] 日期2025-02-06选入10只股票
# [2025-10-26 16:25:24] 日期2025-02-07选入10只股票
# [2025-10-26 16:25:24] 日期2025-02-10选入10只股票
# [2025-10-26 16:25:24] 日期2025-02-11选入10只股票
# [2025-10-26 16:25:24] 日期2025-02-12选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-13选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-14选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-17选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-18选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-19选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-20选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-21选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-24选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-25选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-26选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-27选入10只股票
# [2025-10-26 16:25:25] 日期2025-02-28选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-03选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-04选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-05选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-06选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-07选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-10选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-11选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-12选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-13选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-14选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-17选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-18选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-19选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-20选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-21选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-24选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-25选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-26选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-27选入10只股票
# [2025-10-26 16:25:25] 日期2025-03-28选入10只股票
# [2025-10-26 16:25:26] 日期2025-03-31选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-01选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-02选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-03选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-07选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-08选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-09选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-10选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-11选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-14选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-15选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-16选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-17选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-18选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-21选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-22选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-23选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-24选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-25选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-28选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-29选入10只股票
# [2025-10-26 16:25:26] 日期2025-04-30选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-06选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-07选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-08选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-09选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-12选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-13选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-14选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-15选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-16选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-19选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-20选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-21选入10只股票
# [2025-10-26 16:25:26] 日期2025-05-22选入10只股票
# [2025-10-26 16:25:27] 日期2025-05-23选入10只股票
# [2025-10-26 16:25:27] 日期2025-05-26选入10只股票
# [2025-10-26 16:25:27] 日期2025-05-27选入10只股票
# [2025-10-26 16:25:27] 日期2025-05-28选入10只股票
# [2025-10-26 16:25:27] 日期2025-05-29选入10只股票
# [2025-10-26 16:25:27] 日期2025-05-30选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-03选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-04选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-05选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-06选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-09选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-10选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-11选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-12选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-13选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-16选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-17选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-18选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-19选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-20选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-23选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-24选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-25选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-26选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-27选入10只股票
# [2025-10-26 16:25:27] 日期2025-06-30选入10只股票
# [2025-10-26 16:25:27] 日期2025-07-01选入10只股票
# [2025-10-26 16:25:27] 日期2025-07-02选入10只股票
# [2025-10-26 16:25:27] 日期2025-07-03选入10只股票
# [2025-10-26 16:25:27] 日期2025-07-04选入10只股票
# [2025-10-26 16:25:27] 日期2025-07-07选入10只股票
# [2025-10-26 16:25:27] 日期2025-07-08选入10只股票
# [2025-10-26 16:25:27] 日期2025-07-09选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-10选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-11选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-14选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-15选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-16选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-17选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-18选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-21选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-22选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-23选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-24选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-25选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-28选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-29选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-30选入10只股票
# [2025-10-26 16:25:28] 日期2025-07-31选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-01选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-04选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-05选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-06选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-07选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-08选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-11选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-12选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-13选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-14选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-15选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-18选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-19选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-20选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-21选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-22选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-25选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-26选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-27选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-28选入10只股票
# [2025-10-26 16:25:28] 日期2025-08-29选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-01选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-02选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-03选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-04选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-05选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-08选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-09选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-10选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-11选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-12选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-15选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-16选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-17选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-18选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-19选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-22选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-23选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-24选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-25选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-26选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-29选入10只股票
# [2025-10-26 16:25:29] 日期2025-09-30选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-09选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-10选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-13选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-14选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-15选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-16选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-17选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-20选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-21选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-22选入10只股票
# [2025-10-26 16:25:29] 日期2025-10-23选入10只股票
# [2025-10-26 16:25:30] 选股完成，共6780条记录，保存至./daily_selection.csv

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# --------------------------
# 配置参数
# --------------------------
CONFIG = {
    "selection_path": r'./daily_selection.csv',  # 上一步选股结果
    "widetable_path": r'D:\workspace\xiaoyao\data\widetable.parquet',  # 宽表路径
    "result_path": r'./backtest_result.csv',  # 回测结果
    "fund_growth_path": r'./fund_growth.csv',  # 资金增长曲线
    "log_path": r'./backtest_log.txt',
    "initial_fund": 100000.0  # 初始资金
}

# --------------------------
# 工具函数
# --------------------------
def init_log():
    with open(CONFIG["log_path"], 'w', encoding='utf-8') as f:
        f.write(f"【评测启动】{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

def log_msg(msg):
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    log_line = f"[{timestamp}] {msg}"
    print(log_line)
    with open(CONFIG["log_path"], 'a', encoding='utf-8') as f:
        f.write(log_line + "\n")

# --------------------------
# 加载数据并建立日期映射
# --------------------------
def load_data():
    log_msg("加载选股结果和价格数据...")
    # 1. 加载选股结果
    selection = pd.read_csv(CONFIG["selection_path"])
    selection["selection_date"] = pd.to_datetime(selection["selection_date"])
    selection["stock_code"] = selection["stock_code"].astype(str)
    
    # 2. 加载价格数据并建立[股票+日期]→价格映射
    price_cols = ['date', 'stock_code', 'open', 'close', 'paused']
    price_df = pd.read_parquet(CONFIG["widetable_path"], columns=price_cols)
    price_df["date"] = pd.to_datetime(price_df["date"])
    price_df["stock_code"] = price_df["stock_code"].astype(str)
    price_df = price_df[price_df['paused'] == 0].copy()  # 过滤停牌
    
    # 建立映射：(stock_code, date) → open/close
    open_map = price_df.set_index(['stock_code', 'date'])['open'].to_dict()
    close_map = price_df.set_index(['stock_code', 'date'])['close'].to_dict()
    
    log_msg(f"数据加载完成：{len(selection)}条选股记录，{len(price_df)}条价格记录")
    return selection, open_map, close_map

# --------------------------
# 计算交易收益（T+1买，T+2卖）
# --------------------------
def calculate_returns(selection, open_map, close_map):
    log_msg("计算交易收益...")
    # 新增买卖日期（T+1买入，T+2卖出）
    selection['buy_date'] = selection['selection_date'] + pd.Timedelta(days=1)
    selection['sell_date'] = selection['selection_date'] + pd.Timedelta(days=2)
    
    # 计算买入价（T+1开盘价）和卖出价（T+2收盘价）
    def get_prices(row):
        stock = row['stock_code']
        buy_date = row['buy_date']
        sell_date = row['sell_date']
        
        buy_price = open_map.get((stock, buy_date), np.nan)
        sell_price = close_map.get((stock, sell_date), np.nan)
        return pd.Series([buy_price, sell_price])
    
    selection[['buy_price', 'sell_price']] = selection.apply(get_prices, axis=1)
    
    # 过滤无效价格
    valid = selection.dropna(subset=['buy_price', 'sell_price'])
    valid = valid[(valid['buy_price'] > 0) & (valid['sell_price'] > 0)].copy()
    
    # 计算单只股票收益
    valid['return_rate'] = (valid['sell_price'] / valid['buy_price'] - 1) * 100  # 收益率(%)
    log_msg(f"有效交易{len(valid)}笔，无效交易{len(selection)-len(valid)}笔")
    return valid

# --------------------------
# 按日汇总收益和资金增长
# --------------------------
def summarize_results(valid_trades):
    log_msg("汇总每日收益和资金增长...")
    # 1. 按日汇总平均收益
    daily_summary = valid_trades.groupby('selection_date').agg(
        avg_return=('return_rate', 'mean'),  # 当日平均收益率(%)
        trade_count=('stock_code', 'count')  # 当日交易数量
    ).reset_index()
    
    # 2. 计算每日资金增长率（增长率=1 + 0.5*平均收益/100）
    daily_summary['growth_rate'] = 1 + 0.5 * (daily_summary['avg_return'] / 100)
    
    # 3. 计算累计资金（连乘增长率）
    daily_summary = daily_summary.sort_values('selection_date')
    daily_summary['cumulative_fund'] = CONFIG['initial_fund'] * daily_summary['growth_rate'].cumprod()
    
    # 4. 保存结果
    valid_trades.to_csv(CONFIG["result_path"], index=False, encoding='utf-8-sig')
    daily_summary.to_csv(CONFIG["fund_growth_path"], index=False, encoding='utf-8-sig')
    
    # 5. 打印核心指标
    final_fund = daily_summary['cumulative_fund'].iloc[-1] if not daily_summary.empty else CONFIG['initial_fund']
    total_return = (final_fund / CONFIG['initial_fund'] - 1) * 100
    log_msg(f"\n核心评测结果：")
    log_msg(f"初始资金：{CONFIG['initial_fund']:.2f}元")
    log_msg(f"最终资金：{final_fund:.2f}元")
    log_msg(f"累计收益率：{total_return:.2f}%")
    log_msg(f"总交易日：{len(daily_summary)}天")
    log_msg(f"平均每日收益率：{daily_summary['avg_return'].mean():.2f}%")
    
    return daily_summary

# --------------------------
# 主函数
# --------------------------
def run_backtest():
    try:
        init_log()
        selection, open_map, close_map = load_data()
        valid_trades = calculate_returns(selection, open_map, close_map)
        if len(valid_trades) == 0:
            log_msg("无有效交易，评测终止")
            return None
        daily_summary = summarize_results(valid_trades)
        return daily_summary
    except Exception as e:
        log_msg(f"评测失败：{str(e)}")
        raise

# 执行评测
if __name__ == "__main__":
    fund_growth = run_backtest()
# Out:
# [2025-10-26 16:25:33] 加载选股结果和价格数据...
# [2025-10-26 16:25:49] 数据加载完成：6780条选股记录，3438070条价格记录
# [2025-10-26 16:25:49] 计算交易收益...
# [2025-10-26 16:25:51] 有效交易3860笔，无效交易2920笔
# [2025-10-26 16:25:51] 汇总每日收益和资金增长...
# [2025-10-26 16:25:51]
# 核心评测结果：
# [2025-10-26 16:25:51] 初始资金：100000.00元
# [2025-10-26 16:25:51] 最终资金：105200.60元
# [2025-10-26 16:25:51] 累计收益率：5.20%
# [2025-10-26 16:25:51] 总交易日：388天
# [2025-10-26 16:25:51] 平均每日收益率：0.05%
