# %%
import pandas as pd
import numpy as np
from datetime import datetime
from itertools import combinations
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform

# --------------------------
# 步骤1：读取数据并筛选大涨股票（修复日期提取）
# --------------------------
try:
    df_wide = pd.read_parquet(r'D:\workspace\xiaoyao\data\stock_daily_price.parquet', engine='pyarrow')
    print(f"宽表数据读取成功，共{len(df_wide)}条记录")

    # 数据清洗
    df_valid = df_wide[
        (df_wide['paused'] == 0.0) & 
        (df_wide['open'] > 0) & 
        (df_wide['close'].notna()) & 
        (df_wide['open'].notna())
    ].copy()

    # 计算涨跌幅
    df_valid['dakepct'] = (df_valid['close'] - df_valid['open']) / df_valid['open']
    df_big_rise = df_valid[df_valid['dakepct'] > 0.07].copy()
    print(f"筛选出大涨股票记录：{len(df_big_rise)}条")

    # 核心修复：处理“YYYY-MM-DD 00:00:00”格式，只保留日期部分（按空格分割）
    df_big_rise['pure_date'] = df_big_rise['date'].apply(
        lambda x: str(x).split(' ')[0]  # 分割后取前半段“YYYY-MM-DD”
    )

    # 保留必要字段
    required_fields = ['pure_date', 'stock_code']
    if not set(required_fields).issubset(df_big_rise.columns):
        missing = set(required_fields) - set(df_big_rise.columns)
        raise ValueError(f"宽表缺少必要字段：{missing}")
    df_big_rise = df_big_rise[required_fields]

except Exception as e:
    print(f"筛选大涨股票失败：{str(e)}")
    raise


# --------------------------
# 步骤2：按时间拆分训练集（2005-2024）和测试集（2025）
# --------------------------
def split_train_test(dates):
    """修复：解析纯日期“YYYY-MM-DD”，拆分训练/测试集"""
    try:
        train_dates = []
        test_dates = []
        for date_str in dates:
            # 此时date_str已为“YYYY-MM-DD”，直接解析
            date_dt = datetime.strptime(date_str, "%Y-%m-%d")
            if 2005 <= date_dt.year <= 2024:
                train_dates.append(date_str)
            elif date_dt.year == 2025:
                test_dates.append(date_str)
        return train_dates, test_dates
    except Exception as e:
        print(f"日期拆分错误（示例：{dates[:1]}）：{str(e)}")
        return [], []

try:
    # 分组聚合大涨日期
    df_group = df_big_rise.groupby('stock_code').agg(
        大涨日期列表=('pure_date', list)
    ).reset_index()

    # 拆分训练/测试日期
    df_group[['训练期大涨日期', '测试期大涨日期']] = df_group['大涨日期列表'].apply(
        lambda x: pd.Series(split_train_test(x))
    )

    # 过滤训练期无数据的股票
    df_train = df_group[df_group['训练期大涨日期'].apply(len) > 0].copy()
    print(f"训练集有效股票数：{len(df_train)}（需≥2）")
    if len(df_train) < 2:
        # 检查年份分布
        all_years = []
        for dates in df_group['大涨日期列表']:
            for d in dates:
                try:
                    all_years.append(datetime.strptime(d, "%Y-%m-%d").year)
                except:
                    pass
        print(f"数据中包含的年份：{sorted(list(set(all_years)))}")
        raise ValueError("训练集有效股票不足2只，可能是数据年份不在2005-2024范围内")

except Exception as e:
    print(f"数据拆分失败：{str(e)}")
    raise


# --------------------------
# 步骤3：计算股票对的惩罚后协同率
# --------------------------
MIN_COMMON_DATES = 3
PENALTY_THRESHOLD = 0.1

try:
    stock_dates = dict(zip(df_train['stock_code'], df_train['训练期大涨日期'].apply(set)))
    stocks = list(stock_dates.keys())

    co_pairs = []
    for a, b in combinations(stocks, 2):
        dates_a = stock_dates[a]
        dates_b = stock_dates[b]
        len_a, len_b = len(dates_a), len(dates_b)
        common = len(dates_a & dates_b)

        if common < MIN_COMMON_DATES:
            continue

        raw_co = common / min(len_a, len_b)
        penalty = common / max(len_a, len_b)
        penalized_co = raw_co * penalty

        co_pairs.append({
            '股票A': a, '股票B': b,
            '股票A大涨次数': len_a, '股票B大涨次数': len_b,
            '共同大涨次数': common,
            '原始协同率': round(raw_co, 3),
            '惩罚后协同率': round(penalized_co, 3)
        })

    df_co = pd.DataFrame(co_pairs)
    high_co_pairs = df_co[df_co['惩罚后协同率'] >= PENALTY_THRESHOLD].copy()
    print(f"筛选出高协同股票对：{len(high_co_pairs)}对")
    if len(high_co_pairs) < 1:
        raise ValueError("高协同对不足，建议降低PENALTY_THRESHOLD至0.05")

except Exception as e:
    print(f"协同率计算失败：{str(e)}")
    raise


# --------------------------
# 步骤4：层次聚类生成股票组
# --------------------------
try:
    all_co_stocks = list(set(high_co_pairs['股票A']) | set(high_co_pairs['股票B']))
    if len(all_co_stocks) < 2:
        raise ValueError("参与聚类的股票不足2只")

    # 构建协同率矩阵
    co_matrix = pd.DataFrame(0.0, index=all_co_stocks, columns=all_co_stocks)
    for _, row in high_co_pairs.iterrows():
        a, b = row['股票A'], row['股票B']
        co_matrix.loc[a, b] = row['惩罚后协同率']
        co_matrix.loc[b, a] = row['惩罚后协同率']
    np.fill_diagonal(co_matrix.values, 0.0)

    # 转换为距离矩阵并聚类
    distance_matrix = 1 - co_matrix
    np.fill_diagonal(distance_matrix.values, 0.0)
    linkage_matrix = linkage(squareform(distance_matrix), method='ward')
    cluster_labels = fcluster(linkage_matrix, t=1 - PENALTY_THRESHOLD, criterion='distance')

    # 生成股票组
    df_clusters = pd.DataFrame({
        'stock_code': all_co_stocks,
        '股票组编号': cluster_labels
    })
    cluster_result = df_clusters.groupby('股票组编号').agg({
        'stock_code': list
    }).rename(columns={'stock_code': '组内股票代码'})
    cluster_result = cluster_result[cluster_result['组内股票代码'].apply(len) >= 2]
    print(f"训练集生成有效股票组：{len(cluster_result)}组")
    if len(cluster_result) == 0:
        raise ValueError("未生成有效组，建议降低聚类阈值t=0.95")

except Exception as e:
    print(f"聚类失败：{str(e)}")
    raise


# --------------------------
# 步骤5：测试集验证（筛选稳定组）
# --------------------------
try:
    test_stock_dates = dict(zip(df_group['stock_code'], df_group['测试期大涨日期'].apply(set)))
    stable_clusters = []

    for cluster_id, group in cluster_result.iterrows():
        stocks_in_group = group['组内股票代码']
        test_valid = [s for s in stocks_in_group if len(test_stock_dates[s]) > 0]
        if len(test_valid) < 2:
            continue

        # 计算测试期协同率
        test_co_list = []
        for a, b in combinations(test_valid, 2):
            dates_a = test_stock_dates[a]
            dates_b = test_stock_dates[b]
            common = len(dates_a & dates_b)
            min_total = min(len(dates_a), len(dates_b))
            test_co = common / min_total if min_total > 0 else 0
            test_co_list.append(test_co)

        # 训练期平均协同率
        train_co_subset = high_co_pairs[
            (high_co_pairs['股票A'].isin(stocks_in_group)) &
            (high_co_pairs['股票B'].isin(stocks_in_group))
        ]['惩罚后协同率']
        avg_train_co = train_co_subset.mean() if not train_co_subset.empty else 0
        avg_test_co = np.mean(test_co_list) if test_co_list else 0

        # 验证稳定组
        if avg_test_co >= avg_train_co * 0.5:
            stable_clusters.append({
                '股票组编号': cluster_id,
                '组内股票代码': stocks_in_group,
                '训练期平均协同率': round(avg_train_co, 3),
                '测试期平均协同率': round(avg_test_co, 3)
            })

    df_stable = pd.DataFrame(stable_clusters)
    print(f"2025测试期验证通过的稳定股票组：{len(df_stable)}组")
    df_stable.to_csv('稳定大涨股票组.csv', index=False, encoding='utf-8-sig')
    print("结果已保存至：稳定大涨股票组.csv")

except Exception as e:
    print(f"测试集验证失败：{str(e)}")
    raise


# 输出结果预览
if not df_stable.empty:
    print("\n稳定股票组预览：")
    print(df_stable[['股票组编号', '组内股票代码', '训练期平均协同率', '测试期平均协同率']].head())
# Out:
# 宽表数据读取成功，共15080320条记录
# 筛选出大涨股票记录：325529条
# 日期拆分错误（示例：['2005-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-01-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-11-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-03-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2015-01-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-06-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2013-09-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-05-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-10-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-11-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-10-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-06-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-06-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-09-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-10-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-02-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-01-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-12-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2009-07-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-11-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-06-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-11-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-01-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-03-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-03-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-12-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-10-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-03-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-11-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-02-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-01-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-10-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-11-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-04-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-01-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-09-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-11-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-07-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-04-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-07-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-09-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-09-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-10-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-09-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-10-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-10-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-07-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-06-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-01-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-04-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-07-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-01-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-09-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-12-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-09-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-12-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-07-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-02-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-02-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-06-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-09-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-12-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-10-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-05-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-09-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-01-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-12-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-11-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-10-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-10-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-12-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-11-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-07-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-07-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-02-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-02-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-02-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-06-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-05-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-05-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-10-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-06-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-05-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-11-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-09-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-10-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-12-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-04-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-07-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-11-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-11-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-10-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-01-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-03-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-01-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-07-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-04-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-07-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-12-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-02-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-06-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-08-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2017-12-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2016-01-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-03-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-02-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2005-06-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-06-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-07-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-07-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-04-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-07-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-02-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-04-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-08-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-09-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-09-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-10-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-01-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-10-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-02-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-12-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-06-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-10-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-01-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-11-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2007-01-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-12-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-11-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-11-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2006-11-21 00:00:00']）：unconverted data remains:  00:00:00
# ...
# 日期拆分错误（示例：['2024-02-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-05-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-09-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-01-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-12-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-12-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-12-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-01-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-12-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-12-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-06-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-01-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-12-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-05-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-01-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-05-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-06-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-08-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-09-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-03-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-01-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-09-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-05-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-11-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-06-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-09-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-05-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-11-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-06-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-06-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-08-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-09-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-05-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-05-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-08-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-09-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-02-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-09-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-08-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-02-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-09-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-08-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-05-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-11-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-12-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-02-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-12-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-09-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-06-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-12-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-02-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-12-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-04-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-02-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-06-27 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-07-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-01-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-12-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-01-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-11-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-12-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-02-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-12-21 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-02-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-09 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-03 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-04-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-02-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-05-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-12-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-04-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-04-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-06-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-08-29 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-04-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-03-05 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-02-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-07 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-06-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-11-04 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-09-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-10-13 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-12-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-09-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-09-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-11-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-01-10 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-28 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-10-17 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2023-12-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-09-30 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-10-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-10-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-08-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-12-16 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2024-02-06 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-03-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-05-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-04-01 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-02-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-23 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-15 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-26 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-10-19 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2025-06-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-09-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-11-25 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-12 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-08-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-09-02 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-11-11 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-01-18 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-08 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2022-01-24 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-14 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-22 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2021-07-20 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-07-31 00:00:00']）：unconverted data remains:  00:00:00
# 日期拆分错误（示例：['2020-10-29 00:00:00']）：unconverted data remains:  00:00:00
# 训练集有效股票数：0（需≥2）
# 数据中包含的年份：[]
# 数据拆分失败：训练集有效股票不足2只，可能是数据年份不在2005-2024范围内
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 89
#      87                     pass
#      88         print(f"数据中包含的年份：{sorted(list(set(all_years)))}")
# ---> 89         raise ValueError("训练集有效股票不足2只，可能是数据年份不在2005-2024范围内")
#      91 except Exception as e:
#      92     print(f"数据拆分失败：{str(e)}")
#
# ValueError: 训练集有效股票不足2只，可能是数据年份不在2005-2024范围内
