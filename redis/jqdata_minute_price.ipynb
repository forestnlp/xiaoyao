# %% [markdown]
# ## 1.下载数据

# %%
import redis
import pickle
import time
import uuid
import pandas as pd
from io import StringIO
from typing import Any, Optional
from datetime import datetime, timedelta

class RemoteSender:
    def __init__(self, host='*', port=6379, password='*'):
        self.redis = redis.Redis(
            host=host, port=port, password=password,
            decode_responses=False
        )
        self.task_queue = 'function_calls'
        self.result_queue = 'function_results'
        self._test_connection()
        print(f"✅ 发送端pandas版本：{pd.__version__}")

    def _test_connection(self):
        try:
            self.redis.ping()
            print("✅ 发送端：Redis连接成功")
        except Exception as e:
            print(f"❌ 发送端：连接失败 - {e}")
            raise

    def call_remote_function(self, func_name: str, *args, **kwargs) -> Any:
        task_id = f"task_{uuid.uuid4().hex[:8]}"
        task = {
            'func_name': func_name,
            'args': args,
            'kwargs': kwargs,
            'task_id': task_id
        }
        self.redis.rpush(self.task_queue, pickle.dumps(task))
        print(f"📤 已调用远程函数：{func_name}（任务ID：{task_id}）")
        return self._get_result(task_id)

    def _get_result(self, task_id: str, timeout=300) -> Any:
        start_time = time.time()
        while time.time() - start_time < timeout:
            result_data = self.redis.blpop(self.result_queue, timeout=10)
            if not result_data:
                continue

            _, res_bytes = result_data
            result = pickle.loads(res_bytes)
            if result['task_id'] == task_id:
                if result['status'] == 'success':
                    return result['result']  # 返回CSV字符串
                else:
                    raise Exception(f"远程执行失败：{result['error']}")
            self.redis.rpush(self.result_queue, res_bytes)
        raise TimeoutError("任务超时")

    def save_to_csv(self, csv_str: Optional[str], filename: str) -> bool:
        """将CSV字符串保存为本地CSV文件（替代Parquet）"""
        if not csv_str:
            print("⚠️ 数据为空，不保存")
            return False
        try:
            # 从CSV字符串恢复DataFrame（兼容所有pandas版本）
            df = pd.read_csv(StringIO(csv_str))
            # 保存为CSV文件
            df.to_csv(filename, index=False)
            print(f"✅ 保存成功：{filename}（{len(df)}条记录）")
            return True
        except Exception as e:
            print(f"❌ 保存失败：{e}")
            return False

def generate_date_range(start_date_str: str, end_date_str: str) -> list:
    """生成从开始日期到结束日期的所有日期字符串（YYYYMMDD格式）"""
    dates = []
    try:
        start_date = datetime.strptime(start_date_str, '%Y%m%d')
        end_date = datetime.strptime(end_date_str, '%Y%m%d')
        
        if start_date > end_date:
            raise ValueError("开始日期晚于结束日期")
            
        current_date = start_date
        while current_date <= end_date:
            dates.append(current_date.strftime('%Y%m%d'))
            current_date += timedelta(days=1)
    except Exception as e:
        print(f"日期处理错误：{e}")
    return dates

if __name__ == "__main__":

    # 从配置文件读取Redis连接信息
    with open('redis.conf', 'r') as f:
        for line in f:
            if line.startswith('host='):
                host = line.split('=')[1].strip()
            elif line.startswith('port='):
                port = int(line.split('=')[1].strip())
            elif line.startswith('password='):
                password = line.split('=')[1].strip()
    # 初始化Redis发送端
    sender = RemoteSender(host=host, port=port, password=password)
    
    # 定义日期范围：从20250516到20250923
    # 读取../data/stock_daily_price.parquet文件，获取最大的日期+1，是start_date
    # df = pd.read_parquet('../data/stock_minute_price.parquet')

    start_date = '20250101'# (df['date'].max() + timedelta(days=1)).strftime('%Y%m%d')
    # 获取当日日期-1，是end_date
    end_date = '20250105'#(datetime.today() - timedelta(days=1)).strftime('%Y%m%d')
    
    # 生成日期列表
    date_list = generate_date_range(start_date, end_date)
    print(f"=== 共需获取 {len(date_list)} 天的数据 ===")
    

    daily_df = pd.read_parquet('../data/stock_daily_price.parquet')
    # 循环调用获取每日数据
    for i, date in enumerate(date_list, 1):
        # 读取daily_df，获取该date下、paused==0的stock_code列表
        stock_code_list = daily_df[(daily_df['date'] == date) & (daily_df['paused'] == 0)]['stock_code'].tolist()
        print(f"=== 该日期下有 {len(stock_code_list)} 个股票 ===")
        # 如果stock_code_list为空或者数量小于1000，就跳过
        if not stock_code_list or len(stock_code_list) < 1000:
            print(f"⚠️ 该日期下股票数量不足1000，跳过")
            continue

        for stock_code in stock_code_list:
            try:
                # 调用远程函数获取当日数据
                csv_data = sender.call_remote_function('fetch_minute_stock_data', date,stock_code)
                # 保存为CSV文件，文件名包含日期
                sender.save_to_csv(csv_data, f'stock_minute_price_{date}_{stock_code}.csv')
                
                # 适当延迟，避免请求过于频繁
                time.sleep(0.05)
            except Exception as e:
                print(f"❌ {date} 处理失败：{e}")
                # 失败后也延迟一下，避免快速重试导致的问题
                time.sleep(1)
    print("\n=== 所有日期处理完成 ===")
# Out:
# ✅ 发送端：Redis连接成功
# ✅ 发送端pandas版本：2.3.2
# === 共需获取 5 天的数据 ===
# === 该日期下有 0 个股票 ===
# ⚠️ 该日期下股票数量不足1000，跳过
# === 该日期下有 5105 个股票 ===
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_71a03df1）
# ✅ 保存成功：stock_minute_price_20250102_000001.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_43179ad0）
# ✅ 保存成功：stock_minute_price_20250102_000002.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_035a8a5c）
# ✅ 保存成功：stock_minute_price_20250102_000004.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_bcd9cf5e）
# ✅ 保存成功：stock_minute_price_20250102_000006.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_fd6505d8）
# ✅ 保存成功：stock_minute_price_20250102_000007.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1d2c0cbe）
# ✅ 保存成功：stock_minute_price_20250102_000008.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a04fac83）
# ✅ 保存成功：stock_minute_price_20250102_000009.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0bf2359d）
# ✅ 保存成功：stock_minute_price_20250102_000010.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cf94f419）
# ✅ 保存成功：stock_minute_price_20250102_000011.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2d4dfeb9）
# ✅ 保存成功：stock_minute_price_20250102_000012.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_dece6080）
# ✅ 保存成功：stock_minute_price_20250102_000014.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_39c51b9b）
# ✅ 保存成功：stock_minute_price_20250102_000017.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1984117a）
# ✅ 保存成功：stock_minute_price_20250102_000019.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_592e54e3）
# ✅ 保存成功：stock_minute_price_20250102_000020.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3fe3bf0d）
# ✅ 保存成功：stock_minute_price_20250102_000021.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_31419026）
# ✅ 保存成功：stock_minute_price_20250102_000025.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b4a8ac74）
# ✅ 保存成功：stock_minute_price_20250102_000026.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_402b1718）
# ✅ 保存成功：stock_minute_price_20250102_000027.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e921ddf6）
# ✅ 保存成功：stock_minute_price_20250102_000028.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d478fcb5）
# ✅ 保存成功：stock_minute_price_20250102_000029.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f64c13a4）
# ✅ 保存成功：stock_minute_price_20250102_000030.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_38cb5cbe）
# ✅ 保存成功：stock_minute_price_20250102_000031.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c1522566）
# ✅ 保存成功：stock_minute_price_20250102_000032.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f9c342c9）
# ✅ 保存成功：stock_minute_price_20250102_000034.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_91987ec0）
# ✅ 保存成功：stock_minute_price_20250102_000035.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_df22a744）
# ✅ 保存成功：stock_minute_price_20250102_000036.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_bb96cb9e）
# ✅ 保存成功：stock_minute_price_20250102_000037.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_21ad6ef2）
# ✅ 保存成功：stock_minute_price_20250102_000039.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f046817f）
# ✅ 保存成功：stock_minute_price_20250102_000040.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1f431b2d）
# ✅ 保存成功：stock_minute_price_20250102_000042.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8ec5db64）
# ✅ 保存成功：stock_minute_price_20250102_000045.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e172418c）
# ✅ 保存成功：stock_minute_price_20250102_000048.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_20549de4）
# ✅ 保存成功：stock_minute_price_20250102_000049.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4aac849c）
# ✅ 保存成功：stock_minute_price_20250102_000050.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_28bf6a23）
# ✅ 保存成功：stock_minute_price_20250102_000055.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_899bb008）
# ✅ 保存成功：stock_minute_price_20250102_000056.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d770916f）
# ✅ 保存成功：stock_minute_price_20250102_000058.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_682423ab）
# ✅ 保存成功：stock_minute_price_20250102_000059.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b1c41933）
# ✅ 保存成功：stock_minute_price_20250102_000060.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1b1a5022）
# ✅ 保存成功：stock_minute_price_20250102_000061.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0afb9ec2）
# ✅ 保存成功：stock_minute_price_20250102_000062.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_53209eb2）
# ✅ 保存成功：stock_minute_price_20250102_000063.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2ea1cdc1）
# ✅ 保存成功：stock_minute_price_20250102_000065.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_782c9fac）
# ✅ 保存成功：stock_minute_price_20250102_000066.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ca03afbd）
# ✅ 保存成功：stock_minute_price_20250102_000068.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c27aa749）
# ✅ 保存成功：stock_minute_price_20250102_000069.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3cd19657）
# ✅ 保存成功：stock_minute_price_20250102_000070.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4cea5f6b）
# ✅ 保存成功：stock_minute_price_20250102_000078.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_fab66940）
# ✅ 保存成功：stock_minute_price_20250102_000088.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6289e1a0）
# ✅ 保存成功：stock_minute_price_20250102_000089.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_03ed21a7）
# ✅ 保存成功：stock_minute_price_20250102_000090.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3d2b201b）
# ✅ 保存成功：stock_minute_price_20250102_000096.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_eef5f4a8）
# ✅ 保存成功：stock_minute_price_20250102_000099.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8b754d9f）
# ✅ 保存成功：stock_minute_price_20250102_000100.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3cd0f7fd）
# ✅ 保存成功：stock_minute_price_20250102_000151.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0834f6e5）
# ✅ 保存成功：stock_minute_price_20250102_000153.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8fe86e95）
# ✅ 保存成功：stock_minute_price_20250102_000155.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_61374fa4）
# ✅ 保存成功：stock_minute_price_20250102_000156.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cceca600）
# ✅ 保存成功：stock_minute_price_20250102_000157.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_06d1df75）
# ✅ 保存成功：stock_minute_price_20250102_000158.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6b5ab018）
# ✅ 保存成功：stock_minute_price_20250102_000159.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b630aafd）
# ✅ 保存成功：stock_minute_price_20250102_000166.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ad077e2e）
# ✅ 保存成功：stock_minute_price_20250102_000301.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ac201b30）
# ✅ 保存成功：stock_minute_price_20250102_000333.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_01b61ba5）
# ✅ 保存成功：stock_minute_price_20250102_000338.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c8192a51）
# ✅ 保存成功：stock_minute_price_20250102_000400.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_07840fc2）
# ✅ 保存成功：stock_minute_price_20250102_000401.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3e1063f5）
# ✅ 保存成功：stock_minute_price_20250102_000402.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b32e038b）
# ✅ 保存成功：stock_minute_price_20250102_000403.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f7433d8a）
# ✅ 保存成功：stock_minute_price_20250102_000404.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_eada168f）
# ✅ 保存成功：stock_minute_price_20250102_000407.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_abb25818）
# ✅ 保存成功：stock_minute_price_20250102_000408.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_24713a93）
# ✅ 保存成功：stock_minute_price_20250102_000409.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_621bf028）
# ✅ 保存成功：stock_minute_price_20250102_000410.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_735ef8f1）
# ✅ 保存成功：stock_minute_price_20250102_000411.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_31b3c623）
# ✅ 保存成功：stock_minute_price_20250102_000415.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f4240288）
# ✅ 保存成功：stock_minute_price_20250102_000417.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e6f906fa）
# ✅ 保存成功：stock_minute_price_20250102_000419.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f0c8166d）
# ✅ 保存成功：stock_minute_price_20250102_000420.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_90eb6dde）
# ✅ 保存成功：stock_minute_price_20250102_000422.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_558ad75a）
# ✅ 保存成功：stock_minute_price_20250102_000423.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e6ce9ac7）
# ✅ 保存成功：stock_minute_price_20250102_000425.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_49733f4a）
# ✅ 保存成功：stock_minute_price_20250102_000426.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_57197338）
# ✅ 保存成功：stock_minute_price_20250102_000428.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_994ae50c）
# ✅ 保存成功：stock_minute_price_20250102_000429.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b160562d）
# ✅ 保存成功：stock_minute_price_20250102_000430.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e9d30e20）
# ✅ 保存成功：stock_minute_price_20250102_000488.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2579deea）
# ✅ 保存成功：stock_minute_price_20250102_000498.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8b930fee）
# ✅ 保存成功：stock_minute_price_20250102_000501.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_aa01b1f3）
# ✅ 保存成功：stock_minute_price_20250102_000503.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ccf69377）
# ✅ 保存成功：stock_minute_price_20250102_000504.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_13749200）
# ✅ 保存成功：stock_minute_price_20250102_000505.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1987a79c）
# ✅ 保存成功：stock_minute_price_20250102_000506.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5c20bccd）
# ✅ 保存成功：stock_minute_price_20250102_000507.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f907555a）
# ✅ 保存成功：stock_minute_price_20250102_000509.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_32bcb5c0）
# ✅ 保存成功：stock_minute_price_20250102_000510.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c407bc0c）
# ✅ 保存成功：stock_minute_price_20250102_000513.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f622bce8）
# ✅ 保存成功：stock_minute_price_20250102_000514.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_65f48ebe）
# ✅ 保存成功：stock_minute_price_20250102_000516.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c563d1bc）
# ✅ 保存成功：stock_minute_price_20250102_000517.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d8bf2e32）
# ✅ 保存成功：stock_minute_price_20250102_000518.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9eeb6646）
# ✅ 保存成功：stock_minute_price_20250102_000519.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c2fb4a7f）
# ✅ 保存成功：stock_minute_price_20250102_000520.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e6a6e07e）
# ✅ 保存成功：stock_minute_price_20250102_000521.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c99a7b02）
# ✅ 保存成功：stock_minute_price_20250102_000523.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c83a3d4d）
# ✅ 保存成功：stock_minute_price_20250102_000524.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d13e2f4e）
# ✅ 保存成功：stock_minute_price_20250102_000525.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_68216205）
# ✅ 保存成功：stock_minute_price_20250102_000526.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cb8dde68）
# ✅ 保存成功：stock_minute_price_20250102_000528.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d6608967）
# ✅ 保存成功：stock_minute_price_20250102_000529.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9d4cf85a）
# ✅ 保存成功：stock_minute_price_20250102_000530.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9df41546）
# ✅ 保存成功：stock_minute_price_20250102_000531.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e55f175f）
# ✅ 保存成功：stock_minute_price_20250102_000532.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3dc5b5ad）
# ✅ 保存成功：stock_minute_price_20250102_000533.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2fb032fc）
# ✅ 保存成功：stock_minute_price_20250102_000534.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_497373e3）
# ✅ 保存成功：stock_minute_price_20250102_000536.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a9662b57）
# ✅ 保存成功：stock_minute_price_20250102_000537.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_da661551）
# ✅ 保存成功：stock_minute_price_20250102_000538.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ba63fce4）
# ✅ 保存成功：stock_minute_price_20250102_000539.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ba02cccf）
# ✅ 保存成功：stock_minute_price_20250102_000541.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cecb040e）
# ✅ 保存成功：stock_minute_price_20250102_000543.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ccd82ec6）
# ✅ 保存成功：stock_minute_price_20250102_000544.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_dffc8669）
# ✅ 保存成功：stock_minute_price_20250102_000545.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ec024c82）
# ✅ 保存成功：stock_minute_price_20250102_000546.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3abe6d20）
# ✅ 保存成功：stock_minute_price_20250102_000547.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a7cea4d7）
# ✅ 保存成功：stock_minute_price_20250102_000548.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_19c1f8e9）
# ✅ 保存成功：stock_minute_price_20250102_000550.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_64589592）
# ✅ 保存成功：stock_minute_price_20250102_000551.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_18828fbc）
# ✅ 保存成功：stock_minute_price_20250102_000552.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_02f96bc0）
# ✅ 保存成功：stock_minute_price_20250102_000553.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f166bad4）
# ✅ 保存成功：stock_minute_price_20250102_000554.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b5e6f64a）
# ✅ 保存成功：stock_minute_price_20250102_000555.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2f06e4ea）
# ✅ 保存成功：stock_minute_price_20250102_000557.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_01bef4bd）
# ✅ 保存成功：stock_minute_price_20250102_000558.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_746a7144）
# ✅ 保存成功：stock_minute_price_20250102_000559.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_da999df0）
# ✅ 保存成功：stock_minute_price_20250102_000560.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cc9e6d2d）
# ✅ 保存成功：stock_minute_price_20250102_000561.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_493f3cbe）
# ✅ 保存成功：stock_minute_price_20250102_000563.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_82c9426e）
# ✅ 保存成功：stock_minute_price_20250102_000564.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_36369b26）
# ✅ 保存成功：stock_minute_price_20250102_000565.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0464ea6b）
# ✅ 保存成功：stock_minute_price_20250102_000566.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_79f8a8c7）
# ✅ 保存成功：stock_minute_price_20250102_000567.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_77db444c）
# ✅ 保存成功：stock_minute_price_20250102_000568.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_db0f0bf0）
# ✅ 保存成功：stock_minute_price_20250102_000570.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_63fa5f28）
# ✅ 保存成功：stock_minute_price_20250102_000571.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_93b52151）
# ✅ 保存成功：stock_minute_price_20250102_000572.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3f1b41f1）
# ✅ 保存成功：stock_minute_price_20250102_000573.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3a8e1169）
# ✅ 保存成功：stock_minute_price_20250102_000576.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_27959409）
# ✅ 保存成功：stock_minute_price_20250102_000581.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_81079862）
# ✅ 保存成功：stock_minute_price_20250102_000582.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_76414e13）
# ✅ 保存成功：stock_minute_price_20250102_000584.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f959feb4）
# ✅ 保存成功：stock_minute_price_20250102_000586.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b3fc7aa6）
# ✅ 保存成功：stock_minute_price_20250102_000589.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0e6d7d41）
# ✅ 保存成功：stock_minute_price_20250102_000590.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c2a14cdd）
# ✅ 保存成功：stock_minute_price_20250102_000591.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8cce7c45）
# ✅ 保存成功：stock_minute_price_20250102_000592.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c4e05fca）
# ✅ 保存成功：stock_minute_price_20250102_000593.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4c7724f2）
# ✅ 保存成功：stock_minute_price_20250102_000595.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b6baaeed）
# ✅ 保存成功：stock_minute_price_20250102_000596.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b05224be）
# ✅ 保存成功：stock_minute_price_20250102_000597.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f56720a6）
# ✅ 保存成功：stock_minute_price_20250102_000598.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7178524b）
# ✅ 保存成功：stock_minute_price_20250102_000599.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_64de4093）
# ✅ 保存成功：stock_minute_price_20250102_000600.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cc22a867）
# ✅ 保存成功：stock_minute_price_20250102_000601.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7be03772）
# ✅ 保存成功：stock_minute_price_20250102_000603.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cf19b623）
# ✅ 保存成功：stock_minute_price_20250102_000605.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_57de6603）
# ✅ 保存成功：stock_minute_price_20250102_000607.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e38c1f53）
# ✅ 保存成功：stock_minute_price_20250102_000608.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4958bb89）
# ✅ 保存成功：stock_minute_price_20250102_000609.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_72f69966）
# ✅ 保存成功：stock_minute_price_20250102_000610.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_fbc9ba5f）
# ✅ 保存成功：stock_minute_price_20250102_000612.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_782c9968）
# ✅ 保存成功：stock_minute_price_20250102_000615.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a3cd0506）
# ✅ 保存成功：stock_minute_price_20250102_000617.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4292dc2a）
# ✅ 保存成功：stock_minute_price_20250102_000619.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_24cacca8）
# ✅ 保存成功：stock_minute_price_20250102_000620.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ddff4ad8）
# ✅ 保存成功：stock_minute_price_20250102_000622.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_be281b8d）
# ✅ 保存成功：stock_minute_price_20250102_000623.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e229c336）
# ✅ 保存成功：stock_minute_price_20250102_000625.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d10e429a）
# ✅ 保存成功：stock_minute_price_20250102_000626.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1b8ddefd）
# ✅ 保存成功：stock_minute_price_20250102_000627.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9e508334）
# ✅ 保存成功：stock_minute_price_20250102_000628.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a1f0b17b）
# ✅ 保存成功：stock_minute_price_20250102_000629.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3ae9d4a7）
# ✅ 保存成功：stock_minute_price_20250102_000630.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2ca78efe）
# ✅ 保存成功：stock_minute_price_20250102_000631.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_779099a7）
# ✅ 保存成功：stock_minute_price_20250102_000632.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3248fc92）
# ✅ 保存成功：stock_minute_price_20250102_000633.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7e89b0d5）
# ✅ 保存成功：stock_minute_price_20250102_000635.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8f1fb908）
# ✅ 保存成功：stock_minute_price_20250102_000636.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a437b20c）
# ✅ 保存成功：stock_minute_price_20250102_000637.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c093cd3f）
# ✅ 保存成功：stock_minute_price_20250102_000638.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6c36de1f）
# ✅ 保存成功：stock_minute_price_20250102_000639.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ced28af6）
# ✅ 保存成功：stock_minute_price_20250102_000650.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_77a17454）
# ✅ 保存成功：stock_minute_price_20250102_000651.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c142753b）
# ✅ 保存成功：stock_minute_price_20250102_000652.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_acbfb1ce）
# ✅ 保存成功：stock_minute_price_20250102_000655.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1ce4b5b9）
# ✅ 保存成功：stock_minute_price_20250102_000656.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_87533602）
# ✅ 保存成功：stock_minute_price_20250102_000657.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_fa5bdc44）
# ✅ 保存成功：stock_minute_price_20250102_000659.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_24b23178）
# ✅ 保存成功：stock_minute_price_20250102_000661.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9074d9c3）
# ✅ 保存成功：stock_minute_price_20250102_000663.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f3056adf）
# ✅ 保存成功：stock_minute_price_20250102_000665.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b31c625d）
# ✅ 保存成功：stock_minute_price_20250102_000668.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4bfad6be）
# ✅ 保存成功：stock_minute_price_20250102_000669.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2ad5e6b9）
# ✅ 保存成功：stock_minute_price_20250102_000670.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f4dabfe5）
# ✅ 保存成功：stock_minute_price_20250102_000672.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9c1308b8）
# ✅ 保存成功：stock_minute_price_20250102_000676.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b1156777）
# ✅ 保存成功：stock_minute_price_20250102_000677.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_12c9bca6）
# ✅ 保存成功：stock_minute_price_20250102_000678.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b45ab7cb）
# ✅ 保存成功：stock_minute_price_20250102_000679.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6256d6f6）
# ✅ 保存成功：stock_minute_price_20250102_000680.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cfcfd889）
# ✅ 保存成功：stock_minute_price_20250102_000681.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_abff27c3）
# ✅ 保存成功：stock_minute_price_20250102_000682.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0cd32c75）
# ✅ 保存成功：stock_minute_price_20250102_000683.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4356f301）
# ✅ 保存成功：stock_minute_price_20250102_000685.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_90397282）
# ✅ 保存成功：stock_minute_price_20250102_000686.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_45a4b71e）
# ✅ 保存成功：stock_minute_price_20250102_000688.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d4ee6fdc）
# ✅ 保存成功：stock_minute_price_20250102_000690.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e533d5a4）
# ✅ 保存成功：stock_minute_price_20250102_000691.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_87f3f180）
# ✅ 保存成功：stock_minute_price_20250102_000692.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_87793d79）
# ✅ 保存成功：stock_minute_price_20250102_000695.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e587c27e）
# ✅ 保存成功：stock_minute_price_20250102_000697.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9a34c830）
# ✅ 保存成功：stock_minute_price_20250102_000698.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3dfef92d）
# ✅ 保存成功：stock_minute_price_20250102_000700.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_04ffe014）
# ✅ 保存成功：stock_minute_price_20250102_000701.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1f0908d6）
# ✅ 保存成功：stock_minute_price_20250102_000702.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_163afd4e）
# ✅ 保存成功：stock_minute_price_20250102_000703.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_71cac47c）
# ✅ 保存成功：stock_minute_price_20250102_000705.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a567ed06）
# ✅ 保存成功：stock_minute_price_20250102_000707.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9b11f5a1）
# ✅ 保存成功：stock_minute_price_20250102_000708.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f2f93341）
# ✅ 保存成功：stock_minute_price_20250102_000709.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4b97c62a）
# ✅ 保存成功：stock_minute_price_20250102_000710.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e837d3ea）
# ✅ 保存成功：stock_minute_price_20250102_000711.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_335f52b2）
# ✅ 保存成功：stock_minute_price_20250102_000712.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_00cd6e4a）
# ✅ 保存成功：stock_minute_price_20250102_000713.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8607f5c1）
# ✅ 保存成功：stock_minute_price_20250102_000715.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d64329b3）
# ✅ 保存成功：stock_minute_price_20250102_000716.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_872ec0de）
# ✅ 保存成功：stock_minute_price_20250102_000717.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ed281256）
# ✅ 保存成功：stock_minute_price_20250102_000718.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_881b0b6d）
# ✅ 保存成功：stock_minute_price_20250102_000719.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_95306edc）
# ✅ 保存成功：stock_minute_price_20250102_000720.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_70fb6227）
# ✅ 保存成功：stock_minute_price_20250102_000721.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0e9b7a41）
# ✅ 保存成功：stock_minute_price_20250102_000722.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a0b96f57）
# ✅ 保存成功：stock_minute_price_20250102_000723.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_fd88ac68）
# ✅ 保存成功：stock_minute_price_20250102_000725.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0a04e064）
# ✅ 保存成功：stock_minute_price_20250102_000726.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9cc637a2）
# ✅ 保存成功：stock_minute_price_20250102_000727.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_97d92c8c）
# ✅ 保存成功：stock_minute_price_20250102_000728.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2d72797c）
# ✅ 保存成功：stock_minute_price_20250102_000729.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c816ab97）
# ✅ 保存成功：stock_minute_price_20250102_000731.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6c25abd9）
# ✅ 保存成功：stock_minute_price_20250102_000733.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_da05c6de）
# ✅ 保存成功：stock_minute_price_20250102_000735.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d946015b）
# ✅ 保存成功：stock_minute_price_20250102_000736.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_766c69b9）
# ✅ 保存成功：stock_minute_price_20250102_000737.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_39176282）
# ✅ 保存成功：stock_minute_price_20250102_000738.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2b27bb94）
# ✅ 保存成功：stock_minute_price_20250102_000739.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_67908b3e）
# ✅ 保存成功：stock_minute_price_20250102_000750.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9ac7b00d）
# ✅ 保存成功：stock_minute_price_20250102_000751.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f3971253）
# ✅ 保存成功：stock_minute_price_20250102_000752.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_271c3748）
# ✅ 保存成功：stock_minute_price_20250102_000753.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5197c72c）
# ✅ 保存成功：stock_minute_price_20250102_000755.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_674ec6ee）
# ✅ 保存成功：stock_minute_price_20250102_000756.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f6391cae）
# ✅ 保存成功：stock_minute_price_20250102_000757.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2e855095）
# ✅ 保存成功：stock_minute_price_20250102_000758.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d7a9e97d）
# ✅ 保存成功：stock_minute_price_20250102_000759.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e7c8e653）
# ✅ 保存成功：stock_minute_price_20250102_000761.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_51392d36）
# ✅ 保存成功：stock_minute_price_20250102_000762.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4f652d0d）
# ✅ 保存成功：stock_minute_price_20250102_000766.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3493b253）
# ✅ 保存成功：stock_minute_price_20250102_000767.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f444e543）
# ✅ 保存成功：stock_minute_price_20250102_000768.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_068edcb0）
# ✅ 保存成功：stock_minute_price_20250102_000776.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f0048b4a）
# ✅ 保存成功：stock_minute_price_20250102_000778.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_16a12c57）
# ✅ 保存成功：stock_minute_price_20250102_000779.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_bba0e537）
# ✅ 保存成功：stock_minute_price_20250102_000782.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6487b7e7）
# ✅ 保存成功：stock_minute_price_20250102_000783.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0b99cc0d）
# ✅ 保存成功：stock_minute_price_20250102_000785.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3ae321c9）
# ✅ 保存成功：stock_minute_price_20250102_000786.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f7aae206）
# ✅ 保存成功：stock_minute_price_20250102_000788.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_79456700）
# ✅ 保存成功：stock_minute_price_20250102_000789.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2a8356de）
# ✅ 保存成功：stock_minute_price_20250102_000790.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f7770061）
# ✅ 保存成功：stock_minute_price_20250102_000791.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_72afd211）
# ✅ 保存成功：stock_minute_price_20250102_000792.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cef53abe）
# ✅ 保存成功：stock_minute_price_20250102_000793.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_da300630）
# ✅ 保存成功：stock_minute_price_20250102_000795.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_026c6118）
# ✅ 保存成功：stock_minute_price_20250102_000796.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_26fb0df5）
# ✅ 保存成功：stock_minute_price_20250102_000797.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_30fdbf8f）
# ✅ 保存成功：stock_minute_price_20250102_000798.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_51215341）
# ✅ 保存成功：stock_minute_price_20250102_000799.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8c5bfa49）
# ✅ 保存成功：stock_minute_price_20250102_000800.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d1d7782f）
# ✅ 保存成功：stock_minute_price_20250102_000801.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2c6691db）
# ✅ 保存成功：stock_minute_price_20250102_000802.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_422b5dda）
# ✅ 保存成功：stock_minute_price_20250102_000803.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9871b935）
# ✅ 保存成功：stock_minute_price_20250102_000807.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a0b358bb）
# ✅ 保存成功：stock_minute_price_20250102_000809.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_013a89f8）
# ✅ 保存成功：stock_minute_price_20250102_000810.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9e3922ea）
# ✅ 保存成功：stock_minute_price_20250102_000811.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c7cd5bbb）
# ✅ 保存成功：stock_minute_price_20250102_000812.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8b187ef0）
# ✅ 保存成功：stock_minute_price_20250102_000813.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b27995d8）
# ✅ 保存成功：stock_minute_price_20250102_000815.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9489dae2）
# ✅ 保存成功：stock_minute_price_20250102_000816.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5d209eda）
# ✅ 保存成功：stock_minute_price_20250102_000818.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e90f1a35）
# ✅ 保存成功：stock_minute_price_20250102_000819.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b668414e）
# ✅ 保存成功：stock_minute_price_20250102_000820.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0f430219）
# ✅ 保存成功：stock_minute_price_20250102_000821.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a86f41a2）
# ✅ 保存成功：stock_minute_price_20250102_000822.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ccad8856）
# ✅ 保存成功：stock_minute_price_20250102_000823.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9fc1d74f）
# ✅ 保存成功：stock_minute_price_20250102_000825.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4120f9a1）
# ✅ 保存成功：stock_minute_price_20250102_000826.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_16e9e027）
# ✅ 保存成功：stock_minute_price_20250102_000828.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d9440d94）
# ✅ 保存成功：stock_minute_price_20250102_000829.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_68c88eb8）
# ✅ 保存成功：stock_minute_price_20250102_000830.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_58094a85）
# ✅ 保存成功：stock_minute_price_20250102_000831.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7e014241）
# ✅ 保存成功：stock_minute_price_20250102_000833.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_67fc1ae0）
# ✅ 保存成功：stock_minute_price_20250102_000837.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f460ce84）
# ✅ 保存成功：stock_minute_price_20250102_000838.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_61ceb0fb）
# ✅ 保存成功：stock_minute_price_20250102_000839.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b63dd7b6）
# ✅ 保存成功：stock_minute_price_20250102_000848.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6f963314）
# ✅ 保存成功：stock_minute_price_20250102_000850.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_00c4c89c）
# ✅ 保存成功：stock_minute_price_20250102_000851.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_dd20dc39）
# ✅ 保存成功：stock_minute_price_20250102_000852.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e172123f）
# ✅ 保存成功：stock_minute_price_20250102_000856.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4c8566ff）
# ✅ 保存成功：stock_minute_price_20250102_000858.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_06a6d286）
# ✅ 保存成功：stock_minute_price_20250102_000859.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_57d4d44c）
# ✅ 保存成功：stock_minute_price_20250102_000860.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_65703376）
# ✅ 保存成功：stock_minute_price_20250102_000862.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_935a2ba0）
# ✅ 保存成功：stock_minute_price_20250102_000863.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3313f62c）
# ✅ 保存成功：stock_minute_price_20250102_000868.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_54359c7f）
# ✅ 保存成功：stock_minute_price_20250102_000869.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_15165aff）
# ✅ 保存成功：stock_minute_price_20250102_000875.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1aa6ed75）
# ✅ 保存成功：stock_minute_price_20250102_000876.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b5fca342）
# ✅ 保存成功：stock_minute_price_20250102_000877.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_751fdd57）
# ✅ 保存成功：stock_minute_price_20250102_000878.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a9d2c61a）
# ✅ 保存成功：stock_minute_price_20250102_000880.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d436e753）
# ✅ 保存成功：stock_minute_price_20250102_000881.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9f5a1bda）
# ✅ 保存成功：stock_minute_price_20250102_000882.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6fb8f85a）
# ✅ 保存成功：stock_minute_price_20250102_000883.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d22fe144）
# ✅ 保存成功：stock_minute_price_20250102_000885.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d025d2d1）
# ✅ 保存成功：stock_minute_price_20250102_000886.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a5418d81）
# ✅ 保存成功：stock_minute_price_20250102_000887.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_42946513）
# ✅ 保存成功：stock_minute_price_20250102_000888.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f4ccfa59）
# ✅ 保存成功：stock_minute_price_20250102_000889.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_090ae6c2）
# ✅ 保存成功：stock_minute_price_20250102_000890.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1861ffdd）
# ✅ 保存成功：stock_minute_price_20250102_000892.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_223de3d9）
# ✅ 保存成功：stock_minute_price_20250102_000893.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c8ee12c8）
# ✅ 保存成功：stock_minute_price_20250102_000895.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1bb3adb4）
# ✅ 保存成功：stock_minute_price_20250102_000897.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6a921ef1）
# ✅ 保存成功：stock_minute_price_20250102_000898.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5bb65de7）
# ✅ 保存成功：stock_minute_price_20250102_000899.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c8d6c0a2）
# ✅ 保存成功：stock_minute_price_20250102_000900.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_22bcf860）
# ✅ 保存成功：stock_minute_price_20250102_000901.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_39f6e89e）
# ✅ 保存成功：stock_minute_price_20250102_000902.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_29df0632）
# ✅ 保存成功：stock_minute_price_20250102_000903.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b4257d88）
# ✅ 保存成功：stock_minute_price_20250102_000905.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0090438f）
# ✅ 保存成功：stock_minute_price_20250102_000906.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_db2c70c0）
# ✅ 保存成功：stock_minute_price_20250102_000908.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9794e820）
# ✅ 保存成功：stock_minute_price_20250102_000909.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f1b80fd3）
# ✅ 保存成功：stock_minute_price_20250102_000910.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f332deda）
# ✅ 保存成功：stock_minute_price_20250102_000911.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b59f13aa）
# ✅ 保存成功：stock_minute_price_20250102_000912.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_035add19）
# ✅ 保存成功：stock_minute_price_20250102_000913.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0ebcd700）
# ✅ 保存成功：stock_minute_price_20250102_000915.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3fe80ef6）
# ✅ 保存成功：stock_minute_price_20250102_000917.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9ce74172）
# ✅ 保存成功：stock_minute_price_20250102_000919.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d59321e3）
# ✅ 保存成功：stock_minute_price_20250102_000920.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4f99984b）
# ✅ 保存成功：stock_minute_price_20250102_000921.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d7e4f714）
# ✅ 保存成功：stock_minute_price_20250102_000922.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e03ea867）
# ✅ 保存成功：stock_minute_price_20250102_000923.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b3097ed5）
# ✅ 保存成功：stock_minute_price_20250102_000925.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_72ff3996）
# ✅ 保存成功：stock_minute_price_20250102_000926.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4551dfd9）
# ✅ 保存成功：stock_minute_price_20250102_000927.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9cff72b1）
# ✅ 保存成功：stock_minute_price_20250102_000928.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_dbad84eb）
# ✅ 保存成功：stock_minute_price_20250102_000929.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3e783127）
# ✅ 保存成功：stock_minute_price_20250102_000930.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_805df37e）
# ✅ 保存成功：stock_minute_price_20250102_000931.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4cd0ddcb）
# ✅ 保存成功：stock_minute_price_20250102_000932.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5ac1a7e9）
# ✅ 保存成功：stock_minute_price_20250102_000933.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ea7a0534）
# ✅ 保存成功：stock_minute_price_20250102_000935.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4fe8e3ba）
# ✅ 保存成功：stock_minute_price_20250102_000936.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_689dca80）
# ✅ 保存成功：stock_minute_price_20250102_000937.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9ec2e3c1）
# ✅ 保存成功：stock_minute_price_20250102_000938.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3559860f）
# ✅ 保存成功：stock_minute_price_20250102_000948.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_df5234b7）
# ✅ 保存成功：stock_minute_price_20250102_000949.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5d17a51a）
# ✅ 保存成功：stock_minute_price_20250102_000950.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6f0c4bb3）
# ✅ 保存成功：stock_minute_price_20250102_000951.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e3d79628）
# ✅ 保存成功：stock_minute_price_20250102_000952.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_799f3cb3）
# ✅ 保存成功：stock_minute_price_20250102_000953.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_57982f87）
# ✅ 保存成功：stock_minute_price_20250102_000955.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_897a90ac）
# ✅ 保存成功：stock_minute_price_20250102_000957.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_878561fc）
# ✅ 保存成功：stock_minute_price_20250102_000958.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3df4ba49）
# ✅ 保存成功：stock_minute_price_20250102_000959.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_03ba178b）
# ✅ 保存成功：stock_minute_price_20250102_000960.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_26205b85）
# ✅ 保存成功：stock_minute_price_20250102_000962.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_62f79928）
# ✅ 保存成功：stock_minute_price_20250102_000963.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_40e5f848）
# ✅ 保存成功：stock_minute_price_20250102_000965.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_bc75e620）
# ✅ 保存成功：stock_minute_price_20250102_000966.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e06727df）
# ✅ 保存成功：stock_minute_price_20250102_000967.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0ff7a326）
# ✅ 保存成功：stock_minute_price_20250102_000968.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cf966865）
# ✅ 保存成功：stock_minute_price_20250102_000969.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cc1cfb83）
# ✅ 保存成功：stock_minute_price_20250102_000970.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c24fc64f）
# ✅ 保存成功：stock_minute_price_20250102_000972.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_62b36aa0）
# ✅ 保存成功：stock_minute_price_20250102_000973.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_40c5c330）
# ✅ 保存成功：stock_minute_price_20250102_000975.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cd2bb86a）
# ✅ 保存成功：stock_minute_price_20250102_000977.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d725642b）
# ✅ 保存成功：stock_minute_price_20250102_000978.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b3e3508e）
# ✅ 保存成功：stock_minute_price_20250102_000980.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_35ad8c63）
# ✅ 保存成功：stock_minute_price_20250102_000981.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3950cc20）
# ✅ 保存成功：stock_minute_price_20250102_000983.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_16210764）
# ✅ 保存成功：stock_minute_price_20250102_000985.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a222f26e）
# ✅ 保存成功：stock_minute_price_20250102_000987.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_de49b840）
# ✅ 保存成功：stock_minute_price_20250102_000988.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2a7104ee）
# ✅ 保存成功：stock_minute_price_20250102_000989.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c5f26ff2）
# ✅ 保存成功：stock_minute_price_20250102_000990.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c2506beb）
# ✅ 保存成功：stock_minute_price_20250102_000993.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9880edc3）
# ✅ 保存成功：stock_minute_price_20250102_000995.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2b1c3654）
# ✅ 保存成功：stock_minute_price_20250102_000997.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2358721b）
# ✅ 保存成功：stock_minute_price_20250102_000998.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_699ce8e5）
# ✅ 保存成功：stock_minute_price_20250102_000999.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3c9eec3a）
# ✅ 保存成功：stock_minute_price_20250102_001201.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ed5225dc）
# ✅ 保存成功：stock_minute_price_20250102_001202.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6ecbc576）
# ✅ 保存成功：stock_minute_price_20250102_001203.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b4af58f3）
# ✅ 保存成功：stock_minute_price_20250102_001205.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cc28294d）
# ✅ 保存成功：stock_minute_price_20250102_001206.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6f982fb4）
# ✅ 保存成功：stock_minute_price_20250102_001207.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_83a7abc2）
# ✅ 保存成功：stock_minute_price_20250102_001208.XSHE.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_d0882fdf）
# ...
# ✅ 保存成功：stock_minute_price_20250102_601311.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_06f2ecbd）
# ✅ 保存成功：stock_minute_price_20250102_601318.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_72bdf8b9）
# ✅ 保存成功：stock_minute_price_20250102_601319.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_333db895）
# ✅ 保存成功：stock_minute_price_20250102_601326.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9124fc3c）
# ✅ 保存成功：stock_minute_price_20250102_601328.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_24aad0c8）
# ✅ 保存成功：stock_minute_price_20250102_601330.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7d6df094）
# ✅ 保存成功：stock_minute_price_20250102_601333.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6384cd69）
# ✅ 保存成功：stock_minute_price_20250102_601336.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_71b7db80）
# ✅ 保存成功：stock_minute_price_20250102_601339.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2c17a841）
# ✅ 保存成功：stock_minute_price_20250102_601360.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cb929427）
# ✅ 保存成功：stock_minute_price_20250102_601366.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_34e51f7b）
# ✅ 保存成功：stock_minute_price_20250102_601368.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_42037f1b）
# ✅ 保存成功：stock_minute_price_20250102_601369.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5ebf01c1）
# ✅ 保存成功：stock_minute_price_20250102_601375.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_18f6459b）
# ✅ 保存成功：stock_minute_price_20250102_601377.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ee22cea5）
# ✅ 保存成功：stock_minute_price_20250102_601388.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3e8e0957）
# ✅ 保存成功：stock_minute_price_20250102_601390.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_bc65e61e）
# ✅ 保存成功：stock_minute_price_20250102_601398.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2cd09338）
# ✅ 保存成功：stock_minute_price_20250102_601399.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_43856d20）
# ✅ 保存成功：stock_minute_price_20250102_601456.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_fb6a3cfb）
# ✅ 保存成功：stock_minute_price_20250102_601500.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c21786c1）
# ✅ 保存成功：stock_minute_price_20250102_601512.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b56ac9e3）
# ✅ 保存成功：stock_minute_price_20250102_601515.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6ea5cd8f）
# ✅ 保存成功：stock_minute_price_20250102_601518.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c86567b6）
# ✅ 保存成功：stock_minute_price_20250102_601519.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ab33382b）
# ✅ 保存成功：stock_minute_price_20250102_601528.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2028501e）
# ✅ 保存成功：stock_minute_price_20250102_601555.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_92087fd9）
# ✅ 保存成功：stock_minute_price_20250102_601566.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7fc19f26）
# ✅ 保存成功：stock_minute_price_20250102_601567.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9567ebf4）
# ✅ 保存成功：stock_minute_price_20250102_601568.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cd59195e）
# ✅ 保存成功：stock_minute_price_20250102_601577.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_61c2a675）
# ✅ 保存成功：stock_minute_price_20250102_601579.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_748c30e2）
# ✅ 保存成功：stock_minute_price_20250102_601588.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7a91e3f2）
# ✅ 保存成功：stock_minute_price_20250102_601595.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f989b8c3）
# ✅ 保存成功：stock_minute_price_20250102_601598.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9533eff9）
# ✅ 保存成功：stock_minute_price_20250102_601599.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3d601a14）
# ✅ 保存成功：stock_minute_price_20250102_601600.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f747f47d）
# ✅ 保存成功：stock_minute_price_20250102_601601.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5160346a）
# ✅ 保存成功：stock_minute_price_20250102_601606.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2365a533）
# ✅ 保存成功：stock_minute_price_20250102_601607.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3253cfed）
# ✅ 保存成功：stock_minute_price_20250102_601608.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_57259c5b）
# ✅ 保存成功：stock_minute_price_20250102_601609.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_64b99242）
# ✅ 保存成功：stock_minute_price_20250102_601611.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5b332b1c）
# ✅ 保存成功：stock_minute_price_20250102_601615.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_af2a356f）
# ✅ 保存成功：stock_minute_price_20250102_601616.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_1c00136c）
# ✅ 保存成功：stock_minute_price_20250102_601618.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ad3bd255）
# ✅ 保存成功：stock_minute_price_20250102_601619.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_62b75251）
# ✅ 保存成功：stock_minute_price_20250102_601628.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_f0d843f1）
# ✅ 保存成功：stock_minute_price_20250102_601633.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_21297c9c）
# ✅ 保存成功：stock_minute_price_20250102_601636.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_91837524）
# ✅ 保存成功：stock_minute_price_20250102_601658.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_141caf7e）
# ✅ 保存成功：stock_minute_price_20250102_601665.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_41f3fca2）
# ✅ 保存成功：stock_minute_price_20250102_601666.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_51431afe）
# ✅ 保存成功：stock_minute_price_20250102_601668.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7d5b495d）
# ✅ 保存成功：stock_minute_price_20250102_601669.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_bed5436f）
# ✅ 保存成功：stock_minute_price_20250102_601677.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_191fb0f2）
# ✅ 保存成功：stock_minute_price_20250102_601678.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_b4524665）
# ✅ 保存成功：stock_minute_price_20250102_601686.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cb295976）
# ✅ 保存成功：stock_minute_price_20250102_601688.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_3de78390）
# ✅ 保存成功：stock_minute_price_20250102_601689.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7fe046ba）
# ✅ 保存成功：stock_minute_price_20250102_601696.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c7e7dd63）
# ✅ 保存成功：stock_minute_price_20250102_601698.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_0f4034ba）
# ✅ 保存成功：stock_minute_price_20250102_601699.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_dd539f22）
# ✅ 保存成功：stock_minute_price_20250102_601700.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4a171398）
# ✅ 保存成功：stock_minute_price_20250102_601702.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ddcb9fd4）
# ✅ 保存成功：stock_minute_price_20250102_601717.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_836db925）
# ✅ 保存成功：stock_minute_price_20250102_601718.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_877c58d7）
# ✅ 保存成功：stock_minute_price_20250102_601727.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8efa3615）
# ✅ 保存成功：stock_minute_price_20250102_601728.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ec2170c5）
# ✅ 保存成功：stock_minute_price_20250102_601766.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_24451a27）
# ✅ 保存成功：stock_minute_price_20250102_601777.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_cf86a3ff）
# ✅ 保存成功：stock_minute_price_20250102_601778.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_73612fd5）
# ✅ 保存成功：stock_minute_price_20250102_601788.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_a15e38f7）
# ✅ 保存成功：stock_minute_price_20250102_601789.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_64d85380）
# ✅ 保存成功：stock_minute_price_20250102_601798.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_15192b00）
# ✅ 保存成功：stock_minute_price_20250102_601799.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_df757822）
# ✅ 保存成功：stock_minute_price_20250102_601800.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_21d093dd）
# ✅ 保存成功：stock_minute_price_20250102_601801.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_61f12c15）
# ✅ 保存成功：stock_minute_price_20250102_601808.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_50109c94）
# ✅ 保存成功：stock_minute_price_20250102_601811.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_5774d04f）
# ✅ 保存成功：stock_minute_price_20250102_601816.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_9039d95b）
# ✅ 保存成功：stock_minute_price_20250102_601818.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_6a34ea6d）
# ✅ 保存成功：stock_minute_price_20250102_601825.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_020e95c8）
# ✅ 保存成功：stock_minute_price_20250102_601827.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_51123d10）
# ✅ 保存成功：stock_minute_price_20250102_601828.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_7c7faaa3）
# ✅ 保存成功：stock_minute_price_20250102_601838.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_e3f80759）
# ✅ 保存成功：stock_minute_price_20250102_601857.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c5184f44）
# ✅ 保存成功：stock_minute_price_20250102_601858.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_8681e497）
# ✅ 保存成功：stock_minute_price_20250102_601860.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_4c859fb5）
# ✅ 保存成功：stock_minute_price_20250102_601865.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_ffa179bb）
# ✅ 保存成功：stock_minute_price_20250102_601866.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_aeb309e1）
# ✅ 保存成功：stock_minute_price_20250102_601868.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_2e4f05db）
# ✅ 保存成功：stock_minute_price_20250102_601869.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_c423903b）
# ✅ 保存成功：stock_minute_price_20250102_601872.XSHG.csv（240条记录）
# 📤 已调用远程函数：fetch_minute_stock_data（任务ID：task_07900b36）
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 133
#     130 for stock_code in stock_code_list:
#     131     try:
#     132         # 调用远程函数获取当日数据
# --> 133         csv_data = sender.call_remote_function('fetch_minute_stock_data', date,stock_code)
#     134         # 保存为CSV文件，文件名包含日期
#     135         sender.save_to_csv(csv_data, f'stock_minute_price_{date}_{stock_code}.csv')
#
# Cell In[8], line 39, in RemoteSender.call_remote_function(self, func_name, *args, **kwargs)
#      37 self.redis.rpush(self.task_queue, pickle.dumps(task))
#      38 print(f"📤 已调用远程函数：{func_name}（任务ID：{task_id}）")
# ---> 39 return self._get_result(task_id)
#
# Cell In[8], line 44, in RemoteSender._get_result(self, task_id, timeout)
#      42 start_time = time.time()
#      43 while time.time() - start_time < timeout:
# ---> 44     result_data = self.redis.blpop(self.result_queue, timeout=10)
#      45     if not result_data:
#      46         continue
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\commands\core.py:2558, in ListCommands.blpop(self, keys, timeout)
#    2556 keys = list_or_args(keys, None)
#    2557 keys.append(timeout)
# -> 2558 return self.execute_command("BLPOP", *keys)
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\client.py:621, in Redis.execute_command(self, *args, **options)
#     620 def execute_command(self, *args, **options):
# --> 621     return self._execute_command(*args, **options)
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\client.py:632, in Redis._execute_command(self, *args, **options)
#     630     self.single_connection_lock.acquire()
#     631 try:
# --> 632     return conn.retry.call_with_retry(
#     633         lambda: self._send_command_parse_response(
#     634             conn, command_name, *args, **options
#     635         ),
#     636         lambda _: self._close_connection(conn),
#     637     )
#     638 finally:
#     639     if self._single_connection_client:
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\retry.py:105, in Retry.call_with_retry(self, do, fail)
#     103 while True:
#     104     try:
# --> 105         return do()
#     106     except self._supported_errors as error:
#     107         failures += 1
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\client.py:633, in Redis._execute_command.<locals>.<lambda>()
#     630     self.single_connection_lock.acquire()
#     631 try:
#     632     return conn.retry.call_with_retry(
# --> 633         lambda: self._send_command_parse_response(
#     634             conn, command_name, *args, **options
#     635         ),
#     636         lambda _: self._close_connection(conn),
#     637     )
#     638 finally:
#     639     if self._single_connection_client:
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\client.py:604, in Redis._send_command_parse_response(self, conn, command_name, *args, **options)
#     600 """
#     601 Send a command and parse the response
#     602 """
#     603 conn.send_command(*args, **options)
# --> 604 return self.parse_response(conn, command_name, **options)
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\client.py:651, in Redis.parse_response(self, connection, command_name, **options)
#     649         options.pop(NEVER_DECODE)
#     650     else:
# --> 651         response = connection.read_response()
#     652 except ResponseError:
#     653     if EMPTY_RESPONSE in options:
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\connection.py:650, in AbstractConnection.read_response(self, disable_decoding, disconnect_on_error, push_request)
#     646         response = self._parser.read_response(
#     647             disable_decoding=disable_decoding, push_request=push_request
#     648         )
#     649     else:
# --> 650         response = self._parser.read_response(disable_decoding=disable_decoding)
#     651 except socket.timeout:
#     652     if disconnect_on_error:
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\_parsers\resp2.py:15, in _RESP2Parser.read_response(self, disable_decoding)
#      13 pos = self._buffer.get_pos() if self._buffer else None
#      14 try:
# ---> 15     result = self._read_response(disable_decoding=disable_decoding)
#      16 except BaseException:
#      17     if self._buffer:
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\_parsers\resp2.py:25, in _RESP2Parser._read_response(self, disable_decoding)
#      24 def _read_response(self, disable_decoding=False):
# ---> 25     raw = self._buffer.readline()
#      26     if not raw:
#      27         raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\_parsers\socket.py:115, in SocketBuffer.readline(self)
#     112 data = buf.readline()
#     113 while not data.endswith(SYM_CRLF):
#     114     # there's more data in the socket that we need
# --> 115     self._read_from_socket()
#     116     data += buf.readline()
#     118 return data[:-2]
#
# File d:\sdk\Anaconda3\envs\xiaoyao\lib\site-packages\redis\_parsers\socket.py:65, in SocketBuffer._read_from_socket(self, length, timeout, raise_on_timeout)
#      63 try:
#      64     while True:
# ---> 65         data = self._sock.recv(socket_read_size)
#      66         # an empty string indicates the server shutdown the socket
#      67         if isinstance(data, bytes) and len(data) == 0:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 将csv合并为一个parquet文件

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将 /d:/workspace/xiaoyao/redis/ 目录下的所有 stock_***.csv 文件合并为一个 parquet 文件
确保与现有 /d:/workspace/xiaoyao/data/stock_daily_price.parquet 保持字段、压缩方式一致
"""

import os
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path
import glob


def merge_stock_csv_to_parquet(csv_dir, output_parquet_file):
    """
    合并指定目录下的所有 stock_***.csv 文件到单个 parquet 文件
    
    Args:
        csv_dir: CSV 文件所在目录
        output_parquet_file: 输出的 parquet 文件路径
    """
    print(f"📁 开始处理目录: {csv_dir}")
    
    # 获取所有 stock_***.csv 文件
    csv_pattern = os.path.join(csv_dir, "stock_minute_price_*.csv")
    csv_files = glob.glob(csv_pattern)
    
    if not csv_files:
        print("❌ 未找到 stock_minute_price_*.csv 文件")
        return False
    
    print(f"📊 找到 {len(csv_files)} 个 CSV 文件")
    
    # 按文件名排序（确保按日期顺序处理）
    csv_files.sort()
    
    # 读取并合并所有 CSV 文件
    all_dataframes = []
    total_records = 0
    
    for i, csv_file in enumerate(csv_files, 1):
        filename = os.path.basename(csv_file)
        print(f"正在处理 ({i}/{len(csv_files)}): {filename}")
        
        try:
            # 读取 CSV 文件
            df = pd.read_csv(csv_file)
            
            # 数据验证和清洗
            # 确保 date 列是 datetime 类型
            df['date'] = pd.to_datetime(df['date'])
            
            # 确保数值列的数据类型正确
            numeric_columns = ['open', 'close', 'low', 'high', 'volume']
            
            for col in numeric_columns:
                if col in df.columns:
                    df[col] = pd.to_numeric(df[col], errors='coerce')
            
            # 删除无效数据
            df = df.dropna(subset=['date', 'stock_code','time'])
            
            all_dataframes.append(df)
            total_records += len(df)
            print(f"  ✅ 成功读取 {len(df)} 条记录")
            
        except Exception as e:
            print(f"  ❌ 处理失败: {e}")
            continue
    
    if not all_dataframes:
        print("❌ 没有成功读取任何数据")
        return False
    
    print(f"\n📊 合并所有数据...")
    # 合并所有数据框
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    
    # 去重（按 date + stock_code + time）
    combined_df = combined_df.drop_duplicates(subset=['date', 'stock_code','time'])
    
    # 按日期和股票代码排序
    combined_df = combined_df.sort_values(['date', 'stock_code','time']).reset_index(drop=True)
    
    print(f"📈 总计 {len(combined_df)} 条记录（去重后）")
    
    # 确保输出目录存在
    output_dir = os.path.dirname(output_parquet_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")
    
    # 转换为 pyarrow Table
    table = pa.Table.from_pandas(combined_df)
    
    # 使用与目标文件相同的压缩方式 (snappy) 和格式写入 parquet
    try:
        pq.write_table(
            table, 
            output_parquet_file,
            compression='snappy',
            version='2.6',  # 使用较新的 parquet 版本
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024  # 64MB batch size for better performance
        )
        
        print(f"✅ 成功保存到: {output_parquet_file}")
        print(f"📊 文件大小: {os.path.getsize(output_parquet_file) / (1024*1024):.2f} MB")
        
        return True
        
    except Exception as e:
        print(f"❌ 保存 parquet 文件失败: {e}")
        return False


def main():
    """主函数"""
    # 设置路径
    csv_directory = "d:/workspace/xiaoyao/redis/"
    # 确保输出目录存在
    output_dir = os.path.join(csv_directory, 'parquet')
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")

    output_file = os.path.join(output_dir, 'stock_minute_price_to_merged.parquet')
    
    print("=" * 60)
    print("🚀 开始合并 stock_***.csv 文件到 parquet")
    print("=" * 60)
    
    # 执行合并
    success = merge_stock_csv_to_parquet(csv_directory, output_file)
    
    if success:
        print("\n🎉 合并完成！")
        
        # 验证结果
        try:
            print("\n📋 验证结果:")
            result_df = pd.read_parquet(output_file)
            print(f"   总行数: {len(result_df)}")
            print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
            print(f"   股票数量: {result_df['stock_code'].nunique()}")
            print(f"   列名: {list(result_df.columns)}")
            
        except Exception as e:
            print(f"⚠️  验证失败: {e}")
    
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 stock_***.csv 文件到 parquet
# ============================================================
# 📁 开始处理目录: d:/workspace/xiaoyao/redis/
# 📊 找到 3 个 CSV 文件
# 正在处理 (1/3): stock_daily_price_20250926.csv
#   ✅ 成功读取 5158 条记录
# 正在处理 (2/3): stock_daily_price_20250929.csv
#   ✅ 成功读取 5158 条记录
# 正在处理 (3/3): stock_daily_price_20250930.csv
#   ✅ 成功读取 5159 条记录
#
# 📊 合并所有数据...
# 📈 总计 15475 条记录（去重后）
# ✅ 成功保存到: d:/workspace/xiaoyao/redis/parquet\stock_daily_price_to_merged.parquet
# 📊 文件大小: 0.90 MB
#
# 🎉 合并完成！
#
# 📋 验证结果:
#    总行数: 15475
#    日期范围: 2025-09-26 00:00:00 到 2025-09-30 00:00:00
#    股票数量: 5160
#    列名: ['date', 'stock_code', 'open', 'close', 'low', 'high', 'volume', 'money', 'factor', 'high_limit', 'low_limit', 'avg', 'pre_close', 'paused']
# ============================================================

# %% [markdown]
# ## 将新生成的 merged_stock_data.parquet 与现有的 stock_daily_price.parquet 合并

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将新生成的 merged_stock_data.parquet 与现有的 stock_daily_price.parquet 合并
"""

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import os


def merge_parquet_files(existing_file, new_file, output_file):
    """
    合并两个 parquet 文件
    
    Args:
        existing_file: 现有的 parquet 文件路径
        new_file: 新的 parquet 文件路径  
        output_file: 输出的合并文件路径
    """
    print("📊 开始合并 parquet 文件...")
    
    try:
        # 读取现有数据
        print(f"📖 读取现有文件: {existing_file}")
        existing_df = pd.read_parquet(existing_file)
        print(f"   现有数据行数: {len(existing_df)}")
        
        # 读取新数据
        print(f"📖 读取新文件: {new_file}")
        new_df = pd.read_parquet(new_file)
        print(f"   新数据行数: {len(new_df)}")
        
        # 合并数据
        print("🔄 合并数据中...")
        combined_df = pd.concat([existing_df, new_df], ignore_index=True)
        
        # 去重（按 date + stock_code）
        print("🧹 去重处理...")
        combined_df = combined_df.drop_duplicates(subset=['date', 'stock_code'])
        
        # 排序
        print("📅 按日期排序...")
        combined_df = combined_df.sort_values(['date', 'stock_code']).reset_index(drop=True)
        
        print(f"📈 合并后总行数: {len(combined_df)}")
        
        # 确保输出目录存在
        output_dir = os.path.dirname(output_file)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)
        
        # 转换为 pyarrow Table
        table = pa.Table.from_pandas(combined_df)
        
        # 写入 parquet（使用与源文件相同的格式）
        print(f"💾 保存合并结果: {output_file}")
        pq.write_table(
            table,
            output_file,
            compression='snappy',
            version='2.6',
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024
        )
        
        print(f"✅ 合并完成！文件大小: {os.path.getsize(output_file) / (1024*1024):.2f} MB")
        
        # 验证结果
        print("\n📋 验证结果:")
        result_df = pd.read_parquet(output_file)
        print(f"   最终行数: {len(result_df)}")
        print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
        print(f"   股票数量: {result_df['stock_code'].nunique()}")
        
        return True
        
    except Exception as e:
        print(f"❌ 合并失败: {e}")
        return False


def main():
    """主函数"""
    # 设置文件路径

    existing_file = "d:/workspace/xiaoyao/data/stock_daily_price.parquet"
    new_file = "d:/workspace/xiaoyao/redis/parquet/stock_daily_price_to_merged.parquet"
    output_file = "d:/workspace/xiaoyao/redis/parquet/stock_daily_price.parquet"

    print("=" * 60)
    print("🚀 开始合并 parquet 文件")
    print("=" * 60)
    
    # 检查文件是否存在
    if not os.path.exists(existing_file):
        print(f"❌ 现有文件不存在: {existing_file}")
        return
    
    if not os.path.exists(new_file):
        print(f"❌ 新文件不存在: {new_file}")
        return
    
    # 执行合并
    success = merge_parquet_files(existing_file, new_file, output_file)
    
    if success:
        print("\n🎉 合并成功！")
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 parquet 文件
# ============================================================
# 📊 开始合并 parquet 文件...
# 📖 读取现有文件: d:/workspace/xiaoyao/data/stock_daily_price.parquet
#    现有数据行数: 15039052
# 📖 读取新文件: d:/workspace/xiaoyao/redis/parquet/stock_daily_price_to_merged.parquet
#    新数据行数: 15475
# 🔄 合并数据中...
# 🧹 去重处理...
# 📅 按日期排序...
# 📈 合并后总行数: 15054527
# 💾 保存合并结果: d:/workspace/xiaoyao/redis/parquet/stock_daily_price.parquet
# ✅ 合并完成！文件大小: 519.95 MB
#
# 📋 验证结果:
#    最终行数: 15054527
#    日期范围: 2005-01-04 00:00:00 到 2025-09-30 00:00:00
#    股票数量: 5447
#
# 🎉 合并成功！
# ============================================================

# %% [markdown]
# ## 删除已使用的csv

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
删除指定目录下的 stock_***.csv 文件
"""

import os
import glob
from pathlib import Path


def delete_stock_csv_files(target_directory, pattern="stock_*.csv"):
    #删除满足模式的所有文件
    files = glob.glob(os.path.join(target_directory, pattern))
    for file in files:
        try:
            os.remove(file)
            print(f"已删除：{file}")
        except Exception as e:
            print(f"删除 {file} 失败：{e}")

if __name__ == "__main__":
    delete_stock_csv_files(r'D:\workspace\xiaoyao\redis','stock_minute_price_*.csv')
    print("\n" + "=" * 60)
# Out:
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000001.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000002.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000004.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000006.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000007.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000008.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000009.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000010.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000011.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000012.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000014.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000017.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000019.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000020.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000021.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000025.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000026.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000027.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000028.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000029.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000030.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000031.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000032.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000034.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000035.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000036.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000037.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000039.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000040.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000042.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000045.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000048.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000049.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000050.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000055.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000056.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000058.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000059.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000060.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000061.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000062.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000063.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000065.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000066.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000068.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000069.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000070.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000078.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000088.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000089.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000090.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000096.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000099.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000100.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000151.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000153.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000155.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000156.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000157.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000158.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000159.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000166.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000301.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000333.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000338.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000400.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000401.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000402.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000403.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000404.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000407.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000408.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000409.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000410.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000411.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000415.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000417.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000419.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000420.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000422.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000423.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000425.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000426.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000428.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000429.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000430.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000488.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000498.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000501.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000503.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000504.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000505.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000506.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000507.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000509.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000510.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000513.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000514.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000516.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000517.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000518.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000519.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000520.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000521.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000523.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000524.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000525.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000526.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000528.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000529.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000530.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000531.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000532.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000533.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000534.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000536.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000537.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000538.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000539.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000541.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000543.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000544.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000545.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000546.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000547.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000548.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000550.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000551.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000552.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000553.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000554.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000555.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000557.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000558.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000559.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000560.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000561.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000563.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000564.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000565.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000566.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000567.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000568.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000570.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000571.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000572.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000573.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000576.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000581.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000582.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000584.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000586.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000589.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000590.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000591.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000592.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000593.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000595.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000596.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000597.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000598.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000599.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000600.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000601.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000603.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000605.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000607.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000608.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000609.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000610.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000612.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000615.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000617.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000619.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000620.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000622.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000623.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000625.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000626.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000627.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000628.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000629.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000630.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000631.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000632.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000633.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000635.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000636.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000637.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000638.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000639.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000650.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000651.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000652.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000655.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000656.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000657.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000659.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000661.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000663.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000665.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000668.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000669.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000670.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000672.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000676.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000677.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000678.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000679.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000680.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000681.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000682.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000683.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000685.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000686.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000688.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000690.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000691.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000692.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000695.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000697.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000698.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000700.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000701.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000702.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000703.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000705.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000707.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000708.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000709.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000710.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000711.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000712.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000713.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000715.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000716.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000717.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000718.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000719.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000720.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000721.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000722.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000723.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000725.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000726.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000727.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000728.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000729.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000731.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000733.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000735.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000736.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000737.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000738.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000739.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000750.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000751.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000752.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000753.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000755.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000756.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000757.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000758.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000759.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000761.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000762.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000766.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000767.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000768.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000776.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000778.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000779.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000782.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000783.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000785.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000786.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000788.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000789.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000790.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000791.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000792.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000793.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000795.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000796.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000797.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000798.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000799.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000800.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000801.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000802.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000803.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000807.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000809.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000810.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000811.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000812.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000813.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000815.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000816.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000818.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000819.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000820.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000821.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000822.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000823.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000825.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000826.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000828.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000829.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000830.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000831.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000833.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000837.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000838.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000839.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000848.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000850.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000851.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000852.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000856.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000858.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000859.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000860.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000862.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000863.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000868.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000869.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000875.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000876.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000877.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000878.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000880.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000881.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000882.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000883.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000885.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000886.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000887.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000888.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000889.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000890.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000892.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000893.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000895.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000897.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000898.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000899.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000900.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000901.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000902.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000903.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000905.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000906.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000908.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000909.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000910.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000911.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000912.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000913.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000915.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000917.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000919.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000920.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000921.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000922.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000923.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000925.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000926.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000927.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000928.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000929.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000930.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000931.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000932.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000933.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000935.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000936.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000937.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000938.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000948.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000949.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000950.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000951.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000952.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000953.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000955.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000957.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000958.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000959.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000960.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000962.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000963.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000965.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000966.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000967.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000968.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000969.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000970.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000972.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000973.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000975.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000977.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000978.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000980.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000981.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000983.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000985.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000987.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000988.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000989.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000990.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000993.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000995.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000997.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000998.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_000999.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001201.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001202.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001203.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001205.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001206.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001207.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001208.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001209.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001210.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001211.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001212.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001213.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001215.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001216.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001217.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001218.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001219.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001222.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001223.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001225.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001226.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001227.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001228.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001229.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001230.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001231.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001234.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001236.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001238.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001239.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001255.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001256.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001258.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001259.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001260.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001266.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001267.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001268.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001269.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001270.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001277.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001278.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001279.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001282.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001283.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001286.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001287.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001288.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001289.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001296.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001298.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001299.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001300.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001301.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001306.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001308.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001309.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001311.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001313.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001314.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001316.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001317.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001318.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001319.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001322.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001323.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001324.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001326.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001328.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001330.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001331.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001332.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001333.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001336.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001337.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001338.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001339.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001358.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001359.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001360.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001366.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001367.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001368.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001373.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001376.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001378.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001379.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001380.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001387.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001389.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001391.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001696.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001872.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001896.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001914.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001965.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_001979.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002001.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002003.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002004.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002005.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002006.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002007.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002008.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002009.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002010.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002011.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002012.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002014.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002015.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002016.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002017.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002019.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002020.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002021.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002022.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002023.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002024.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002025.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002026.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002027.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002028.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002029.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002030.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002031.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002032.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002033.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002034.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002035.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002036.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002037.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002038.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002039.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002040.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002041.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002042.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002043.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002044.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002045.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002046.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002047.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002048.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002049.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002050.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002051.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002052.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002053.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002054.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002055.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002056.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002057.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002058.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002059.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002060.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002061.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002062.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002063.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002064.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002065.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002066.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002067.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002068.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002069.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002072.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002073.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002074.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002075.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002076.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002077.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002078.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002079.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002080.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002081.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002082.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002083.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002084.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002085.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002086.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002088.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002090.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002091.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002092.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002093.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002094.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002095.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002096.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002097.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002098.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002099.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002100.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002101.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002102.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002103.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002104.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002105.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002106.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002107.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002108.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002109.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002110.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002111.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002112.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002114.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002115.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002116.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002117.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002119.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002120.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002121.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002122.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002124.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002125.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002126.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002127.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002128.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002129.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002130.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002131.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002132.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002133.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002134.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002135.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002136.XSHE.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_002137.XSHE.csv
# ...
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600966.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600967.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600968.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600969.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600970.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600971.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600973.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600975.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600976.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600977.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600979.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600980.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600981.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600982.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600983.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600984.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600985.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600986.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600987.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600988.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600989.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600990.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600992.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600993.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600995.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600996.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600997.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600998.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_600999.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601000.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601001.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601002.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601003.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601005.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601006.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601007.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601008.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601009.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601010.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601011.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601012.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601015.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601016.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601018.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601019.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601020.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601021.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601022.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601028.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601033.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601038.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601058.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601059.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601061.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601065.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601066.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601068.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601069.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601077.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601083.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601086.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601088.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601089.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601096.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601098.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601099.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601100.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601101.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601106.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601107.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601108.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601111.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601113.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601116.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601117.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601118.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601121.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601126.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601127.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601128.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601133.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601136.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601137.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601138.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601139.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601155.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601156.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601158.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601162.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601163.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601166.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601168.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601169.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601177.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601179.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601186.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601187.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601188.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601198.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601199.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601200.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601208.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601211.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601212.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601216.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601218.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601222.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601225.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601226.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601228.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601229.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601231.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601233.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601236.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601238.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601279.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601288.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601298.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601311.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601318.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601319.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601326.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601328.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601330.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601333.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601336.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601339.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601360.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601366.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601368.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601369.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601375.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601377.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601388.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601390.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601398.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601399.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601456.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601500.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601512.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601515.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601518.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601519.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601528.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601555.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601566.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601567.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601568.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601577.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601579.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601588.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601595.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601598.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601599.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601600.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601601.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601606.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601607.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601608.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601609.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601611.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601615.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601616.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601618.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601619.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601628.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601633.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601636.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601658.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601665.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601666.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601668.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601669.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601677.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601678.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601686.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601688.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601689.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601696.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601698.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601699.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601700.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601702.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601717.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601718.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601727.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601728.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601766.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601777.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601778.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601788.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601789.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601798.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601799.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601800.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601801.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601808.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601811.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601816.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601818.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601825.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601827.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601828.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601838.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601857.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601858.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601860.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601865.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601866.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601868.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601869.XSHG.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_minute_price_20250102_601872.XSHG.csv
#
# ============================================================

# %% [markdown]
# ## 将新的parquet文件移动到data目录覆盖原文件

# %%
# 将子目录下的某个parquet文件移动到指定目录
import os
import shutil

# 定义源目录和目标目录
source_dir = "D:\\workspace\\xiaoyao\\redis\\parquet"
target_dir = "D:\\workspace\\xiaoyao\\data"

# 确保目标目录存在
os.makedirs(target_dir, exist_ok=True)

# 定义要移动的文件
file_to_move = "stock_daily_price.parquet"

# 构建源文件的完整路径
source_file_path = os.path.join(source_dir, file_to_move)

# 构建目标文件的完整路径
target_file_path = os.path.join(target_dir, file_to_move)

# 检查源文件是否存在
if os.path.exists(source_file_path):
    # 移动文件
    shutil.move(source_file_path, target_file_path)
    print(f"Moved: {file_to_move} to {target_dir}")
else:
    print(f"File not found: {file_to_move}")

# 删除指定的parquet文件
file_to_delete = os.path.join(source_dir, 'stock_daily_price_to_merged.parquet')
if os.path.exists(file_to_delete):
    os.remove(file_to_delete)
    print(f"Deleted: {file_to_move} from {source_dir}")
else:
    print(f"File not found: {file_to_move} in {source_dir}")
# Out:
# Moved: stock_daily_price.parquet to D:\workspace\xiaoyao\data
# Deleted: stock_daily_price.parquet from D:\workspace\xiaoyao\redis\parquet
