# %% [markdown]
# ## 1.下载数据

# %%
import redis
import pickle
import time
import uuid
import pandas as pd
from io import StringIO
from typing import Any, Optional
from datetime import datetime, timedelta

class RemoteSender:
    def __init__(self, host='*', port=6379, password='*'):
        self.redis = redis.Redis(
            host=host, port=port, password=password,
            decode_responses=False
        )
        self.task_queue = 'function_calls'
        self.result_queue = 'function_results'
        self._test_connection()
        print(f"✅ 发送端pandas版本：{pd.__version__}")

    def _test_connection(self):
        try:
            self.redis.ping()
            print("✅ 发送端：Redis连接成功")
        except Exception as e:
            print(f"❌ 发送端：连接失败 - {e}")
            raise

    def call_remote_function(self, func_name: str, *args, **kwargs) -> Any:
        task_id = f"task_{uuid.uuid4().hex[:8]}"
        task = {
            'func_name': func_name,
            'args': args,
            'kwargs': kwargs,
            'task_id': task_id
        }
        self.redis.rpush(self.task_queue, pickle.dumps(task))
        print(f"📤 已调用远程函数：{func_name}（任务ID：{task_id}）")
        return self._get_result(task_id)

    def _get_result(self, task_id: str, timeout=300) -> Any:
        start_time = time.time()
        while time.time() - start_time < timeout:
            result_data = self.redis.blpop(self.result_queue, timeout=10)
            if not result_data:
                continue

            _, res_bytes = result_data
            result = pickle.loads(res_bytes)
            if result['task_id'] == task_id:
                if result['status'] == 'success':
                    return result['result']  # 返回CSV字符串
                else:
                    raise Exception(f"远程执行失败：{result['error']}")
            self.redis.rpush(self.result_queue, res_bytes)
        raise TimeoutError("任务超时")

    def save_to_csv(self, csv_str: Optional[str], filename: str) -> bool:
        """将CSV字符串保存为本地CSV文件（替代Parquet）"""
        if not csv_str:
            print("⚠️ 数据为空，不保存")
            return False
        try:
            # 从CSV字符串恢复DataFrame（兼容所有pandas版本）
            df = pd.read_csv(StringIO(csv_str))
            # 保存为CSV文件
            df.to_csv(filename, index=False)
            print(f"✅ 保存成功：{filename}（{len(df)}条记录）")
            return True
        except Exception as e:
            print(f"❌ 保存失败：{e}")
            return False

def generate_date_range(start_date_str: str, end_date_str: str) -> list:
    """生成从开始日期到结束日期的所有日期字符串（YYYYMMDD格式）"""
    dates = []
    try:
        start_date = datetime.strptime(start_date_str, '%Y%m%d')
        end_date = datetime.strptime(end_date_str, '%Y%m%d')
        
        if start_date > end_date:
            raise ValueError("开始日期晚于结束日期")
            
        current_date = start_date
        while current_date <= end_date:
            dates.append(current_date.strftime('%Y%m%d'))
            current_date += timedelta(days=1)
    except Exception as e:
        print(f"日期处理错误：{e}")
    return dates

if __name__ == "__main__":

    # 从配置文件读取Redis连接信息
    with open('redis.conf', 'r') as f:
        for line in f:
            if line.startswith('host='):
                host = line.split('=')[1].strip()
            elif line.startswith('port='):
                port = int(line.split('=')[1].strip())
            elif line.startswith('password='):
                password = line.split('=')[1].strip()
    # 初始化Redis发送端
    sender = RemoteSender(host=host, port=port, password=password)
    
    # 定义日期范围：从20250516到20250923
    # 读取../data/stock_daily_price.parquet文件，获取最大的日期+1，是start_date
    df = pd.read_parquet('../data/stock_daily_cctvnews.parquet')
    start_date = '20230101'#(df['date'].max() + timedelta(days=1)).strftime('%Y%m%d')
    # 获取当日日期-1，是end_date
    end_date = '20241231'#(datetime.today() - timedelta(days=1)).strftime('%Y%m%d')
    
    # 生成日期列表
    date_list = generate_date_range(start_date, end_date)
    print(f"=== 共需获取 {len(date_list)} 天的数据 ===")
    
    # 循环调用获取每日数据
    for i, date in enumerate(date_list, 1):
        print(f"\n=== 正在处理 {i}/{len(date_list)}：{date} ===")
        try:
            # 调用远程函数获取当日数据
            csv_data = sender.call_remote_function('fetch_cctv_news', date)
            # 保存为CSV文件，文件名包含日期
            sender.save_to_csv(csv_data, f'stock_daily_cctvnews_{date}.csv')
            
            # 适当延迟，避免请求过于频繁
            time.sleep(0.1)
        except Exception as e:
            print(f"❌ {date} 处理失败：{e}")
            # 失败后也延迟一下，避免快速重试导致的问题
            time.sleep(2)
    
    print("\n=== 所有日期处理完成 ===")
# Out:
# ✅ 发送端：Redis连接成功
# ✅ 发送端pandas版本：2.3.2
# === 共需获取 731 天的数据 ===
#
# === 正在处理 1/731：20230101 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_99f4a249）
# ✅ 保存成功：stock_daily_cctvnews_20230101.csv（13条记录）
#
# === 正在处理 2/731：20230102 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0c07ce62）
# ✅ 保存成功：stock_daily_cctvnews_20230102.csv（12条记录）
#
# === 正在处理 3/731：20230103 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9268ce1f）
# ✅ 保存成功：stock_daily_cctvnews_20230103.csv（13条记录）
#
# === 正在处理 4/731：20230104 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a5b75a4a）
# ✅ 保存成功：stock_daily_cctvnews_20230104.csv（13条记录）
#
# === 正在处理 5/731：20230105 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_80af5d23）
# ✅ 保存成功：stock_daily_cctvnews_20230105.csv（12条记录）
#
# === 正在处理 6/731：20230106 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_996c5180）
# ✅ 保存成功：stock_daily_cctvnews_20230106.csv（15条记录）
#
# === 正在处理 7/731：20230107 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fa59af7b）
# ✅ 保存成功：stock_daily_cctvnews_20230107.csv（12条记录）
#
# === 正在处理 8/731：20230108 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_37c65a9e）
# ✅ 保存成功：stock_daily_cctvnews_20230108.csv（12条记录）
#
# === 正在处理 9/731：20230109 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9324a9c6）
# ✅ 保存成功：stock_daily_cctvnews_20230109.csv（11条记录）
#
# === 正在处理 10/731：20230110 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1ccbb0a1）
# ✅ 保存成功：stock_daily_cctvnews_20230110.csv（13条记录）
#
# === 正在处理 11/731：20230111 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ae4e0924）
# ✅ 保存成功：stock_daily_cctvnews_20230111.csv（12条记录）
#
# === 正在处理 12/731：20230112 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7d16b012）
# ✅ 保存成功：stock_daily_cctvnews_20230112.csv（15条记录）
#
# === 正在处理 13/731：20230113 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_912bd93f）
# ✅ 保存成功：stock_daily_cctvnews_20230113.csv（13条记录）
#
# === 正在处理 14/731：20230114 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e0bb319a）
# ✅ 保存成功：stock_daily_cctvnews_20230114.csv（10条记录）
#
# === 正在处理 15/731：20230115 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4fbc9698）
# ✅ 保存成功：stock_daily_cctvnews_20230115.csv（13条记录）
#
# === 正在处理 16/731：20230116 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8e0764be）
# ✅ 保存成功：stock_daily_cctvnews_20230116.csv（10条记录）
#
# === 正在处理 17/731：20230117 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b3217c47）
# ✅ 保存成功：stock_daily_cctvnews_20230117.csv（12条记录）
#
# === 正在处理 18/731：20230118 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_775937b3）
# ✅ 保存成功：stock_daily_cctvnews_20230118.csv（10条记录）
#
# === 正在处理 19/731：20230119 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_af928bd7）
# ✅ 保存成功：stock_daily_cctvnews_20230119.csv（15条记录）
#
# === 正在处理 20/731：20230120 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d219a53e）
# ✅ 保存成功：stock_daily_cctvnews_20230120.csv（10条记录）
#
# === 正在处理 21/731：20230121 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4274a3ad）
# ✅ 保存成功：stock_daily_cctvnews_20230121.csv（12条记录）
#
# === 正在处理 22/731：20230122 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_edf52c1c）
# ✅ 保存成功：stock_daily_cctvnews_20230122.csv（11条记录）
#
# === 正在处理 23/731：20230123 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_808a876c）
# ✅ 保存成功：stock_daily_cctvnews_20230123.csv（12条记录）
#
# === 正在处理 24/731：20230124 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a185cfc3）
# ✅ 保存成功：stock_daily_cctvnews_20230124.csv（13条记录）
#
# === 正在处理 25/731：20230125 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4f528b31）
# ✅ 保存成功：stock_daily_cctvnews_20230125.csv（14条记录）
#
# === 正在处理 26/731：20230126 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cfdd5246）
# ✅ 保存成功：stock_daily_cctvnews_20230126.csv（14条记录）
#
# === 正在处理 27/731：20230127 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8c9e1293）
# ✅ 保存成功：stock_daily_cctvnews_20230127.csv（15条记录）
#
# === 正在处理 28/731：20230128 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_66c7def4）
# ✅ 保存成功：stock_daily_cctvnews_20230128.csv（12条记录）
#
# === 正在处理 29/731：20230129 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7f1a1580）
# ✅ 保存成功：stock_daily_cctvnews_20230129.csv（13条记录）
#
# === 正在处理 30/731：20230130 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_99070f39）
# ✅ 保存成功：stock_daily_cctvnews_20230130.csv（14条记录）
#
# === 正在处理 31/731：20230131 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_748fe9b5）
# ✅ 保存成功：stock_daily_cctvnews_20230131.csv（12条记录）
#
# === 正在处理 32/731：20230201 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_848b4109）
# ✅ 保存成功：stock_daily_cctvnews_20230201.csv（11条记录）
#
# === 正在处理 33/731：20230202 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1539fc96）
# ✅ 保存成功：stock_daily_cctvnews_20230202.csv（13条记录）
#
# === 正在处理 34/731：20230203 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_de6b098b）
# ✅ 保存成功：stock_daily_cctvnews_20230203.csv（13条记录）
#
# === 正在处理 35/731：20230204 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3fa90310）
# ✅ 保存成功：stock_daily_cctvnews_20230204.csv（13条记录）
#
# === 正在处理 36/731：20230205 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1cf5441e）
# ✅ 保存成功：stock_daily_cctvnews_20230205.csv（13条记录）
#
# === 正在处理 37/731：20230206 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ab523d49）
# ✅ 保存成功：stock_daily_cctvnews_20230206.csv（14条记录）
#
# === 正在处理 38/731：20230207 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9cf5cf2d）
# ✅ 保存成功：stock_daily_cctvnews_20230207.csv（10条记录）
#
# === 正在处理 39/731：20230208 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8c5944ea）
# ✅ 保存成功：stock_daily_cctvnews_20230208.csv（12条记录）
#
# === 正在处理 40/731：20230209 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_eed0c2b5）
# ✅ 保存成功：stock_daily_cctvnews_20230209.csv（13条记录）
#
# === 正在处理 41/731：20230210 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_953e4e9a）
# ✅ 保存成功：stock_daily_cctvnews_20230210.csv（15条记录）
#
# === 正在处理 42/731：20230211 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bc96224c）
# ✅ 保存成功：stock_daily_cctvnews_20230211.csv（12条记录）
#
# === 正在处理 43/731：20230212 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ded5a944）
# ✅ 保存成功：stock_daily_cctvnews_20230212.csv（14条记录）
#
# === 正在处理 44/731：20230213 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8c31df1e）
# ✅ 保存成功：stock_daily_cctvnews_20230213.csv（15条记录）
#
# === 正在处理 45/731：20230214 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d04d4310）
# ✅ 保存成功：stock_daily_cctvnews_20230214.csv（14条记录）
#
# === 正在处理 46/731：20230215 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c886e0fc）
# ✅ 保存成功：stock_daily_cctvnews_20230215.csv（15条记录）
#
# === 正在处理 47/731：20230216 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_98652ca7）
# ✅ 保存成功：stock_daily_cctvnews_20230216.csv（17条记录）
#
# === 正在处理 48/731：20230217 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cf7705b9）
# ✅ 保存成功：stock_daily_cctvnews_20230217.csv（12条记录）
#
# === 正在处理 49/731：20230218 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0dd6ee7a）
# ✅ 保存成功：stock_daily_cctvnews_20230218.csv（15条记录）
#
# === 正在处理 50/731：20230219 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e080234a）
# ✅ 保存成功：stock_daily_cctvnews_20230219.csv（13条记录）
#
# === 正在处理 51/731：20230220 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fe8cedf8）
# ✅ 保存成功：stock_daily_cctvnews_20230220.csv（14条记录）
#
# === 正在处理 52/731：20230221 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_90cfebc6）
# ✅ 保存成功：stock_daily_cctvnews_20230221.csv（15条记录）
#
# === 正在处理 53/731：20230222 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_81b645dc）
# ✅ 保存成功：stock_daily_cctvnews_20230222.csv（12条记录）
#
# === 正在处理 54/731：20230223 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6d5505a2）
# ✅ 保存成功：stock_daily_cctvnews_20230223.csv（16条记录）
#
# === 正在处理 55/731：20230224 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_354658a9）
# ✅ 保存成功：stock_daily_cctvnews_20230224.csv（13条记录）
#
# === 正在处理 56/731：20230225 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_70329189）
# ✅ 保存成功：stock_daily_cctvnews_20230225.csv（10条记录）
#
# === 正在处理 57/731：20230226 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f0cfea3c）
# ✅ 保存成功：stock_daily_cctvnews_20230226.csv（12条记录）
#
# === 正在处理 58/731：20230227 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e8d2e836）
# ✅ 保存成功：stock_daily_cctvnews_20230227.csv（13条记录）
#
# === 正在处理 59/731：20230228 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_47211ca1）
# ✅ 保存成功：stock_daily_cctvnews_20230228.csv（10条记录）
#
# === 正在处理 60/731：20230301 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8335473f）
# ✅ 保存成功：stock_daily_cctvnews_20230301.csv（21条记录）
#
# === 正在处理 61/731：20230302 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2dfec8e0）
# ✅ 保存成功：stock_daily_cctvnews_20230302.csv（16条记录）
#
# === 正在处理 62/731：20230303 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3da4e218）
# ✅ 保存成功：stock_daily_cctvnews_20230303.csv（16条记录）
#
# === 正在处理 63/731：20230304 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a440f639）
# ✅ 保存成功：stock_daily_cctvnews_20230304.csv（13条记录）
#
# === 正在处理 64/731：20230305 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fb475cf8）
# ✅ 保存成功：stock_daily_cctvnews_20230305.csv（16条记录）
#
# === 正在处理 65/731：20230306 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_23f996e8）
# ✅ 保存成功：stock_daily_cctvnews_20230306.csv（21条记录）
#
# === 正在处理 66/731：20230307 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fca12799）
# ✅ 保存成功：stock_daily_cctvnews_20230307.csv（18条记录）
#
# === 正在处理 67/731：20230308 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d3da674a）
# ✅ 保存成功：stock_daily_cctvnews_20230308.csv（18条记录）
#
# === 正在处理 68/731：20230309 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1be9c512）
# ✅ 保存成功：stock_daily_cctvnews_20230309.csv（17条记录）
#
# === 正在处理 69/731：20230310 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6d289af8）
# ✅ 保存成功：stock_daily_cctvnews_20230310.csv（19条记录）
#
# === 正在处理 70/731：20230311 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_712f1680）
# ✅ 保存成功：stock_daily_cctvnews_20230311.csv（13条记录）
#
# === 正在处理 71/731：20230312 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a3df7989）
# ✅ 保存成功：stock_daily_cctvnews_20230312.csv（21条记录）
#
# === 正在处理 72/731：20230313 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b64a8863）
# ✅ 保存成功：stock_daily_cctvnews_20230313.csv（14条记录）
#
# === 正在处理 73/731：20230314 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a82543c5）
# ✅ 保存成功：stock_daily_cctvnews_20230314.csv（15条记录）
#
# === 正在处理 74/731：20230315 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d58b0e82）
# ✅ 保存成功：stock_daily_cctvnews_20230315.csv（16条记录）
#
# === 正在处理 75/731：20230316 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_46d7668f）
# ✅ 保存成功：stock_daily_cctvnews_20230316.csv（11条记录）
#
# === 正在处理 76/731：20230317 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_05c0ce68）
# ✅ 保存成功：stock_daily_cctvnews_20230317.csv（16条记录）
#
# === 正在处理 77/731：20230318 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b4d46a0c）
# ✅ 保存成功：stock_daily_cctvnews_20230318.csv（17条记录）
#
# === 正在处理 78/731：20230319 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c7996431）
# ✅ 保存成功：stock_daily_cctvnews_20230319.csv（14条记录）
#
# === 正在处理 79/731：20230320 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f36cbaf5）
# ✅ 保存成功：stock_daily_cctvnews_20230320.csv（16条记录）
#
# === 正在处理 80/731：20230321 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_765ee270）
# ✅ 保存成功：stock_daily_cctvnews_20230321.csv（12条记录）
#
# === 正在处理 81/731：20230322 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4d91113b）
# ✅ 保存成功：stock_daily_cctvnews_20230322.csv（11条记录）
#
# === 正在处理 82/731：20230323 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9f474b2c）
# ✅ 保存成功：stock_daily_cctvnews_20230323.csv（12条记录）
#
# === 正在处理 83/731：20230324 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_490e7613）
# ✅ 保存成功：stock_daily_cctvnews_20230324.csv（11条记录）
#
# === 正在处理 84/731：20230325 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9675a129）
# ✅ 保存成功：stock_daily_cctvnews_20230325.csv（14条记录）
#
# === 正在处理 85/731：20230326 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ded8cf3d）
# ✅ 保存成功：stock_daily_cctvnews_20230326.csv（15条记录）
#
# === 正在处理 86/731：20230327 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b8036851）
# ✅ 保存成功：stock_daily_cctvnews_20230327.csv（15条记录）
#
# === 正在处理 87/731：20230328 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a50ba9ca）
# ✅ 保存成功：stock_daily_cctvnews_20230328.csv（15条记录）
#
# === 正在处理 88/731：20230329 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_84683bc2）
# ✅ 保存成功：stock_daily_cctvnews_20230329.csv（12条记录）
#
# === 正在处理 89/731：20230330 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_546ff49f）
# ✅ 保存成功：stock_daily_cctvnews_20230330.csv（14条记录）
#
# === 正在处理 90/731：20230331 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6f3d4634）
# ✅ 保存成功：stock_daily_cctvnews_20230331.csv（17条记录）
#
# === 正在处理 91/731：20230401 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9b182ef2）
# ✅ 保存成功：stock_daily_cctvnews_20230401.csv（13条记录）
#
# === 正在处理 92/731：20230402 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6f1625f0）
# ✅ 保存成功：stock_daily_cctvnews_20230402.csv（17条记录）
#
# === 正在处理 93/731：20230403 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d0194143）
# ✅ 保存成功：stock_daily_cctvnews_20230403.csv（11条记录）
#
# === 正在处理 94/731：20230404 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_35f5ef40）
# ✅ 保存成功：stock_daily_cctvnews_20230404.csv（12条记录）
#
# === 正在处理 95/731：20230405 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_00d0cc0b）
# ✅ 保存成功：stock_daily_cctvnews_20230405.csv（15条记录）
#
# === 正在处理 96/731：20230406 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a61fe751）
# ✅ 保存成功：stock_daily_cctvnews_20230406.csv（22条记录）
#
# === 正在处理 97/731：20230407 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4959fa13）
# ✅ 保存成功：stock_daily_cctvnews_20230407.csv（12条记录）
#
# === 正在处理 98/731：20230408 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_239c097b）
# ✅ 保存成功：stock_daily_cctvnews_20230408.csv（13条记录）
#
# === 正在处理 99/731：20230409 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_53d02d84）
# ✅ 保存成功：stock_daily_cctvnews_20230409.csv（16条记录）
#
# === 正在处理 100/731：20230410 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b9befa8f）
# ✅ 保存成功：stock_daily_cctvnews_20230410.csv（14条记录）
#
# === 正在处理 101/731：20230411 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7d9decd6）
# ✅ 保存成功：stock_daily_cctvnews_20230411.csv（16条记录）
#
# === 正在处理 102/731：20230412 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9ccdc55c）
# ✅ 保存成功：stock_daily_cctvnews_20230412.csv（13条记录）
#
# === 正在处理 103/731：20230413 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7b7d73f2）
# ✅ 保存成功：stock_daily_cctvnews_20230413.csv（11条记录）
#
# === 正在处理 104/731：20230414 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_69f8eaac）
# ✅ 保存成功：stock_daily_cctvnews_20230414.csv（16条记录）
#
# === 正在处理 105/731：20230415 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_07186baf）
# ✅ 保存成功：stock_daily_cctvnews_20230415.csv（14条记录）
#
# === 正在处理 106/731：20230416 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6ad705ef）
# ✅ 保存成功：stock_daily_cctvnews_20230416.csv（15条记录）
#
# === 正在处理 107/731：20230417 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_dc743b9e）
# ✅ 保存成功：stock_daily_cctvnews_20230417.csv（15条记录）
#
# === 正在处理 108/731：20230418 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_de12f7b1）
# ✅ 保存成功：stock_daily_cctvnews_20230418.csv（16条记录）
#
# === 正在处理 109/731：20230419 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_49472f8c）
# ✅ 保存成功：stock_daily_cctvnews_20230419.csv（14条记录）
#
# === 正在处理 110/731：20230420 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_324c2cea）
# ✅ 保存成功：stock_daily_cctvnews_20230420.csv（17条记录）
#
# === 正在处理 111/731：20230421 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c9eb7a4f）
# ✅ 保存成功：stock_daily_cctvnews_20230421.csv（14条记录）
#
# === 正在处理 112/731：20230422 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c10329b1）
# ✅ 保存成功：stock_daily_cctvnews_20230422.csv（18条记录）
#
# === 正在处理 113/731：20230423 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d6ac77e8）
# ✅ 保存成功：stock_daily_cctvnews_20230423.csv（13条记录）
#
# === 正在处理 114/731：20230424 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3ab6008e）
# ✅ 保存成功：stock_daily_cctvnews_20230424.csv（15条记录）
#
# === 正在处理 115/731：20230425 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0fd6a58c）
# ✅ 保存成功：stock_daily_cctvnews_20230425.csv（18条记录）
#
# === 正在处理 116/731：20230426 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_32c5b5dc）
# ✅ 保存成功：stock_daily_cctvnews_20230426.csv（13条记录）
#
# === 正在处理 117/731：20230427 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3a6857d0）
# ✅ 保存成功：stock_daily_cctvnews_20230427.csv（17条记录）
#
# === 正在处理 118/731：20230428 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_84644793）
# ✅ 保存成功：stock_daily_cctvnews_20230428.csv（15条记录）
#
# === 正在处理 119/731：20230429 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1d4129e8）
# ✅ 保存成功：stock_daily_cctvnews_20230429.csv（16条记录）
#
# === 正在处理 120/731：20230430 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ef2428fe）
# ✅ 保存成功：stock_daily_cctvnews_20230430.csv（18条记录）
#
# === 正在处理 121/731：20230501 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2031ecc0）
# ✅ 保存成功：stock_daily_cctvnews_20230501.csv（15条记录）
#
# === 正在处理 122/731：20230502 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_14b2c97e）
# ✅ 保存成功：stock_daily_cctvnews_20230502.csv（17条记录）
#
# === 正在处理 123/731：20230503 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a4bb7940）
# ✅ 保存成功：stock_daily_cctvnews_20230503.csv（16条记录）
#
# === 正在处理 124/731：20230504 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_568ffc4a）
# ✅ 保存成功：stock_daily_cctvnews_20230504.csv（12条记录）
#
# === 正在处理 125/731：20230505 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_360cf299）
# ✅ 保存成功：stock_daily_cctvnews_20230505.csv（14条记录）
#
# === 正在处理 126/731：20230506 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_51acb9b1）
# ✅ 保存成功：stock_daily_cctvnews_20230506.csv（15条记录）
#
# === 正在处理 127/731：20230507 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_482f578a）
# ✅ 保存成功：stock_daily_cctvnews_20230507.csv（14条记录）
#
# === 正在处理 128/731：20230508 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5516100b）
# ✅ 保存成功：stock_daily_cctvnews_20230508.csv（18条记录）
#
# === 正在处理 129/731：20230509 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_101e4748）
# ✅ 保存成功：stock_daily_cctvnews_20230509.csv（16条记录）
#
# === 正在处理 130/731：20230510 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_87d6c89e）
# ✅ 保存成功：stock_daily_cctvnews_20230510.csv（11条记录）
#
# === 正在处理 131/731：20230511 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_93c14328）
# ✅ 保存成功：stock_daily_cctvnews_20230511.csv（15条记录）
#
# === 正在处理 132/731：20230512 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9098843f）
# ✅ 保存成功：stock_daily_cctvnews_20230512.csv（13条记录）
#
# === 正在处理 133/731：20230513 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7b097e0f）
# ✅ 保存成功：stock_daily_cctvnews_20230513.csv（13条记录）
#
# === 正在处理 134/731：20230514 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4376b782）
# ✅ 保存成功：stock_daily_cctvnews_20230514.csv（12条记录）
#
# === 正在处理 135/731：20230515 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_93e3476b）
# ✅ 保存成功：stock_daily_cctvnews_20230515.csv（14条记录）
#
# === 正在处理 136/731：20230516 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cad2c662）
# ✅ 保存成功：stock_daily_cctvnews_20230516.csv（13条记录）
#
# === 正在处理 137/731：20230517 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_db270f80）
# ✅ 保存成功：stock_daily_cctvnews_20230517.csv（9条记录）
#
# === 正在处理 138/731：20230518 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f0bfdda3）
# ✅ 保存成功：stock_daily_cctvnews_20230518.csv（11条记录）
#
# === 正在处理 139/731：20230519 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_60156ab3）
# ✅ 保存成功：stock_daily_cctvnews_20230519.csv（9条记录）
#
# === 正在处理 140/731：20230520 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5f2b2f30）
# ✅ 保存成功：stock_daily_cctvnews_20230520.csv（11条记录）
#
# === 正在处理 141/731：20230521 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e709ae15）
# ✅ 保存成功：stock_daily_cctvnews_20230521.csv（14条记录）
#
# === 正在处理 142/731：20230522 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1dbcb79d）
# ✅ 保存成功：stock_daily_cctvnews_20230522.csv（16条记录）
#
# === 正在处理 143/731：20230523 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_86ebe370）
# ✅ 保存成功：stock_daily_cctvnews_20230523.csv（18条记录）
#
# === 正在处理 144/731：20230524 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4ce61fce）
# ✅ 保存成功：stock_daily_cctvnews_20230524.csv（17条记录）
#
# === 正在处理 145/731：20230525 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1e6588f9）
# ✅ 保存成功：stock_daily_cctvnews_20230525.csv（15条记录）
#
# === 正在处理 146/731：20230526 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_75169ceb）
# ✅ 保存成功：stock_daily_cctvnews_20230526.csv（16条记录）
#
# === 正在处理 147/731：20230527 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_de7b24c5）
# ✅ 保存成功：stock_daily_cctvnews_20230527.csv（13条记录）
#
# === 正在处理 148/731：20230528 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5383af28）
# ✅ 保存成功：stock_daily_cctvnews_20230528.csv（13条记录）
#
# === 正在处理 149/731：20230529 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0ab34450）
# ✅ 保存成功：stock_daily_cctvnews_20230529.csv（11条记录）
#
# === 正在处理 150/731：20230530 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_457e8bcb）
# ✅ 保存成功：stock_daily_cctvnews_20230530.csv（13条记录）
#
# === 正在处理 151/731：20230531 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a8801f80）
# ✅ 保存成功：stock_daily_cctvnews_20230531.csv（11条记录）
#
# === 正在处理 152/731：20230601 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c031dc8f）
# ✅ 保存成功：stock_daily_cctvnews_20230601.csv（13条记录）
#
# === 正在处理 153/731：20230602 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5b8e8ad7）
# ✅ 保存成功：stock_daily_cctvnews_20230602.csv（10条记录）
#
# === 正在处理 154/731：20230603 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_dca76392）
# ✅ 保存成功：stock_daily_cctvnews_20230603.csv（14条记录）
#
# === 正在处理 155/731：20230604 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_08962f37）
# ✅ 保存成功：stock_daily_cctvnews_20230604.csv（10条记录）
#
# === 正在处理 156/731：20230605 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_711a860c）
# ✅ 保存成功：stock_daily_cctvnews_20230605.csv（16条记录）
#
# === 正在处理 157/731：20230606 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ae7f4c4d）
# ✅ 保存成功：stock_daily_cctvnews_20230606.csv（10条记录）
#
# === 正在处理 158/731：20230607 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f1a4b700）
# ✅ 保存成功：stock_daily_cctvnews_20230607.csv（15条记录）
#
# === 正在处理 159/731：20230608 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6bb52389）
# ✅ 保存成功：stock_daily_cctvnews_20230608.csv（15条记录）
#
# === 正在处理 160/731：20230609 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2fa39149）
# ✅ 保存成功：stock_daily_cctvnews_20230609.csv（14条记录）
#
# === 正在处理 161/731：20230610 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_52a785c0）
# ✅ 保存成功：stock_daily_cctvnews_20230610.csv（11条记录）
#
# === 正在处理 162/731：20230611 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1b7c343a）
# ✅ 保存成功：stock_daily_cctvnews_20230611.csv（13条记录）
#
# === 正在处理 163/731：20230612 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2b6b4649）
# ✅ 保存成功：stock_daily_cctvnews_20230612.csv（13条记录）
#
# === 正在处理 164/731：20230613 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_18bc4d20）
# ✅ 保存成功：stock_daily_cctvnews_20230613.csv（15条记录）
#
# === 正在处理 165/731：20230614 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8953babf）
# ✅ 保存成功：stock_daily_cctvnews_20230614.csv（16条记录）
#
# === 正在处理 166/731：20230615 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_42cf006d）
# ✅ 保存成功：stock_daily_cctvnews_20230615.csv（17条记录）
#
# === 正在处理 167/731：20230616 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_da00f760）
# ✅ 保存成功：stock_daily_cctvnews_20230616.csv（13条记录）
#
# === 正在处理 168/731：20230617 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0fa4a655）
# ✅ 保存成功：stock_daily_cctvnews_20230617.csv（15条记录）
#
# === 正在处理 169/731：20230618 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_77bf1e27）
# ✅ 保存成功：stock_daily_cctvnews_20230618.csv（15条记录）
#
# === 正在处理 170/731：20230619 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e4a25b80）
# ✅ 保存成功：stock_daily_cctvnews_20230619.csv（10条记录）
#
# === 正在处理 171/731：20230620 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3f6aec09）
# ✅ 保存成功：stock_daily_cctvnews_20230620.csv（13条记录）
#
# === 正在处理 172/731：20230621 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1da29604）
# ✅ 保存成功：stock_daily_cctvnews_20230621.csv（16条记录）
#
# === 正在处理 173/731：20230622 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ad09ac4e）
# ✅ 保存成功：stock_daily_cctvnews_20230622.csv（14条记录）
#
# === 正在处理 174/731：20230623 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f83ea9e6）
# ✅ 保存成功：stock_daily_cctvnews_20230623.csv（17条记录）
#
# === 正在处理 175/731：20230624 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ed91163d）
# ✅ 保存成功：stock_daily_cctvnews_20230624.csv（18条记录）
#
# === 正在处理 176/731：20230625 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_105a0e84）
# ✅ 保存成功：stock_daily_cctvnews_20230625.csv（15条记录）
#
# === 正在处理 177/731：20230626 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9a25b46c）
# ✅ 保存成功：stock_daily_cctvnews_20230626.csv（13条记录）
#
# === 正在处理 178/731：20230627 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8d6fee9a）
# ✅ 保存成功：stock_daily_cctvnews_20230627.csv（17条记录）
#
# === 正在处理 179/731：20230628 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_aaa0e075）
# ✅ 保存成功：stock_daily_cctvnews_20230628.csv（23条记录）
#
# === 正在处理 180/731：20230629 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_518ec38e）
# ✅ 保存成功：stock_daily_cctvnews_20230629.csv（14条记录）
#
# === 正在处理 181/731：20230630 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1eeaea75）
# ✅ 保存成功：stock_daily_cctvnews_20230630.csv（16条记录）
#
# === 正在处理 182/731：20230701 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_de3b3d55）
# ✅ 保存成功：stock_daily_cctvnews_20230701.csv（12条记录）
#
# === 正在处理 183/731：20230702 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fd39cda5）
# ✅ 保存成功：stock_daily_cctvnews_20230702.csv（12条记录）
#
# === 正在处理 184/731：20230703 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8a94355b）
# ✅ 保存成功：stock_daily_cctvnews_20230703.csv（15条记录）
#
# === 正在处理 185/731：20230704 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_af8d5aa4）
# ✅ 保存成功：stock_daily_cctvnews_20230704.csv（11条记录）
#
# === 正在处理 186/731：20230705 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c253f9e7）
# ✅ 保存成功：stock_daily_cctvnews_20230705.csv（18条记录）
#
# === 正在处理 187/731：20230706 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_75cdf1a6）
# ✅ 保存成功：stock_daily_cctvnews_20230706.csv（18条记录）
#
# === 正在处理 188/731：20230707 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_65b0beff）
# ✅ 保存成功：stock_daily_cctvnews_20230707.csv（12条记录）
#
# === 正在处理 189/731：20230708 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bfb76d7f）
# ✅ 保存成功：stock_daily_cctvnews_20230708.csv（12条记录）
#
# === 正在处理 190/731：20230709 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4cc7c915）
# ✅ 保存成功：stock_daily_cctvnews_20230709.csv（13条记录）
#
# === 正在处理 191/731：20230710 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cb4d2f88）
# ✅ 保存成功：stock_daily_cctvnews_20230710.csv（18条记录）
#
# === 正在处理 192/731：20230711 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_93438bdd）
# ✅ 保存成功：stock_daily_cctvnews_20230711.csv（13条记录）
#
# === 正在处理 193/731：20230712 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e472e3ec）
# ✅ 保存成功：stock_daily_cctvnews_20230712.csv（17条记录）
#
# === 正在处理 194/731：20230713 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_318afbb8）
# ✅ 保存成功：stock_daily_cctvnews_20230713.csv（14条记录）
#
# === 正在处理 195/731：20230714 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_262fba0b）
# ✅ 保存成功：stock_daily_cctvnews_20230714.csv（16条记录）
#
# === 正在处理 196/731：20230715 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f783d9b3）
# ✅ 保存成功：stock_daily_cctvnews_20230715.csv（13条记录）
#
# === 正在处理 197/731：20230716 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_86e39ee7）
# ✅ 保存成功：stock_daily_cctvnews_20230716.csv（13条记录）
#
# === 正在处理 198/731：20230717 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_56f19406）
# ✅ 保存成功：stock_daily_cctvnews_20230717.csv（16条记录）
#
# === 正在处理 199/731：20230718 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7636122f）
# ✅ 保存成功：stock_daily_cctvnews_20230718.csv（12条记录）
#
# === 正在处理 200/731：20230719 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_00b8bce1）
# ✅ 保存成功：stock_daily_cctvnews_20230719.csv（15条记录）
#
# === 正在处理 201/731：20230720 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b595f9aa）
# ✅ 保存成功：stock_daily_cctvnews_20230720.csv（16条记录）
#
# === 正在处理 202/731：20230721 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_89760f85）
# ✅ 保存成功：stock_daily_cctvnews_20230721.csv（18条记录）
#
# === 正在处理 203/731：20230722 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1ab6ce0f）
# ✅ 保存成功：stock_daily_cctvnews_20230722.csv（14条记录）
#
# === 正在处理 204/731：20230723 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f550156d）
# ✅ 保存成功：stock_daily_cctvnews_20230723.csv（15条记录）
#
# === 正在处理 205/731：20230724 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b73d0e59）
# ✅ 保存成功：stock_daily_cctvnews_20230724.csv（15条记录）
#
# === 正在处理 206/731：20230725 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_22c64642）
# ✅ 保存成功：stock_daily_cctvnews_20230725.csv（15条记录）
#
# === 正在处理 207/731：20230726 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6a7cc7ab）
# ✅ 保存成功：stock_daily_cctvnews_20230726.csv（15条记录）
#
# === 正在处理 208/731：20230727 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9c1f7d93）
# ✅ 保存成功：stock_daily_cctvnews_20230727.csv（13条记录）
#
# === 正在处理 209/731：20230728 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_13b4384b）
# ✅ 保存成功：stock_daily_cctvnews_20230728.csv（12条记录）
#
# === 正在处理 210/731：20230729 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e9fde1b4）
# ✅ 保存成功：stock_daily_cctvnews_20230729.csv（8条记录）
#
# === 正在处理 211/731：20230730 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_92cd2e07）
# ✅ 保存成功：stock_daily_cctvnews_20230730.csv（16条记录）
#
# === 正在处理 212/731：20230731 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e9b0082a）
# ✅ 保存成功：stock_daily_cctvnews_20230731.csv（17条记录）
#
# === 正在处理 213/731：20230801 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b58c21c0）
# ✅ 保存成功：stock_daily_cctvnews_20230801.csv（15条记录）
#
# === 正在处理 214/731：20230802 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b942b191）
# ✅ 保存成功：stock_daily_cctvnews_20230802.csv（13条记录）
#
# === 正在处理 215/731：20230803 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bd856aec）
# ✅ 保存成功：stock_daily_cctvnews_20230803.csv（12条记录）
#
# === 正在处理 216/731：20230804 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a443c8d8）
# ✅ 保存成功：stock_daily_cctvnews_20230804.csv（10条记录）
#
# === 正在处理 217/731：20230805 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_070cc323）
# ✅ 保存成功：stock_daily_cctvnews_20230805.csv（13条记录）
#
# === 正在处理 218/731：20230806 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_74a959cf）
# ✅ 保存成功：stock_daily_cctvnews_20230806.csv（13条记录）
#
# === 正在处理 219/731：20230807 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d4c418d4）
# ✅ 保存成功：stock_daily_cctvnews_20230807.csv（11条记录）
#
# === 正在处理 220/731：20230808 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_67b2fed1）
# ✅ 保存成功：stock_daily_cctvnews_20230808.csv（11条记录）
#
# === 正在处理 221/731：20230809 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_78370678）
# ✅ 保存成功：stock_daily_cctvnews_20230809.csv（13条记录）
#
# === 正在处理 222/731：20230810 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0ecbb051）
# ✅ 保存成功：stock_daily_cctvnews_20230810.csv（12条记录）
#
# === 正在处理 223/731：20230811 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b6e95970）
# ✅ 保存成功：stock_daily_cctvnews_20230811.csv（10条记录）
#
# === 正在处理 224/731：20230812 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_568d99c9）
# ✅ 保存成功：stock_daily_cctvnews_20230812.csv（13条记录）
#
# === 正在处理 225/731：20230813 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2e5b428e）
# ✅ 保存成功：stock_daily_cctvnews_20230813.csv（13条记录）
#
# === 正在处理 226/731：20230814 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2bcffd99）
# ✅ 保存成功：stock_daily_cctvnews_20230814.csv（10条记录）
#
# === 正在处理 227/731：20230815 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cb433515）
# ✅ 保存成功：stock_daily_cctvnews_20230815.csv（14条记录）
#
# === 正在处理 228/731：20230816 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fc45a104）
# ✅ 保存成功：stock_daily_cctvnews_20230816.csv（12条记录）
#
# === 正在处理 229/731：20230817 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5e37959c）
# ✅ 保存成功：stock_daily_cctvnews_20230817.csv（9条记录）
#
# === 正在处理 230/731：20230818 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0b64c6ae）
# ✅ 保存成功：stock_daily_cctvnews_20230818.csv（16条记录）
#
# === 正在处理 231/731：20230819 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c6c67a4d）
# ✅ 保存成功：stock_daily_cctvnews_20230819.csv（12条记录）
#
# === 正在处理 232/731：20230820 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4161eef1）
# ✅ 保存成功：stock_daily_cctvnews_20230820.csv（9条记录）
#
# === 正在处理 233/731：20230821 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9cf7eea1）
# ✅ 保存成功：stock_daily_cctvnews_20230821.csv（15条记录）
#
# === 正在处理 234/731：20230822 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_96744488）
# ✅ 保存成功：stock_daily_cctvnews_20230822.csv（15条记录）
#
# === 正在处理 235/731：20230823 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c30b3efb）
# ✅ 保存成功：stock_daily_cctvnews_20230823.csv（9条记录）
#
# === 正在处理 236/731：20230824 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9bfa694e）
# ✅ 保存成功：stock_daily_cctvnews_20230824.csv（14条记录）
#
# === 正在处理 237/731：20230825 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5ec3ce77）
# ✅ 保存成功：stock_daily_cctvnews_20230825.csv（15条记录）
#
# === 正在处理 238/731：20230826 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c7733261）
# ✅ 保存成功：stock_daily_cctvnews_20230826.csv（8条记录）
#
# === 正在处理 239/731：20230827 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d31f63ae）
# ✅ 保存成功：stock_daily_cctvnews_20230827.csv（10条记录）
#
# === 正在处理 240/731：20230828 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8876b8b6）
# ✅ 保存成功：stock_daily_cctvnews_20230828.csv（16条记录）
#
# === 正在处理 241/731：20230829 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d6649d06）
# ✅ 保存成功：stock_daily_cctvnews_20230829.csv（17条记录）
#
# === 正在处理 242/731：20230830 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_654aab7b）
# ✅ 保存成功：stock_daily_cctvnews_20230830.csv（13条记录）
#
# === 正在处理 243/731：20230831 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7f5a1ebc）
# ✅ 保存成功：stock_daily_cctvnews_20230831.csv（14条记录）
#
# === 正在处理 244/731：20230901 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0b8b9983）
# ✅ 保存成功：stock_daily_cctvnews_20230901.csv（19条记录）
#
# === 正在处理 245/731：20230902 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f5224012）
# ✅ 保存成功：stock_daily_cctvnews_20230902.csv（14条记录）
#
# === 正在处理 246/731：20230903 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_71bfe920）
# ✅ 保存成功：stock_daily_cctvnews_20230903.csv（13条记录）
#
# === 正在处理 247/731：20230904 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b2df18cd）
# ✅ 保存成功：stock_daily_cctvnews_20230904.csv（14条记录）
#
# === 正在处理 248/731：20230905 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d26d40b1）
# ✅ 保存成功：stock_daily_cctvnews_20230905.csv（15条记录）
#
# === 正在处理 249/731：20230906 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_29107ae9）
# ✅ 保存成功：stock_daily_cctvnews_20230906.csv（15条记录）
#
# === 正在处理 250/731：20230907 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6845d5c3）
# ✅ 保存成功：stock_daily_cctvnews_20230907.csv（13条记录）
#
# === 正在处理 251/731：20230908 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9e850c18）
# ✅ 保存成功：stock_daily_cctvnews_20230908.csv（17条记录）
#
# === 正在处理 252/731：20230909 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_302dd84c）
# ✅ 保存成功：stock_daily_cctvnews_20230909.csv（16条记录）
#
# === 正在处理 253/731：20230910 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1d4e8a9a）
# ✅ 保存成功：stock_daily_cctvnews_20230910.csv（16条记录）
#
# === 正在处理 254/731：20230911 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_18f796bd）
# ✅ 保存成功：stock_daily_cctvnews_20230911.csv（20条记录）
#
# === 正在处理 255/731：20230912 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1fc20bf2）
# ✅ 保存成功：stock_daily_cctvnews_20230912.csv（16条记录）
#
# === 正在处理 256/731：20230913 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1125f812）
# ✅ 保存成功：stock_daily_cctvnews_20230913.csv（15条记录）
#
# === 正在处理 257/731：20230914 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_71443ded）
# ✅ 保存成功：stock_daily_cctvnews_20230914.csv（18条记录）
#
# === 正在处理 258/731：20230915 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4c2f2192）
# ✅ 保存成功：stock_daily_cctvnews_20230915.csv（18条记录）
#
# === 正在处理 259/731：20230916 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6350f41c）
# ✅ 保存成功：stock_daily_cctvnews_20230916.csv（18条记录）
#
# === 正在处理 260/731：20230917 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fc87d99d）
# ✅ 保存成功：stock_daily_cctvnews_20230917.csv（14条记录）
#
# === 正在处理 261/731：20230918 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bc9f0bcc）
# ✅ 保存成功：stock_daily_cctvnews_20230918.csv（14条记录）
#
# === 正在处理 262/731：20230919 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_07819d03）
# ✅ 保存成功：stock_daily_cctvnews_20230919.csv（14条记录）
#
# === 正在处理 263/731：20230920 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4be351e5）
# ✅ 保存成功：stock_daily_cctvnews_20230920.csv（14条记录）
#
# === 正在处理 264/731：20230921 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6e60f3a2）
# ✅ 保存成功：stock_daily_cctvnews_20230921.csv（14条记录）
#
# === 正在处理 265/731：20230922 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c7db514f）
# ✅ 保存成功：stock_daily_cctvnews_20230922.csv（17条记录）
#
# === 正在处理 266/731：20230923 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b775b149）
# ✅ 保存成功：stock_daily_cctvnews_20230923.csv（13条记录）
#
# === 正在处理 267/731：20230924 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a25f41b4）
# ✅ 保存成功：stock_daily_cctvnews_20230924.csv（9条记录）
#
# === 正在处理 268/731：20230925 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_14ec43a5）
# ✅ 保存成功：stock_daily_cctvnews_20230925.csv（15条记录）
#
# === 正在处理 269/731：20230926 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_701014bc）
# ✅ 保存成功：stock_daily_cctvnews_20230926.csv（12条记录）
#
# === 正在处理 270/731：20230927 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6eb602dc）
# ✅ 保存成功：stock_daily_cctvnews_20230927.csv（16条记录）
#
# === 正在处理 271/731：20230928 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8d8b9d76）
# ✅ 保存成功：stock_daily_cctvnews_20230928.csv（17条记录）
#
# === 正在处理 272/731：20230929 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_495c53e3）
# ✅ 保存成功：stock_daily_cctvnews_20230929.csv（13条记录）
#
# === 正在处理 273/731：20230930 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_71913fd2）
# ✅ 保存成功：stock_daily_cctvnews_20230930.csv（12条记录）
#
# === 正在处理 274/731：20231001 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_49c1aa41）
# ✅ 保存成功：stock_daily_cctvnews_20231001.csv（13条记录）
#
# === 正在处理 275/731：20231002 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2ce32312）
# ✅ 保存成功：stock_daily_cctvnews_20231002.csv（14条记录）
#
# === 正在处理 276/731：20231003 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7e534ea7）
# ✅ 保存成功：stock_daily_cctvnews_20231003.csv（14条记录）
#
# === 正在处理 277/731：20231004 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a9f37b7c）
# ✅ 保存成功：stock_daily_cctvnews_20231004.csv（13条记录）
#
# === 正在处理 278/731：20231005 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a685b6a9）
# ✅ 保存成功：stock_daily_cctvnews_20231005.csv（15条记录）
#
# === 正在处理 279/731：20231006 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e1a0a1f1）
# ✅ 保存成功：stock_daily_cctvnews_20231006.csv（14条记录）
#
# === 正在处理 280/731：20231007 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a2433111）
# ✅ 保存成功：stock_daily_cctvnews_20231007.csv（14条记录）
#
# === 正在处理 281/731：20231008 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2bd947ef）
# ✅ 保存成功：stock_daily_cctvnews_20231008.csv（14条记录）
#
# === 正在处理 282/731：20231009 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9f3c0ba7）
# ✅ 保存成功：stock_daily_cctvnews_20231009.csv（14条记录）
#
# === 正在处理 283/731：20231010 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3c5e44ef）
# ✅ 保存成功：stock_daily_cctvnews_20231010.csv（13条记录）
#
# === 正在处理 284/731：20231011 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3f42b9d4）
# ✅ 保存成功：stock_daily_cctvnews_20231011.csv（17条记录）
#
# === 正在处理 285/731：20231012 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_71e00f8a）
# ✅ 保存成功：stock_daily_cctvnews_20231012.csv（13条记录）
#
# === 正在处理 286/731：20231013 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_366782f2）
# ✅ 保存成功：stock_daily_cctvnews_20231013.csv（14条记录）
#
# === 正在处理 287/731：20231014 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7be4c575）
# ✅ 保存成功：stock_daily_cctvnews_20231014.csv（12条记录）
#
# === 正在处理 288/731：20231015 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9fd2da8b）
# ✅ 保存成功：stock_daily_cctvnews_20231015.csv（12条记录）
#
# === 正在处理 289/731：20231016 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_31502664）
# ✅ 保存成功：stock_daily_cctvnews_20231016.csv（19条记录）
#
# === 正在处理 290/731：20231017 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_818d02d4）
# ✅ 保存成功：stock_daily_cctvnews_20231017.csv（22条记录）
#
# === 正在处理 291/731：20231018 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e975a78d）
# ✅ 保存成功：stock_daily_cctvnews_20231018.csv（21条记录）
#
# === 正在处理 292/731：20231019 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_539ee24d）
# ✅ 保存成功：stock_daily_cctvnews_20231019.csv（29条记录）
#
# === 正在处理 293/731：20231020 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ba5f756d）
# ✅ 保存成功：stock_daily_cctvnews_20231020.csv（25条记录）
#
# === 正在处理 294/731：20231021 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5672774f）
# ✅ 保存成功：stock_daily_cctvnews_20231021.csv（12条记录）
#
# === 正在处理 295/731：20231022 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9c810146）
# ✅ 保存成功：stock_daily_cctvnews_20231022.csv（16条记录）
#
# === 正在处理 296/731：20231023 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a3eaf4ea）
# ✅ 保存成功：stock_daily_cctvnews_20231023.csv（13条记录）
#
# === 正在处理 297/731：20231024 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f450ea05）
# ✅ 保存成功：stock_daily_cctvnews_20231024.csv（15条记录）
#
# === 正在处理 298/731：20231025 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_937451a0）
# ✅ 保存成功：stock_daily_cctvnews_20231025.csv（21条记录）
#
# === 正在处理 299/731：20231026 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_28da6853）
# ✅ 保存成功：stock_daily_cctvnews_20231026.csv（17条记录）
#
# === 正在处理 300/731：20231027 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ef8079ea）
# ✅ 保存成功：stock_daily_cctvnews_20231027.csv（14条记录）
#
# === 正在处理 301/731：20231028 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4347b865）
# ✅ 保存成功：stock_daily_cctvnews_20231028.csv（11条记录）
#
# === 正在处理 302/731：20231029 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f65b7226）
# ✅ 保存成功：stock_daily_cctvnews_20231029.csv（15条记录）
#
# === 正在处理 303/731：20231030 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0ea53cc5）
# ✅ 保存成功：stock_daily_cctvnews_20231030.csv（13条记录）
#
# === 正在处理 304/731：20231031 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_60365c2e）
# ✅ 保存成功：stock_daily_cctvnews_20231031.csv（14条记录）
#
# === 正在处理 305/731：20231101 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f825e296）
# ✅ 保存成功：stock_daily_cctvnews_20231101.csv（17条记录）
#
# === 正在处理 306/731：20231102 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_43516c2d）
# ✅ 保存成功：stock_daily_cctvnews_20231102.csv（14条记录）
#
# === 正在处理 307/731：20231103 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7cdfc2cf）
# ✅ 保存成功：stock_daily_cctvnews_20231103.csv（17条记录）
#
# === 正在处理 308/731：20231104 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_10c6f395）
# ✅ 保存成功：stock_daily_cctvnews_20231104.csv（14条记录）
#
# === 正在处理 309/731：20231105 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_394a3736）
# ✅ 保存成功：stock_daily_cctvnews_20231105.csv（16条记录）
#
# === 正在处理 310/731：20231106 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_416cf66f）
# ✅ 保存成功：stock_daily_cctvnews_20231106.csv（17条记录）
#
# === 正在处理 311/731：20231107 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a875787a）
# ✅ 保存成功：stock_daily_cctvnews_20231107.csv（14条记录）
#
# === 正在处理 312/731：20231108 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ac1b0194）
# ✅ 保存成功：stock_daily_cctvnews_20231108.csv（14条记录）
#
# === 正在处理 313/731：20231109 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bd5086c8）
# ✅ 保存成功：stock_daily_cctvnews_20231109.csv（13条记录）
#
# === 正在处理 314/731：20231110 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6ba79249）
# ✅ 保存成功：stock_daily_cctvnews_20231110.csv（9条记录）
#
# === 正在处理 315/731：20231111 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0567b8d6）
# ✅ 保存成功：stock_daily_cctvnews_20231111.csv（12条记录）
#
# === 正在处理 316/731：20231112 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_18c9d38e）
# ✅ 保存成功：stock_daily_cctvnews_20231112.csv（11条记录）
#
# === 正在处理 317/731：20231113 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5d486dba）
# ✅ 保存成功：stock_daily_cctvnews_20231113.csv（12条记录）
#
# === 正在处理 318/731：20231114 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_71814aa0）
# ✅ 保存成功：stock_daily_cctvnews_20231114.csv（15条记录）
#
# === 正在处理 319/731：20231115 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e9acb94c）
# ✅ 保存成功：stock_daily_cctvnews_20231115.csv（17条记录）
#
# === 正在处理 320/731：20231116 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2d7228e7）
# ✅ 保存成功：stock_daily_cctvnews_20231116.csv（13条记录）
#
# === 正在处理 321/731：20231117 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_dc0147c8）
# ✅ 保存成功：stock_daily_cctvnews_20231117.csv（18条记录）
#
# === 正在处理 322/731：20231118 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c331a925）
# ✅ 保存成功：stock_daily_cctvnews_20231118.csv（12条记录）
#
# === 正在处理 323/731：20231119 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1975e25e）
# ✅ 保存成功：stock_daily_cctvnews_20231119.csv（11条记录）
#
# === 正在处理 324/731：20231120 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_308d890a）
# ✅ 保存成功：stock_daily_cctvnews_20231120.csv（13条记录）
#
# === 正在处理 325/731：20231121 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_49175cd0）
# ✅ 保存成功：stock_daily_cctvnews_20231121.csv（15条记录）
#
# === 正在处理 326/731：20231122 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_26925768）
# ✅ 保存成功：stock_daily_cctvnews_20231122.csv（15条记录）
#
# === 正在处理 327/731：20231123 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0d510420）
# ✅ 保存成功：stock_daily_cctvnews_20231123.csv（18条记录）
#
# === 正在处理 328/731：20231124 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b00362d1）
# ✅ 保存成功：stock_daily_cctvnews_20231124.csv（19条记录）
#
# === 正在处理 329/731：20231125 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_690fad5e）
# ✅ 保存成功：stock_daily_cctvnews_20231125.csv（11条记录）
#
# === 正在处理 330/731：20231126 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8e8e2ebe）
# ✅ 保存成功：stock_daily_cctvnews_20231126.csv（13条记录）
#
# === 正在处理 331/731：20231127 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1bc633f4）
# ✅ 保存成功：stock_daily_cctvnews_20231127.csv（16条记录）
#
# === 正在处理 332/731：20231128 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e28c230d）
# ✅ 保存成功：stock_daily_cctvnews_20231128.csv（13条记录）
#
# === 正在处理 333/731：20231129 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0e7658d5）
# ✅ 保存成功：stock_daily_cctvnews_20231129.csv（11条记录）
#
# === 正在处理 334/731：20231130 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_51730898）
# ✅ 保存成功：stock_daily_cctvnews_20231130.csv（11条记录）
#
# === 正在处理 335/731：20231201 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0fb3b8ac）
# ✅ 保存成功：stock_daily_cctvnews_20231201.csv（11条记录）
#
# === 正在处理 336/731：20231202 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_abadb0d9）
# ✅ 保存成功：stock_daily_cctvnews_20231202.csv（16条记录）
#
# === 正在处理 337/731：20231203 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_049476bc）
# ✅ 保存成功：stock_daily_cctvnews_20231203.csv（11条记录）
#
# === 正在处理 338/731：20231204 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b3bf6447）
# ✅ 保存成功：stock_daily_cctvnews_20231204.csv（13条记录）
#
# === 正在处理 339/731：20231205 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_07cab4e0）
# ✅ 保存成功：stock_daily_cctvnews_20231205.csv（15条记录）
#
# === 正在处理 340/731：20231206 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_df082425）
# ✅ 保存成功：stock_daily_cctvnews_20231206.csv（15条记录）
#
# === 正在处理 341/731：20231207 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6953929e）
# ✅ 保存成功：stock_daily_cctvnews_20231207.csv（15条记录）
#
# === 正在处理 342/731：20231208 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_020a406a）
# ✅ 保存成功：stock_daily_cctvnews_20231208.csv（12条记录）
#
# === 正在处理 343/731：20231209 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_77d9501d）
# ✅ 保存成功：stock_daily_cctvnews_20231209.csv（17条记录）
#
# === 正在处理 344/731：20231210 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_df6724b4）
# ✅ 保存成功：stock_daily_cctvnews_20231210.csv（15条记录）
#
# === 正在处理 345/731：20231211 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_df045060）
# ✅ 保存成功：stock_daily_cctvnews_20231211.csv（12条记录）
#
# === 正在处理 346/731：20231212 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_53791295）
# ✅ 保存成功：stock_daily_cctvnews_20231212.csv（12条记录）
#
# === 正在处理 347/731：20231213 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5340824a）
# ✅ 保存成功：stock_daily_cctvnews_20231213.csv（19条记录）
#
# === 正在处理 348/731：20231214 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2dd06d66）
# ✅ 保存成功：stock_daily_cctvnews_20231214.csv（15条记录）
#
# === 正在处理 349/731：20231215 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e61aa98a）
# ✅ 保存成功：stock_daily_cctvnews_20231215.csv（15条记录）
#
# === 正在处理 350/731：20231216 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ac8a7ccb）
# ✅ 保存成功：stock_daily_cctvnews_20231216.csv（11条记录）
#
# === 正在处理 351/731：20231217 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_801ac8bb）
# ✅ 保存成功：stock_daily_cctvnews_20231217.csv（12条记录）
#
# === 正在处理 352/731：20231218 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_05d26a0a）
# ✅ 保存成功：stock_daily_cctvnews_20231218.csv（15条记录）
#
# === 正在处理 353/731：20231219 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_863019d4）
# ✅ 保存成功：stock_daily_cctvnews_20231219.csv（15条记录）
#
# === 正在处理 354/731：20231220 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3e48ba30）
# ✅ 保存成功：stock_daily_cctvnews_20231220.csv（13条记录）
#
# === 正在处理 355/731：20231221 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e8ed0139）
# ✅ 保存成功：stock_daily_cctvnews_20231221.csv（13条记录）
#
# === 正在处理 356/731：20231222 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_57af0267）
# ✅ 保存成功：stock_daily_cctvnews_20231222.csv（9条记录）
#
# === 正在处理 357/731：20231223 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c94f700f）
# ✅ 保存成功：stock_daily_cctvnews_20231223.csv（13条记录）
#
# === 正在处理 358/731：20231224 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_38a6c74c）
# ✅ 保存成功：stock_daily_cctvnews_20231224.csv（15条记录）
#
# === 正在处理 359/731：20231225 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a9a97032）
# ✅ 保存成功：stock_daily_cctvnews_20231225.csv（13条记录）
#
# === 正在处理 360/731：20231226 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2289c05f）
# ✅ 保存成功：stock_daily_cctvnews_20231226.csv（10条记录）
#
# === 正在处理 361/731：20231227 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_da6169fe）
# ✅ 保存成功：stock_daily_cctvnews_20231227.csv（16条记录）
#
# === 正在处理 362/731：20231228 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5f3e7089）
# ✅ 保存成功：stock_daily_cctvnews_20231228.csv（13条记录）
#
# === 正在处理 363/731：20231229 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d678671c）
# ✅ 保存成功：stock_daily_cctvnews_20231229.csv（14条记录）
#
# === 正在处理 364/731：20231230 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_59076436）
# ✅ 保存成功：stock_daily_cctvnews_20231230.csv（11条记录）
#
# === 正在处理 365/731：20231231 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6cb5026c）
# ✅ 保存成功：stock_daily_cctvnews_20231231.csv（10条记录）
#
# === 正在处理 366/731：20240101 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0d22bff2）
# ✅ 保存成功：stock_daily_cctvnews_20240101.csv（14条记录）
#
# === 正在处理 367/731：20240102 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e409ad7e）
# ✅ 保存成功：stock_daily_cctvnews_20240102.csv（12条记录）
#
# === 正在处理 368/731：20240103 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_143dec0c）
# ✅ 保存成功：stock_daily_cctvnews_20240103.csv（13条记录）
#
# === 正在处理 369/731：20240104 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8fe73702）
# ✅ 保存成功：stock_daily_cctvnews_20240104.csv（12条记录）
#
# === 正在处理 370/731：20240105 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2315374b）
# ✅ 保存成功：stock_daily_cctvnews_20240105.csv（14条记录）
#
# === 正在处理 371/731：20240106 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_58a1f635）
# ✅ 保存成功：stock_daily_cctvnews_20240106.csv（14条记录）
#
# === 正在处理 372/731：20240107 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9c994c57）
# ✅ 保存成功：stock_daily_cctvnews_20240107.csv（14条记录）
#
# === 正在处理 373/731：20240108 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3f415b26）
# ✅ 保存成功：stock_daily_cctvnews_20240108.csv（11条记录）
#
# === 正在处理 374/731：20240109 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_799f00dd）
# ✅ 保存成功：stock_daily_cctvnews_20240109.csv（17条记录）
#
# === 正在处理 375/731：20240110 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e2e6da82）
# ✅ 保存成功：stock_daily_cctvnews_20240110.csv（16条记录）
#
# === 正在处理 376/731：20240111 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_55c2009a）
# ✅ 保存成功：stock_daily_cctvnews_20240111.csv（15条记录）
#
# === 正在处理 377/731：20240112 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d805b92a）
# ✅ 保存成功：stock_daily_cctvnews_20240112.csv（17条记录）
#
# === 正在处理 378/731：20240113 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d5a38a47）
# ✅ 保存成功：stock_daily_cctvnews_20240113.csv（14条记录）
#
# === 正在处理 379/731：20240114 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e0a417b2）
# ✅ 保存成功：stock_daily_cctvnews_20240114.csv（14条记录）
#
# === 正在处理 380/731：20240115 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_88d3e5ab）
# ✅ 保存成功：stock_daily_cctvnews_20240115.csv（16条记录）
#
# === 正在处理 381/731：20240116 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ffb6c3ea）
# ✅ 保存成功：stock_daily_cctvnews_20240116.csv（15条记录）
#
# === 正在处理 382/731：20240117 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f7fa5384）
# ✅ 保存成功：stock_daily_cctvnews_20240117.csv（16条记录）
#
# === 正在处理 383/731：20240118 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_666d7e36）
# ✅ 保存成功：stock_daily_cctvnews_20240118.csv（18条记录）
#
# === 正在处理 384/731：20240119 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c2fd4a16）
# ✅ 保存成功：stock_daily_cctvnews_20240119.csv（16条记录）
#
# === 正在处理 385/731：20240120 ===
# ...
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4121fbb9）
# ✅ 保存成功：stock_daily_cctvnews_20240826.csv（13条记录）
#
# === 正在处理 605/731：20240827 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bdba8f53）
# ✅ 保存成功：stock_daily_cctvnews_20240827.csv（12条记录）
#
# === 正在处理 606/731：20240828 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6207e1eb）
# ✅ 保存成功：stock_daily_cctvnews_20240828.csv（16条记录）
#
# === 正在处理 607/731：20240829 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_123de935）
# ✅ 保存成功：stock_daily_cctvnews_20240829.csv（16条记录）
#
# === 正在处理 608/731：20240830 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_59af7272）
# ✅ 保存成功：stock_daily_cctvnews_20240830.csv（14条记录）
#
# === 正在处理 609/731：20240831 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_70eff074）
# ✅ 保存成功：stock_daily_cctvnews_20240831.csv（13条记录）
#
# === 正在处理 610/731：20240901 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3e69dc56）
# ✅ 保存成功：stock_daily_cctvnews_20240901.csv（13条记录）
#
# === 正在处理 611/731：20240902 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_85b222a6）
# ✅ 保存成功：stock_daily_cctvnews_20240902.csv（20条记录）
#
# === 正在处理 612/731：20240903 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a1046006）
# ✅ 保存成功：stock_daily_cctvnews_20240903.csv（29条记录）
#
# === 正在处理 613/731：20240904 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d424b389）
# ✅ 保存成功：stock_daily_cctvnews_20240904.csv（34条记录）
#
# === 正在处理 614/731：20240905 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2146f7b8）
# ✅ 保存成功：stock_daily_cctvnews_20240905.csv（24条记录）
#
# === 正在处理 615/731：20240906 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4728a78d）
# ✅ 保存成功：stock_daily_cctvnews_20240906.csv（32条记录）
#
# === 正在处理 616/731：20240907 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e1dd833b）
# ✅ 保存成功：stock_daily_cctvnews_20240907.csv（21条记录）
#
# === 正在处理 617/731：20240908 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e57f6d86）
# ✅ 保存成功：stock_daily_cctvnews_20240908.csv（15条记录）
#
# === 正在处理 618/731：20240909 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_993f0bb4）
# ✅ 保存成功：stock_daily_cctvnews_20240909.csv（16条记录）
#
# === 正在处理 619/731：20240910 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_590da1b7）
# ✅ 保存成功：stock_daily_cctvnews_20240910.csv（13条记录）
#
# === 正在处理 620/731：20240911 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_87f3c280）
# ✅ 保存成功：stock_daily_cctvnews_20240911.csv（18条记录）
#
# === 正在处理 621/731：20240912 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d76fe1ff）
# ✅ 保存成功：stock_daily_cctvnews_20240912.csv（11条记录）
#
# === 正在处理 622/731：20240913 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_78cd76c2）
# ✅ 保存成功：stock_daily_cctvnews_20240913.csv（18条记录）
#
# === 正在处理 623/731：20240914 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5b56335e）
# ✅ 保存成功：stock_daily_cctvnews_20240914.csv（18条记录）
#
# === 正在处理 624/731：20240915 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8b030e78）
# ✅ 保存成功：stock_daily_cctvnews_20240915.csv（14条记录）
#
# === 正在处理 625/731：20240916 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a72358ec）
# ✅ 保存成功：stock_daily_cctvnews_20240916.csv（14条记录）
#
# === 正在处理 626/731：20240917 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e12039ff）
# ✅ 保存成功：stock_daily_cctvnews_20240917.csv（14条记录）
#
# === 正在处理 627/731：20240918 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c50c3cd2）
# ✅ 保存成功：stock_daily_cctvnews_20240918.csv（13条记录）
#
# === 正在处理 628/731：20240919 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cc7cbd7c）
# ✅ 保存成功：stock_daily_cctvnews_20240919.csv（16条记录）
#
# === 正在处理 629/731：20240920 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_eb3ec466）
# ✅ 保存成功：stock_daily_cctvnews_20240920.csv（14条记录）
#
# === 正在处理 630/731：20240921 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_308c2544）
# ✅ 保存成功：stock_daily_cctvnews_20240921.csv（11条记录）
#
# === 正在处理 631/731：20240922 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6b56d70a）
# ✅ 保存成功：stock_daily_cctvnews_20240922.csv（13条记录）
#
# === 正在处理 632/731：20240923 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f11d2381）
# ✅ 保存成功：stock_daily_cctvnews_20240923.csv（14条记录）
#
# === 正在处理 633/731：20240924 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_74d15bb9）
# ✅ 保存成功：stock_daily_cctvnews_20240924.csv（12条记录）
#
# === 正在处理 634/731：20240925 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a5d4ecc5）
# ✅ 保存成功：stock_daily_cctvnews_20240925.csv（14条记录）
#
# === 正在处理 635/731：20240926 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5af689f4）
# ✅ 保存成功：stock_daily_cctvnews_20240926.csv（14条记录）
#
# === 正在处理 636/731：20240927 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a4f80ba2）
# ✅ 保存成功：stock_daily_cctvnews_20240927.csv（15条记录）
#
# === 正在处理 637/731：20240928 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b93faf44）
# ✅ 保存成功：stock_daily_cctvnews_20240928.csv（14条记录）
#
# === 正在处理 638/731：20240929 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b81e6520）
# ✅ 保存成功：stock_daily_cctvnews_20240929.csv（14条记录）
#
# === 正在处理 639/731：20240930 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e1c5ecd2）
# ✅ 保存成功：stock_daily_cctvnews_20240930.csv（15条记录）
#
# === 正在处理 640/731：20241001 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ae98da11）
# ✅ 保存成功：stock_daily_cctvnews_20241001.csv（12条记录）
#
# === 正在处理 641/731：20241002 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3ed400b1）
# ✅ 保存成功：stock_daily_cctvnews_20241002.csv（12条记录）
#
# === 正在处理 642/731：20241003 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bfcfaf8d）
# ✅ 保存成功：stock_daily_cctvnews_20241003.csv（11条记录）
#
# === 正在处理 643/731：20241004 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a01d2729）
# ✅ 保存成功：stock_daily_cctvnews_20241004.csv（10条记录）
#
# === 正在处理 644/731：20241005 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1569ed34）
# ✅ 保存成功：stock_daily_cctvnews_20241005.csv（13条记录）
#
# === 正在处理 645/731：20241006 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b3cb4be0）
# ✅ 保存成功：stock_daily_cctvnews_20241006.csv（12条记录）
#
# === 正在处理 646/731：20241007 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_386231c0）
# ✅ 保存成功：stock_daily_cctvnews_20241007.csv（10条记录）
#
# === 正在处理 647/731：20241008 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fc00f211）
# ✅ 保存成功：stock_daily_cctvnews_20241008.csv（14条记录）
#
# === 正在处理 648/731：20241009 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2d2c92f5）
# ✅ 保存成功：stock_daily_cctvnews_20241009.csv（15条记录）
#
# === 正在处理 649/731：20241010 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_30724570）
# ✅ 保存成功：stock_daily_cctvnews_20241010.csv（16条记录）
#
# === 正在处理 650/731：20241011 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bf442a54）
# ✅ 保存成功：stock_daily_cctvnews_20241011.csv（18条记录）
#
# === 正在处理 651/731：20241012 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ac1d788e）
# ✅ 保存成功：stock_daily_cctvnews_20241012.csv（17条记录）
#
# === 正在处理 652/731：20241013 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_852a4a66）
# ✅ 保存成功：stock_daily_cctvnews_20241013.csv（20条记录）
#
# === 正在处理 653/731：20241014 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c69bcce3）
# ✅ 保存成功：stock_daily_cctvnews_20241014.csv（17条记录）
#
# === 正在处理 654/731：20241015 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e170f077）
# ✅ 保存成功：stock_daily_cctvnews_20241015.csv（17条记录）
#
# === 正在处理 655/731：20241016 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7083e9b1）
# ✅ 保存成功：stock_daily_cctvnews_20241016.csv（14条记录）
#
# === 正在处理 656/731：20241017 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_75c68840）
# ✅ 保存成功：stock_daily_cctvnews_20241017.csv（16条记录）
#
# === 正在处理 657/731：20241018 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_165e98a4）
# ✅ 保存成功：stock_daily_cctvnews_20241018.csv（14条记录）
#
# === 正在处理 658/731：20241019 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3ab639ae）
# ✅ 保存成功：stock_daily_cctvnews_20241019.csv（13条记录）
#
# === 正在处理 659/731：20241020 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_35183e7c）
# ✅ 保存成功：stock_daily_cctvnews_20241020.csv（14条记录）
#
# === 正在处理 660/731：20241021 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_27cd681d）
# ✅ 保存成功：stock_daily_cctvnews_20241021.csv（12条记录）
#
# === 正在处理 661/731：20241022 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_647a9824）
# ✅ 保存成功：stock_daily_cctvnews_20241022.csv（14条记录）
#
# === 正在处理 662/731：20241023 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c48e1fae）
# ✅ 保存成功：stock_daily_cctvnews_20241023.csv（16条记录）
#
# === 正在处理 663/731：20241024 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fda64a2f）
# ✅ 保存成功：stock_daily_cctvnews_20241024.csv（13条记录）
#
# === 正在处理 664/731：20241025 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b1c648a3）
# ✅ 保存成功：stock_daily_cctvnews_20241025.csv（17条记录）
#
# === 正在处理 665/731：20241026 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2fef318f）
# ✅ 保存成功：stock_daily_cctvnews_20241026.csv（12条记录）
#
# === 正在处理 666/731：20241027 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1bc361da）
# ✅ 保存成功：stock_daily_cctvnews_20241027.csv（13条记录）
#
# === 正在处理 667/731：20241028 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6a2006dd）
# ✅ 保存成功：stock_daily_cctvnews_20241028.csv（14条记录）
#
# === 正在处理 668/731：20241029 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bd28fa7e）
# ✅ 保存成功：stock_daily_cctvnews_20241029.csv（18条记录）
#
# === 正在处理 669/731：20241030 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f483b0cb）
# ✅ 保存成功：stock_daily_cctvnews_20241030.csv（12条记录）
#
# === 正在处理 670/731：20241031 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_07b27d37）
# ✅ 保存成功：stock_daily_cctvnews_20241031.csv（16条记录）
#
# === 正在处理 671/731：20241101 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f3ef3cc7）
# ✅ 保存成功：stock_daily_cctvnews_20241101.csv（14条记录）
#
# === 正在处理 672/731：20241102 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_46326b92）
# ✅ 保存成功：stock_daily_cctvnews_20241102.csv（12条记录）
#
# === 正在处理 673/731：20241103 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c27d1558）
# ✅ 保存成功：stock_daily_cctvnews_20241103.csv（12条记录）
#
# === 正在处理 674/731：20241104 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_34a9e5e1）
# ✅ 保存成功：stock_daily_cctvnews_20241104.csv（16条记录）
#
# === 正在处理 675/731：20241105 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5ffe8125）
# ✅ 保存成功：stock_daily_cctvnews_20241105.csv（17条记录）
#
# === 正在处理 676/731：20241106 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_59c5110a）
# ✅ 保存成功：stock_daily_cctvnews_20241106.csv（16条记录）
#
# === 正在处理 677/731：20241107 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_68f52b5d）
# ✅ 保存成功：stock_daily_cctvnews_20241107.csv（17条记录）
#
# === 正在处理 678/731：20241108 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_671901e0）
# ✅ 保存成功：stock_daily_cctvnews_20241108.csv（17条记录）
#
# === 正在处理 679/731：20241109 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_573c7ac6）
# ✅ 保存成功：stock_daily_cctvnews_20241109.csv（14条记录）
#
# === 正在处理 680/731：20241110 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e3942c00）
# ✅ 保存成功：stock_daily_cctvnews_20241110.csv（14条记录）
#
# === 正在处理 681/731：20241111 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_029d448b）
# ✅ 保存成功：stock_daily_cctvnews_20241111.csv（15条记录）
#
# === 正在处理 682/731：20241112 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_050e4cbf）
# ✅ 保存成功：stock_daily_cctvnews_20241112.csv（16条记录）
#
# === 正在处理 683/731：20241113 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_814b525a）
# ✅ 保存成功：stock_daily_cctvnews_20241113.csv（15条记录）
#
# === 正在处理 684/731：20241114 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_45f1b928）
# ✅ 保存成功：stock_daily_cctvnews_20241114.csv（12条记录）
#
# === 正在处理 685/731：20241115 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b2c29106）
# ✅ 保存成功：stock_daily_cctvnews_20241115.csv（17条记录）
#
# === 正在处理 686/731：20241116 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8f8ec1c6）
# ✅ 保存成功：stock_daily_cctvnews_20241116.csv（15条记录）
#
# === 正在处理 687/731：20241117 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ea11e99e）
# ✅ 保存成功：stock_daily_cctvnews_20241117.csv（12条记录）
#
# === 正在处理 688/731：20241118 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4c59324d）
# ✅ 保存成功：stock_daily_cctvnews_20241118.csv（14条记录）
#
# === 正在处理 689/731：20241119 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_853fc519）
# ✅ 保存成功：stock_daily_cctvnews_20241119.csv（16条记录）
#
# === 正在处理 690/731：20241120 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e96d76b4）
# ✅ 保存成功：stock_daily_cctvnews_20241120.csv（17条记录）
#
# === 正在处理 691/731：20241121 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_62415ace）
# ✅ 保存成功：stock_daily_cctvnews_20241121.csv（10条记录）
#
# === 正在处理 692/731：20241122 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f1999f9c）
# ✅ 保存成功：stock_daily_cctvnews_20241122.csv（16条记录）
#
# === 正在处理 693/731：20241123 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3e9f8767）
# ✅ 保存成功：stock_daily_cctvnews_20241123.csv（9条记录）
#
# === 正在处理 694/731：20241124 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6a43f3cd）
# ✅ 保存成功：stock_daily_cctvnews_20241124.csv（13条记录）
#
# === 正在处理 695/731：20241125 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8d8a1db4）
# ✅ 保存成功：stock_daily_cctvnews_20241125.csv（14条记录）
#
# === 正在处理 696/731：20241126 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c020697c）
# ✅ 保存成功：stock_daily_cctvnews_20241126.csv（14条记录）
#
# === 正在处理 697/731：20241127 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_05533589）
# ✅ 保存成功：stock_daily_cctvnews_20241127.csv（13条记录）
#
# === 正在处理 698/731：20241128 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8ab20cad）
# ✅ 保存成功：stock_daily_cctvnews_20241128.csv（13条记录）
#
# === 正在处理 699/731：20241129 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_757627d0）
# ✅ 保存成功：stock_daily_cctvnews_20241129.csv（12条记录）
#
# === 正在处理 700/731：20241130 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8a84769b）
# ✅ 保存成功：stock_daily_cctvnews_20241130.csv（14条记录）
#
# === 正在处理 701/731：20241201 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ce763c67）
# ✅ 保存成功：stock_daily_cctvnews_20241201.csv（10条记录）
#
# === 正在处理 702/731：20241202 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_084098c0）
# ✅ 保存成功：stock_daily_cctvnews_20241202.csv（12条记录）
#
# === 正在处理 703/731：20241203 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_58429ceb）
# ✅ 保存成功：stock_daily_cctvnews_20241203.csv（20条记录）
#
# === 正在处理 704/731：20241204 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_01adaa44）
# ✅ 保存成功：stock_daily_cctvnews_20241204.csv（15条记录）
#
# === 正在处理 705/731：20241205 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_15ee902a）
# ✅ 保存成功：stock_daily_cctvnews_20241205.csv（16条记录）
#
# === 正在处理 706/731：20241206 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0bcdb31f）
# ✅ 保存成功：stock_daily_cctvnews_20241206.csv（13条记录）
#
# === 正在处理 707/731：20241207 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f8ff43dd）
# ✅ 保存成功：stock_daily_cctvnews_20241207.csv（13条记录）
#
# === 正在处理 708/731：20241208 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0d1fb0ad）
# ✅ 保存成功：stock_daily_cctvnews_20241208.csv（16条记录）
#
# === 正在处理 709/731：20241209 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_acdd6288）
# ✅ 保存成功：stock_daily_cctvnews_20241209.csv（13条记录）
#
# === 正在处理 710/731：20241210 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bdb6b1d2）
# ✅ 保存成功：stock_daily_cctvnews_20241210.csv（11条记录）
#
# === 正在处理 711/731：20241211 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_75cd734e）
# ✅ 保存成功：stock_daily_cctvnews_20241211.csv（15条记录）
#
# === 正在处理 712/731：20241212 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_be7a9b5b）
# ✅ 保存成功：stock_daily_cctvnews_20241212.csv（13条记录）
#
# === 正在处理 713/731：20241213 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6007e5b2）
# ✅ 保存成功：stock_daily_cctvnews_20241213.csv（14条记录）
#
# === 正在处理 714/731：20241214 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3e0bf3d9）
# ✅ 保存成功：stock_daily_cctvnews_20241214.csv（12条记录）
#
# === 正在处理 715/731：20241215 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0b9cbf0e）
# ✅ 保存成功：stock_daily_cctvnews_20241215.csv（13条记录）
#
# === 正在处理 716/731：20241216 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_09d92175）
# ✅ 保存成功：stock_daily_cctvnews_20241216.csv（13条记录）
#
# === 正在处理 717/731：20241217 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f733a14b）
# ✅ 保存成功：stock_daily_cctvnews_20241217.csv（14条记录）
#
# === 正在处理 718/731：20241218 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ae72730a）
# ✅ 保存成功：stock_daily_cctvnews_20241218.csv（17条记录）
#
# === 正在处理 719/731：20241219 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_677f0dd1）
# ✅ 保存成功：stock_daily_cctvnews_20241219.csv（18条记录）
#
# === 正在处理 720/731：20241220 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1a698dbe）
# ✅ 保存成功：stock_daily_cctvnews_20241220.csv（17条记录）
#
# === 正在处理 721/731：20241221 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_992c1b1d）
# ✅ 保存成功：stock_daily_cctvnews_20241221.csv（12条记录）
#
# === 正在处理 722/731：20241222 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fa576dc6）
# ✅ 保存成功：stock_daily_cctvnews_20241222.csv（12条记录）
#
# === 正在处理 723/731：20241223 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_adfcc141）
# ✅ 保存成功：stock_daily_cctvnews_20241223.csv（14条记录）
#
# === 正在处理 724/731：20241224 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_dc4cfbe4）
# ✅ 保存成功：stock_daily_cctvnews_20241224.csv（14条记录）
#
# === 正在处理 725/731：20241225 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f066a451）
# ✅ 保存成功：stock_daily_cctvnews_20241225.csv（15条记录）
#
# === 正在处理 726/731：20241226 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_789d4378）
# ✅ 保存成功：stock_daily_cctvnews_20241226.csv（15条记录）
#
# === 正在处理 727/731：20241227 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7b3e8c06）
# ✅ 保存成功：stock_daily_cctvnews_20241227.csv（13条记录）
#
# === 正在处理 728/731：20241228 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ed1ada1a）
# ✅ 保存成功：stock_daily_cctvnews_20241228.csv（13条记录）
#
# === 正在处理 729/731：20241229 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d1e06eea）
# ✅ 保存成功：stock_daily_cctvnews_20241229.csv（13条记录）
#
# === 正在处理 730/731：20241230 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a812c033）
# ✅ 保存成功：stock_daily_cctvnews_20241230.csv（14条记录）
#
# === 正在处理 731/731：20241231 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9fecc791）
# ✅ 保存成功：stock_daily_cctvnews_20241231.csv（17条记录）
#
# === 所有日期处理完成 ===

# %% [markdown]
# ## 将csv合并为一个parquet文件

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将 /d:/workspace/xiaoyao/redis/ 目录下的所有 stock_***.csv 文件合并为一个 parquet 文件
确保与现有 /d:/workspace/xiaoyao/data/stock_daily_price.parquet 保持字段、压缩方式一致
"""

import os
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path
import glob


def merge_stock_csv_to_parquet(csv_dir, output_parquet_file):
    """
    合并指定目录下的所有 stock_***.csv 文件到单个 parquet 文件
    
    Args:
        csv_dir: CSV 文件所在目录
        output_parquet_file: 输出的 parquet 文件路径
    """
    print(f"📁 开始处理目录: {csv_dir}")
    
    # 获取所有 stock_***.csv 文件
    csv_pattern = os.path.join(csv_dir, "stock_daily_cctvnews_*.csv")
    csv_files = glob.glob(csv_pattern)
    
    if not csv_files:
        print("❌ 未找到 stock_***.csv 文件")
        return False
    
    print(f"📊 找到 {len(csv_files)} 个 CSV 文件")
    
    # 按文件名排序（确保按日期顺序处理）
    csv_files.sort()
    
    # 读取并合并所有 CSV 文件
    all_dataframes = []
    total_records = 0
    
    for i, csv_file in enumerate(csv_files, 1):
        filename = os.path.basename(csv_file)
        print(f"正在处理 ({i}/{len(csv_files)}): {filename}")
        
        try:
            # 读取 CSV 文件
            df = pd.read_csv(csv_file)
            
            # 数据验证和清洗
            # 确保 date 列是 datetime 类型
            df['date'] = pd.to_datetime(df['date'])
            
            all_dataframes.append(df)
            total_records += len(df)
            print(f"  ✅ 成功读取 {len(df)} 条记录")
            
        except Exception as e:
            print(f"  ❌ 处理失败: {e}")
            continue
    
    if not all_dataframes:
        print("❌ 没有成功读取任何数据")
        return False
    
    print(f"\n📊 合并所有数据...")
    # 合并所有数据框
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    
    # 去重（按 date + stock_code）
    combined_df = combined_df.drop_duplicates(subset=['date', 'id'])
    
    # 按日期和股票代码排序
    combined_df = combined_df.sort_values(['date', 'id']).reset_index(drop=True)
    
    print(f"📈 总计 {len(combined_df)} 条记录（去重后）")
    
    # 确保输出目录存在
    output_dir = os.path.dirname(output_parquet_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")
    
    # 转换为 pyarrow Table
    table = pa.Table.from_pandas(combined_df)
    
    # 使用与目标文件相同的压缩方式 (snappy) 和格式写入 parquet
    try:
        pq.write_table(
            table, 
            output_parquet_file,
            compression='snappy',
            version='2.6',  # 使用较新的 parquet 版本
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024  # 64MB batch size for better performance
        )
        
        print(f"✅ 成功保存到: {output_parquet_file}")
        print(f"📊 文件大小: {os.path.getsize(output_parquet_file) / (1024*1024):.2f} MB")
        
        return True
        
    except Exception as e:
        print(f"❌ 保存 parquet 文件失败: {e}")
        return False


def main():
    """主函数"""
    # 设置路径
    csv_directory = "d:/workspace/xiaoyao/redis/"
    # 确保输出目录存在
    output_dir = os.path.join(csv_directory, 'parquet')
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")

    output_file = os.path.join(output_dir, 'stock_daily_cctvnews_to_merged.parquet')
    
    
    print("=" * 60)
    print("🚀 开始合并 stock_***.csv 文件到 parquet")
    print("=" * 60)
    
    # 执行合并
    success = merge_stock_csv_to_parquet(csv_directory, output_file)
    
    if success:
        print("\n🎉 合并完成！")
        
        # 验证结果
        try:
            print("\n📋 验证结果:")
            result_df = pd.read_parquet(output_file)
            print(f"   总行数: {len(result_df)}")
            print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
            print(f"   股票数量: {result_df['stock_code'].nunique()}")
            print(f"   列名: {list(result_df.columns)}")
            
        except Exception as e:
            print(f"⚠️  验证失败: {e}")
    
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 stock_***.csv 文件到 parquet
# ============================================================
# 📁 开始处理目录: d:/workspace/xiaoyao/redis/
# 📊 找到 731 个 CSV 文件
# 正在处理 (1/731): stock_daily_cctvnews_20230101.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (2/731): stock_daily_cctvnews_20230102.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (3/731): stock_daily_cctvnews_20230103.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (4/731): stock_daily_cctvnews_20230104.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (5/731): stock_daily_cctvnews_20230105.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (6/731): stock_daily_cctvnews_20230106.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (7/731): stock_daily_cctvnews_20230107.csv
#   ✅ 成功读取 12 条记录
# 正在处理 
csv
#   ✅ 成功读取 13 条记录
# 正在处理 (729/731): stock_daily_cctvnews_20241229.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (730/731): stock_daily_cctvnews_20241230.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (731/731): stock_daily_cctvnews_20241231.csv
#   ✅ 成功读取 17 条记录
#
# 📊 合并所有数据...
# 📈 总计 10421 条记录（去重后）
# ✅ 成功保存到: d:/workspace/xiaoyao/redis/parquet\stock_daily_cctvnews_to_merged.parquet
# 📊 文件大小: 9.34 MB
#
# 🎉 合并完成！
#
# 📋 验证结果:
#    总行数: 10421
#    日期范围: 2023-01-01 00:00:00 到 2024-12-31 00:00:00
# ⚠️  验证失败: 'stock_code'
# ============================================================

# %% [markdown]
# ## 将新生成的 stock_daily_auction_to_merged.parquet.parquet 与现有的 stock_daily_auction.parquet 合并

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将新生成的 stock_daily_marketcap_to_merged.parquet.parquet 与现有的 stock_daily_marketcap.parquet 合并
"""

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import os


def merge_parquet_files(existing_file, new_file, output_file):
    """
    合并两个 parquet 文件
    
    Args:
        existing_file: 现有的 parquet 文件路径
        new_file: 新的 parquet 文件路径  
        output_file: 输出的合并文件路径
    """
    print("📊 开始合并 parquet 文件...")
    
    try:
        # 读取现有数据
        print(f"📖 读取现有文件: {existing_file}")
        existing_df = pd.read_parquet(existing_file)
        print(f"   现有数据行数: {len(existing_df)}")
        
        # 读取新数据
        print(f"📖 读取新文件: {new_file}")
        new_df = pd.read_parquet(new_file)
        print(f"   新数据行数: {len(new_df)}")
        
        # 合并数据
        print("🔄 合并数据中...")
        combined_df = pd.concat([existing_df, new_df], ignore_index=True)
        
        # 去重（按 date + stock_code）
        print("🧹 去重处理...")
        combined_df = combined_df.drop_duplicates(subset=['date', 'id'])
        
        # 排序
        print("📅 按日期排序...")
        combined_df = combined_df.sort_values(['date', 'id']).reset_index(drop=True)
        
        print(f"📈 合并后总行数: {len(combined_df)}")
        
        # 确保输出目录存在
        output_dir = os.path.dirname(output_file)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)
        
        # 转换为 pyarrow Table
        table = pa.Table.from_pandas(combined_df)
        
        # 写入 parquet（使用与源文件相同的格式）
        print(f"💾 保存合并结果: {output_file}")
        pq.write_table(
            table,
            output_file,
            compression='snappy',
            version='2.6',
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024
        )
        
        print(f"✅ 合并完成！文件大小: {os.path.getsize(output_file) / (1024*1024):.2f} MB")
        
        # 验证结果
        print("\n📋 验证结果:")
        result_df = pd.read_parquet(output_file)
        print(f"   最终行数: {len(result_df)}")
        print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
        print(f"   新闻数量: {result_df['id'].nunique()}")
        
        return True
        
    except Exception as e:
        print(f"❌ 合并失败: {e}")
        return False


def main():
    """主函数"""
    # 设置文件路径

    existing_file = "d:/workspace/xiaoyao/data/stock_daily_cctvnews.parquet"
    new_file = "d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews_to_merged.parquet"
    output_file = "d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews.parquet"

    print("=" * 60)
    print("🚀 开始合并 parquet 文件")
    print("=" * 60)
    
    # 检查文件是否存在
    if not os.path.exists(existing_file):
        print(f"❌ 现有文件不存在: {existing_file}")
        return
    
    if not os.path.exists(new_file):
        print(f"❌ 新文件不存在: {new_file}")
        return
    
    # 执行合并
    success = merge_parquet_files(existing_file, new_file, output_file)
    
    if success:
        print("\n🎉 合并成功！")
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 parquet 文件
# ============================================================
# 📊 开始合并 parquet 文件...
# 📖 读取现有文件: d:/workspace/xiaoyao/data/stock_daily_cctvnews.parquet
#    现有数据行数: 4098
# 📖 读取新文件: d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews_to_merged.parquet
#    新数据行数: 10421
# 🔄 合并数据中...
# 🧹 去重处理...
# 📅 按日期排序...
# 📈 合并后总行数: 14519
# 💾 保存合并结果: d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews.parquet
# ✅ 合并完成！文件大小: 13.11 MB
#
# 📋 验证结果:
#    最终行数: 14519
#    日期范围: 2023-01-01 00:00:00 到 2025-10-23 00:00:00
#    新闻数量: 14519
#
# 🎉 合并成功！
# ============================================================

# %% [markdown]
# ## 删除已使用的csv

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
删除指定目录下的 stock_***.csv 文件
"""

import os
import glob
from pathlib import Path


def delete_stock_csv_files(target_directory, pattern="stock_*.csv"):
    #删除满足模式的所有文件
    files = glob.glob(os.path.join(target_directory, pattern))
    for file in files:
        try:
            os.remove(file)
            print(f"已删除：{file}")
        except Exception as e:
            print(f"删除 {file} 失败：{e}")

if __name__ == "__main__":
    delete_stock_csv_files(r'D:\workspace\xiaoyao\redis','stock_daily_cctvnews_*.csv')
    print("\n" + "=" * 60)
# Out:
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230101.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230102.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230103.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230104.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230105.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230106.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230107.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230108.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230109.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230110.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230111.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230112.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230113.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230114.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230115.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230116.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230117.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230118.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230119.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230120.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230121.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230122.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230123.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230124.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230125.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230126.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230127.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230128.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230129.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230130.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230131.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230201.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230202.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230203.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230204.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230205.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230206.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230207.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230208.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230209.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230210.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230211.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230212.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230213.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230214.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230215.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230216.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230217.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230218.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230219.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230220.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230221.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230222.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230223.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230224.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230225.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230226.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230227.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230228.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230301.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230302.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230303.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230304.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230305.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230306.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230307.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230308.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230309.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230310.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230311.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230312.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230313.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230314.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230315.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230316.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230317.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230318.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230319.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230320.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230321.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230322.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230323.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230324.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230325.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230326.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230327.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230328.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230329.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230330.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230331.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230401.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230402.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230403.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230404.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230405.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230406.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230407.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230408.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230409.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230410.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230411.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230412.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230413.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230414.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230415.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230416.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230417.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230418.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230419.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230420.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230421.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230422.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230423.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230424.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230425.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230426.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230427.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230428.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230429.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230430.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230501.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230502.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230503.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230504.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230505.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230506.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230507.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230508.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230509.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230510.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230511.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230512.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230513.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230514.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230515.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230516.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20230517.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20
csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240531.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240601.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240602.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240603.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240604.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240605.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240606.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240607.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240608.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240609.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240610.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240611.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240612.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240613.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240614.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240615.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240616.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240617.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240618.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240619.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240620.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240621.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240622.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240623.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240624.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240625.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240626.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240627.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240628.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240629.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240630.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240701.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240702.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240703.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240704.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240705.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240706.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240707.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240708.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240709.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240710.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240711.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240712.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240713.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240714.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240715.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240716.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240717.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240718.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240719.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240720.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240721.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240722.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240723.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240724.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240725.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240726.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240727.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240728.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240729.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240730.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240731.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240801.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240802.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240803.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240804.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240805.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240806.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240807.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240808.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240809.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240810.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240811.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240812.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240813.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240814.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240815.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240816.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240817.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240818.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240819.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240820.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240821.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240822.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240823.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240824.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240825.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240826.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240827.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240828.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240829.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240830.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240831.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240901.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240902.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240903.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240904.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240905.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240906.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240907.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240908.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240909.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240910.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240911.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240912.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240913.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240914.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240915.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240916.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240917.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240918.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240919.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240920.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240921.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240922.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240923.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240924.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240925.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240926.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240927.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240928.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240929.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20240930.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241001.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241002.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241003.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241004.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241005.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241006.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241007.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241008.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241009.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241010.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241011.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241012.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241013.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241014.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241015.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241016.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241017.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241018.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241019.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241020.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241021.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241022.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241023.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241024.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241025.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241026.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241027.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241028.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241029.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241030.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241031.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241101.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241102.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241103.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241104.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241105.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241106.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241107.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241108.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241109.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241110.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241111.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241112.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241113.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241114.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241115.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241116.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241117.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241118.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241119.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241120.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241121.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241122.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241123.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241124.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241125.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241126.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241127.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241128.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241129.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241130.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241201.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241202.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241203.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241204.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241205.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241206.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241207.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241208.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241209.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241210.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241211.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241212.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241213.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241214.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241215.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241216.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241217.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241218.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241219.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241220.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241221.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241222.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241223.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241224.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241225.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241226.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241227.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241228.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241229.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241230.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20241231.csv
#
# ============================================================

# %% [markdown]
# ## 将新的parquet文件移动到data目录覆盖原文件

# %%
# 将子目录下的某个parquet文件移动到指定目录
import os
import shutil

# 定义源目录和目标目录
source_dir = "D:\\workspace\\xiaoyao\\redis\\parquet"
target_dir = "D:\\workspace\\xiaoyao\\data"

# 确保目标目录存在
os.makedirs(target_dir, exist_ok=True)

# 定义要移动的文件
file_to_move = "stock_daily_cctvnews.parquet"

# 构建源文件的完整路径
source_file_path = os.path.join(source_dir, file_to_move)

# 构建目标文件的完整路径
target_file_path = os.path.join(target_dir, file_to_move)

# 检查源文件是否存在
if os.path.exists(source_file_path):
    # 移动文件
    shutil.move(source_file_path, target_file_path)
    print(f"Moved: {file_to_move} to {target_dir}")
else:
    print(f"File not found: {file_to_move}")

# 删除指定的parquet文件
file_to_delete = os.path.join(source_dir, 'stock_daily_cctvnews_to_merged.parquet')
if os.path.exists(file_to_delete):
    os.remove(file_to_delete)
    print(f"Deleted: {file_to_move} from {source_dir}")
else:
    print(f"File not found: {file_to_move} in {source_dir}")
# Out:
# Moved: stock_daily_cctvnews.parquet to D:\workspace\xiaoyao\data
# Deleted: stock_daily_cctvnews.parquet from D:\workspace\xiaoyao\redis\parquet
