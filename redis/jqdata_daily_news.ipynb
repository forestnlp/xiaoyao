# %% [markdown]
# ## 1.下载数据

# %%
import redis
import pickle
import time
import uuid
import pandas as pd
from io import StringIO
from typing import Any, Optional
from datetime import datetime, timedelta

class RemoteSender:
    def __init__(self, host='*', port=6379, password='*'):
        self.redis = redis.Redis(
            host=host, port=port, password=password,
            decode_responses=False
        )
        self.task_queue = 'function_calls'
        self.result_queue = 'function_results'
        self._test_connection()
        print(f"✅ 发送端pandas版本：{pd.__version__}")

    def _test_connection(self):
        try:
            self.redis.ping()
            print("✅ 发送端：Redis连接成功")
        except Exception as e:
            print(f"❌ 发送端：连接失败 - {e}")
            raise

    def call_remote_function(self, func_name: str, *args, **kwargs) -> Any:
        task_id = f"task_{uuid.uuid4().hex[:8]}"
        task = {
            'func_name': func_name,
            'args': args,
            'kwargs': kwargs,
            'task_id': task_id
        }
        self.redis.rpush(self.task_queue, pickle.dumps(task))
        print(f"📤 已调用远程函数：{func_name}（任务ID：{task_id}）")
        return self._get_result(task_id)

    def _get_result(self, task_id: str, timeout=300) -> Any:
        start_time = time.time()
        while time.time() - start_time < timeout:
            result_data = self.redis.blpop(self.result_queue, timeout=10)
            if not result_data:
                continue

            _, res_bytes = result_data
            result = pickle.loads(res_bytes)
            if result['task_id'] == task_id:
                if result['status'] == 'success':
                    return result['result']  # 返回CSV字符串
                else:
                    raise Exception(f"远程执行失败：{result['error']}")
            self.redis.rpush(self.result_queue, res_bytes)
        raise TimeoutError("任务超时")

    def save_to_csv(self, csv_str: Optional[str], filename: str) -> bool:
        """将CSV字符串保存为本地CSV文件（替代Parquet）"""
        if not csv_str:
            print("⚠️ 数据为空，不保存")
            return False
        try:
            # 从CSV字符串恢复DataFrame（兼容所有pandas版本）
            df = pd.read_csv(StringIO(csv_str))
            # 保存为CSV文件
            df.to_csv(filename, index=False)
            print(f"✅ 保存成功：{filename}（{len(df)}条记录）")
            return True
        except Exception as e:
            print(f"❌ 保存失败：{e}")
            return False

def generate_date_range(start_date_str: str, end_date_str: str) -> list:
    """生成从开始日期到结束日期的所有日期字符串（YYYYMMDD格式）"""
    dates = []
    try:
        start_date = datetime.strptime(start_date_str, '%Y%m%d')
        end_date = datetime.strptime(end_date_str, '%Y%m%d')
        
        if start_date > end_date:
            raise ValueError("开始日期晚于结束日期")
            
        current_date = start_date
        while current_date <= end_date:
            dates.append(current_date.strftime('%Y%m%d'))
            current_date += timedelta(days=1)
    except Exception as e:
        print(f"日期处理错误：{e}")
    return dates

if __name__ == "__main__":

    # 从配置文件读取Redis连接信息
    with open('redis.conf', 'r') as f:
        for line in f:
            if line.startswith('host='):
                host = line.split('=')[1].strip()
            elif line.startswith('port='):
                port = int(line.split('=')[1].strip())
            elif line.startswith('password='):
                password = line.split('=')[1].strip()
    # 初始化Redis发送端
    sender = RemoteSender(host=host, port=port, password=password)
    
    # 定义日期范围：从20250516到20250923
    # 读取../data/stock_daily_price.parquet文件，获取最大的日期+1，是start_date
    df = pd.read_parquet('../data/stock_daily_cctvnews.parquet')
    start_date = (df['date'].max() + timedelta(days=1)).strftime('%Y%m%d')
    # 获取当日日期-1，是end_date
    end_date = (datetime.today() - timedelta(days=1)).strftime('%Y%m%d')
    
    # 生成日期列表
    date_list = generate_date_range(start_date, end_date)
    print(f"=== 共需获取 {len(date_list)} 天的数据 ===")
    
    # 循环调用获取每日数据
    for i, date in enumerate(date_list, 1):
        print(f"\n=== 正在处理 {i}/{len(date_list)}：{date} ===")
        try:
            # 调用远程函数获取当日数据
            csv_data = sender.call_remote_function('fetch_cctv_news', date)
            # 保存为CSV文件，文件名包含日期
            sender.save_to_csv(csv_data, f'stock_daily_cctvnews_{date}.csv')
            
            # 适当延迟，避免请求过于频繁
            time.sleep(0.1)
        except Exception as e:
            print(f"❌ {date} 处理失败：{e}")
            # 失败后也延迟一下，避免快速重试导致的问题
            time.sleep(2)
    
    print("\n=== 所有日期处理完成 ===")
# Out:
# ✅ 发送端：Redis连接成功
# ✅ 发送端pandas版本：2.3.2
# === 共需获取 256 天的数据 ===
#
# === 正在处理 1/256：20250126 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_97fca75e）
# ✅ 保存成功：stock_daily_cctvnews_20250126.csv（13条记录）
#
# === 正在处理 2/256：20250127 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a0a0b919）
# ✅ 保存成功：stock_daily_cctvnews_20250127.csv（15条记录）
#
# === 正在处理 3/256：20250128 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fd446d5c）
# ✅ 保存成功：stock_daily_cctvnews_20250128.csv（12条记录）
#
# === 正在处理 4/256：20250129 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_24c6e866）
# ✅ 保存成功：stock_daily_cctvnews_20250129.csv（9条记录）
#
# === 正在处理 5/256：20250130 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_05340fd2）
# ✅ 保存成功：stock_daily_cctvnews_20250130.csv（12条记录）
#
# === 正在处理 6/256：20250131 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a5d205a7）
# ✅ 保存成功：stock_daily_cctvnews_20250131.csv（12条记录）
#
# === 正在处理 7/256：20250201 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b0fbc7e3）
# ✅ 保存成功：stock_daily_cctvnews_20250201.csv（13条记录）
#
# === 正在处理 8/256：20250202 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c78b0e41）
# ✅ 保存成功：stock_daily_cctvnews_20250202.csv（15条记录）
#
# === 正在处理 9/256：20250203 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d2d6df2e）
# ✅ 保存成功：stock_daily_cctvnews_20250203.csv（14条记录）
#
# === 正在处理 10/256：20250204 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cd7a46aa）
# ✅ 保存成功：stock_daily_cctvnews_20250204.csv（14条记录）
#
# === 正在处理 11/256：20250205 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3a480642）
# ✅ 保存成功：stock_daily_cctvnews_20250205.csv（17条记录）
#
# === 正在处理 12/256：20250206 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ba0e5c8b）
# ✅ 保存成功：stock_daily_cctvnews_20250206.csv（15条记录）
#
# === 正在处理 13/256：20250207 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cc9c741f）
# ✅ 保存成功：stock_daily_cctvnews_20250207.csv（16条记录）
#
# === 正在处理 14/256：20250208 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f72307cc）
# ✅ 保存成功：stock_daily_cctvnews_20250208.csv（8条记录）
#
# === 正在处理 15/256：20250209 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_adc26390）
# ✅ 保存成功：stock_daily_cctvnews_20250209.csv（14条记录）
#
# === 正在处理 16/256：20250210 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2b7cac58）
# ✅ 保存成功：stock_daily_cctvnews_20250210.csv（13条记录）
#
# === 正在处理 17/256：20250211 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3f700044）
# ✅ 保存成功：stock_daily_cctvnews_20250211.csv（13条记录）
#
# === 正在处理 18/256：20250212 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_51d6db68）
# ✅ 保存成功：stock_daily_cctvnews_20250212.csv（14条记录）
#
# === 正在处理 19/256：20250213 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0dd574cb）
# ✅ 保存成功：stock_daily_cctvnews_20250213.csv（14条记录）
#
# === 正在处理 20/256：20250214 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_31371f36）
# ✅ 保存成功：stock_daily_cctvnews_20250214.csv（14条记录）
#
# === 正在处理 21/256：20250215 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1299409e）
# ✅ 保存成功：stock_daily_cctvnews_20250215.csv（15条记录）
#
# === 正在处理 22/256：20250216 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cb1aab04）
# ✅ 保存成功：stock_daily_cctvnews_20250216.csv（13条记录）
#
# === 正在处理 23/256：20250217 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3c33bc6b）
# ✅ 保存成功：stock_daily_cctvnews_20250217.csv（11条记录）
#
# === 正在处理 24/256：20250218 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4c2c9dd7）
# ✅ 保存成功：stock_daily_cctvnews_20250218.csv（10条记录）
#
# === 正在处理 25/256：20250219 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9bf49547）
# ✅ 保存成功：stock_daily_cctvnews_20250219.csv（11条记录）
#
# === 正在处理 26/256：20250220 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_62b33469）
# ✅ 保存成功：stock_daily_cctvnews_20250220.csv（11条记录）
#
# === 正在处理 27/256：20250221 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_db4b9850）
# ✅ 保存成功：stock_daily_cctvnews_20250221.csv（14条记录）
#
# === 正在处理 28/256：20250222 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c54a8f01）
# ✅ 保存成功：stock_daily_cctvnews_20250222.csv（11条记录）
#
# === 正在处理 29/256：20250223 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_97476d60）
# ✅ 保存成功：stock_daily_cctvnews_20250223.csv（12条记录）
#
# === 正在处理 30/256：20250224 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9f224948）
# ✅ 保存成功：stock_daily_cctvnews_20250224.csv（15条记录）
#
# === 正在处理 31/256：20250225 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bca7f120）
# ✅ 保存成功：stock_daily_cctvnews_20250225.csv（12条记录）
#
# === 正在处理 32/256：20250226 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_107cd653）
# ✅ 保存成功：stock_daily_cctvnews_20250226.csv（14条记录）
#
# === 正在处理 33/256：20250227 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4d3f50f6）
# ✅ 保存成功：stock_daily_cctvnews_20250227.csv（14条记录）
#
# === 正在处理 34/256：20250228 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6890d6bb）
# ✅ 保存成功：stock_daily_cctvnews_20250228.csv（14条记录）
#
# === 正在处理 35/256：20250301 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2402c934）
# ✅ 保存成功：stock_daily_cctvnews_20250301.csv（14条记录）
#
# === 正在处理 36/256：20250302 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d2d2a78e）
# ✅ 保存成功：stock_daily_cctvnews_20250302.csv（14条记录）
#
# === 正在处理 37/256：20250303 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2134deef）
# ✅ 保存成功：stock_daily_cctvnews_20250303.csv（17条记录）
#
# === 正在处理 38/256：20250304 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1683df05）
# ✅ 保存成功：stock_daily_cctvnews_20250304.csv（19条记录）
#
# === 正在处理 39/256：20250305 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b02e84ba）
# ✅ 保存成功：stock_daily_cctvnews_20250305.csv（20条记录）
#
# === 正在处理 40/256：20250306 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1041c4e4）
# ✅ 保存成功：stock_daily_cctvnews_20250306.csv（18条记录）
#
# === 正在处理 41/256：20250307 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2f67469d）
# ✅ 保存成功：stock_daily_cctvnews_20250307.csv（21条记录）
#
# === 正在处理 42/256：20250308 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cdade02a）
# ✅ 保存成功：stock_daily_cctvnews_20250308.csv（15条记录）
#
# === 正在处理 43/256：20250309 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_904e13ab）
# ✅ 保存成功：stock_daily_cctvnews_20250309.csv（15条记录）
#
# === 正在处理 44/256：20250310 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e993f33c）
# ✅ 保存成功：stock_daily_cctvnews_20250310.csv（16条记录）
#
# === 正在处理 45/256：20250311 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e820d644）
# ✅ 保存成功：stock_daily_cctvnews_20250311.csv（14条记录）
#
# === 正在处理 46/256：20250312 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_36db9bf6）
# ✅ 保存成功：stock_daily_cctvnews_20250312.csv（14条记录）
#
# === 正在处理 47/256：20250313 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2e49d43e）
# ✅ 保存成功：stock_daily_cctvnews_20250313.csv（12条记录）
#
# === 正在处理 48/256：20250314 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_345fdfb7）
# ✅ 保存成功：stock_daily_cctvnews_20250314.csv（13条记录）
#
# === 正在处理 49/256：20250315 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_558902f5）
# ✅ 保存成功：stock_daily_cctvnews_20250315.csv（12条记录）
#
# === 正在处理 50/256：20250316 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2ff588fa）
# ✅ 保存成功：stock_daily_cctvnews_20250316.csv（12条记录）
#
# === 正在处理 51/256：20250317 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cd8dd2e9）
# ✅ 保存成功：stock_daily_cctvnews_20250317.csv（12条记录）
#
# === 正在处理 52/256：20250318 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8fc99108）
# ✅ 保存成功：stock_daily_cctvnews_20250318.csv（14条记录）
#
# === 正在处理 53/256：20250319 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_73b5d287）
# ✅ 保存成功：stock_daily_cctvnews_20250319.csv（11条记录）
#
# === 正在处理 54/256：20250320 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0bf3734c）
# ✅ 保存成功：stock_daily_cctvnews_20250320.csv（13条记录）
#
# === 正在处理 55/256：20250321 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9c3fb2e7）
# ✅ 保存成功：stock_daily_cctvnews_20250321.csv（11条记录）
#
# === 正在处理 56/256：20250322 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d8843714）
# ✅ 保存成功：stock_daily_cctvnews_20250322.csv（12条记录）
#
# === 正在处理 57/256：20250323 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8470627d）
# ✅ 保存成功：stock_daily_cctvnews_20250323.csv（14条记录）
#
# === 正在处理 58/256：20250324 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_23f7274b）
# ✅ 保存成功：stock_daily_cctvnews_20250324.csv（15条记录）
#
# === 正在处理 59/256：20250325 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ac4d64d7）
# ✅ 保存成功：stock_daily_cctvnews_20250325.csv（14条记录）
#
# === 正在处理 60/256：20250326 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_335fe96d）
# ✅ 保存成功：stock_daily_cctvnews_20250326.csv（14条记录）
#
# === 正在处理 61/256：20250327 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fd3b41f1）
# ✅ 保存成功：stock_daily_cctvnews_20250327.csv（13条记录）
#
# === 正在处理 62/256：20250328 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_17f52f3b）
# ✅ 保存成功：stock_daily_cctvnews_20250328.csv（15条记录）
#
# === 正在处理 63/256：20250329 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cd1391ff）
# ✅ 保存成功：stock_daily_cctvnews_20250329.csv（14条记录）
#
# === 正在处理 64/256：20250330 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ea606846）
# ✅ 保存成功：stock_daily_cctvnews_20250330.csv（12条记录）
#
# === 正在处理 65/256：20250331 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5c887f96）
# ✅ 保存成功：stock_daily_cctvnews_20250331.csv（12条记录）
#
# === 正在处理 66/256：20250401 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a6a81622）
# ✅ 保存成功：stock_daily_cctvnews_20250401.csv（15条记录）
#
# === 正在处理 67/256：20250402 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_47c10e3a）
# ✅ 保存成功：stock_daily_cctvnews_20250402.csv（14条记录）
#
# === 正在处理 68/256：20250403 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7e690b1c）
# ✅ 保存成功：stock_daily_cctvnews_20250403.csv（15条记录）
#
# === 正在处理 69/256：20250404 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_36473435）
# ✅ 保存成功：stock_daily_cctvnews_20250404.csv（14条记录）
#
# === 正在处理 70/256：20250405 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4f47d936）
# ✅ 保存成功：stock_daily_cctvnews_20250405.csv（13条记录）
#
# === 正在处理 71/256：20250406 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f1756a5b）
# ✅ 保存成功：stock_daily_cctvnews_20250406.csv（15条记录）
#
# === 正在处理 72/256：20250407 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_af5c4719）
# ✅ 保存成功：stock_daily_cctvnews_20250407.csv（13条记录）
#
# === 正在处理 73/256：20250408 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1d574876）
# ✅ 保存成功：stock_daily_cctvnews_20250408.csv（15条记录）
#
# === 正在处理 74/256：20250409 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f9729aef）
# ✅ 保存成功：stock_daily_cctvnews_20250409.csv（11条记录）
#
# === 正在处理 75/256：20250410 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e182eaf3）
# ✅ 保存成功：stock_daily_cctvnews_20250410.csv（14条记录）
#
# === 正在处理 76/256：20250411 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_422ac118）
# ✅ 保存成功：stock_daily_cctvnews_20250411.csv（13条记录）
#
# === 正在处理 77/256：20250412 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c38a87b6）
# ✅ 保存成功：stock_daily_cctvnews_20250412.csv（11条记录）
#
# === 正在处理 78/256：20250413 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_00ef5982）
# ✅ 保存成功：stock_daily_cctvnews_20250413.csv（16条记录）
#
# === 正在处理 79/256：20250414 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_df1285dc）
# ✅ 保存成功：stock_daily_cctvnews_20250414.csv（14条记录）
#
# === 正在处理 80/256：20250415 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e3afac60）
# ✅ 保存成功：stock_daily_cctvnews_20250415.csv（20条记录）
#
# === 正在处理 81/256：20250416 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_24c7072c）
# ✅ 保存成功：stock_daily_cctvnews_20250416.csv（14条记录）
#
# === 正在处理 82/256：20250417 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0e325edc）
# ✅ 保存成功：stock_daily_cctvnews_20250417.csv（15条记录）
#
# === 正在处理 83/256：20250418 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8302c6b0）
# ✅ 保存成功：stock_daily_cctvnews_20250418.csv（16条记录）
#
# === 正在处理 84/256：20250419 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_84212292）
# ✅ 保存成功：stock_daily_cctvnews_20250419.csv（7条记录）
#
# === 正在处理 85/256：20250420 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_aec10c1e）
# ✅ 保存成功：stock_daily_cctvnews_20250420.csv（13条记录）
#
# === 正在处理 86/256：20250421 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b0717c65）
# ✅ 保存成功：stock_daily_cctvnews_20250421.csv（17条记录）
#
# === 正在处理 87/256：20250422 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a2d70216）
# ✅ 保存成功：stock_daily_cctvnews_20250422.csv（15条记录）
#
# === 正在处理 88/256：20250423 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_297d45b0）
# ✅ 保存成功：stock_daily_cctvnews_20250423.csv（15条记录）
#
# === 正在处理 89/256：20250424 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a1f96df0）
# ✅ 保存成功：stock_daily_cctvnews_20250424.csv（17条记录）
#
# === 正在处理 90/256：20250425 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7e8a5cad）
# ✅ 保存成功：stock_daily_cctvnews_20250425.csv（10条记录）
#
# === 正在处理 91/256：20250426 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c4714e75）
# ✅ 保存成功：stock_daily_cctvnews_20250426.csv（15条记录）
#
# === 正在处理 92/256：20250427 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6c2682aa）
# ✅ 保存成功：stock_daily_cctvnews_20250427.csv（15条记录）
#
# === 正在处理 93/256：20250428 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8c74ae06）
# ✅ 保存成功：stock_daily_cctvnews_20250428.csv（9条记录）
#
# === 正在处理 94/256：20250429 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_597fdfb1）
# ✅ 保存成功：stock_daily_cctvnews_20250429.csv（16条记录）
#
# === 正在处理 95/256：20250430 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_56059876）
# ✅ 保存成功：stock_daily_cctvnews_20250430.csv（16条记录）
#
# === 正在处理 96/256：20250501 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7fb1f0e3）
# ✅ 保存成功：stock_daily_cctvnews_20250501.csv（16条记录）
#
# === 正在处理 97/256：20250502 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9e21d3a1）
# ✅ 保存成功：stock_daily_cctvnews_20250502.csv（12条记录）
#
# === 正在处理 98/256：20250503 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a96f03e1）
# ✅ 保存成功：stock_daily_cctvnews_20250503.csv（15条记录）
#
# === 正在处理 99/256：20250504 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d66e3af8）
# ✅ 保存成功：stock_daily_cctvnews_20250504.csv（14条记录）
#
# === 正在处理 100/256：20250505 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_73f5bae0）
# ✅ 保存成功：stock_daily_cctvnews_20250505.csv（15条记录）
#
# === 正在处理 101/256：20250506 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b4336601）
# ✅ 保存成功：stock_daily_cctvnews_20250506.csv（10条记录）
#
# === 正在处理 102/256：20250507 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4f6040f6）
# ✅ 保存成功：stock_daily_cctvnews_20250507.csv（14条记录）
#
# === 正在处理 103/256：20250508 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_54236722）
# ✅ 保存成功：stock_daily_cctvnews_20250508.csv（12条记录）
#
# === 正在处理 104/256：20250509 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ee430e8a）
# ✅ 保存成功：stock_daily_cctvnews_20250509.csv（11条记录）
#
# === 正在处理 105/256：20250510 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_209fdb08）
# ✅ 保存成功：stock_daily_cctvnews_20250510.csv（14条记录）
#
# === 正在处理 106/256：20250511 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d80c5ff0）
# ✅ 保存成功：stock_daily_cctvnews_20250511.csv（10条记录）
#
# === 正在处理 107/256：20250512 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_60bb1cbc）
# ✅ 保存成功：stock_daily_cctvnews_20250512.csv（16条记录）
#
# === 正在处理 108/256：20250513 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7c2b5f8b）
# ✅ 保存成功：stock_daily_cctvnews_20250513.csv（15条记录）
#
# === 正在处理 109/256：20250514 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_935128ef）
# ✅ 保存成功：stock_daily_cctvnews_20250514.csv（18条记录）
#
# === 正在处理 110/256：20250515 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8cd097df）
# ✅ 保存成功：stock_daily_cctvnews_20250515.csv（13条记录）
#
# === 正在处理 111/256：20250516 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4fcb574a）
# ✅ 保存成功：stock_daily_cctvnews_20250516.csv（16条记录）
#
# === 正在处理 112/256：20250517 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7dc91754）
# ✅ 保存成功：stock_daily_cctvnews_20250517.csv（11条记录）
#
# === 正在处理 113/256：20250518 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_197c674f）
# ✅ 保存成功：stock_daily_cctvnews_20250518.csv（13条记录）
#
# === 正在处理 114/256：20250519 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c5475d0d）
# ✅ 保存成功：stock_daily_cctvnews_20250519.csv（17条记录）
#
# === 正在处理 115/256：20250520 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_14e09674）
# ✅ 保存成功：stock_daily_cctvnews_20250520.csv（14条记录）
#
# === 正在处理 116/256：20250521 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1cbe79df）
# ✅ 保存成功：stock_daily_cctvnews_20250521.csv（15条记录）
#
# === 正在处理 117/256：20250522 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8d1be280）
# ✅ 保存成功：stock_daily_cctvnews_20250522.csv（18条记录）
#
# === 正在处理 118/256：20250523 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ba14b497）
# ✅ 保存成功：stock_daily_cctvnews_20250523.csv（15条记录）
#
# === 正在处理 119/256：20250524 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4700a1a1）
# ✅ 保存成功：stock_daily_cctvnews_20250524.csv（13条记录）
#
# === 正在处理 120/256：20250525 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_83844a8a）
# ✅ 保存成功：stock_daily_cctvnews_20250525.csv（15条记录）
#
# === 正在处理 121/256：20250526 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b2c572f6）
# ✅ 保存成功：stock_daily_cctvnews_20250526.csv（17条记录）
#
# === 正在处理 122/256：20250527 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_05827555）
# ✅ 保存成功：stock_daily_cctvnews_20250527.csv（17条记录）
#
# === 正在处理 123/256：20250528 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2ce72a81）
# ✅ 保存成功：stock_daily_cctvnews_20250528.csv（14条记录）
#
# === 正在处理 124/256：20250529 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9efda7a9）
# ✅ 保存成功：stock_daily_cctvnews_20250529.csv（14条记录）
#
# === 正在处理 125/256：20250530 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5406537e）
# ✅ 保存成功：stock_daily_cctvnews_20250530.csv（13条记录）
#
# === 正在处理 126/256：20250531 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bdcee68c）
# ✅ 保存成功：stock_daily_cctvnews_20250531.csv（14条记录）
#
# === 正在处理 127/256：20250601 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6d957179）
# ✅ 保存成功：stock_daily_cctvnews_20250601.csv（14条记录）
#
# === 正在处理 128/256：20250602 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e3c2961a）
# ✅ 保存成功：stock_daily_cctvnews_20250602.csv（13条记录）
#
# === 正在处理 129/256：20250603 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_eaeb98fb）
# ✅ 保存成功：stock_daily_cctvnews_20250603.csv（15条记录）
#
# === 正在处理 130/256：20250604 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d6960494）
# ✅ 保存成功：stock_daily_cctvnews_20250604.csv（15条记录）
#
# === 正在处理 131/256：20250605 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_28c1347d）
# ✅ 保存成功：stock_daily_cctvnews_20250605.csv（18条记录）
#
# === 正在处理 132/256：20250606 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_17d090a8）
# ✅ 保存成功：stock_daily_cctvnews_20250606.csv（17条记录）
#
# === 正在处理 133/256：20250607 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b62ced99）
# ✅ 保存成功：stock_daily_cctvnews_20250607.csv（15条记录）
#
# === 正在处理 134/256：20250608 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e6c438b3）
# ✅ 保存成功：stock_daily_cctvnews_20250608.csv（14条记录）
#
# === 正在处理 135/256：20250609 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_126ac88d）
# ✅ 保存成功：stock_daily_cctvnews_20250609.csv（14条记录）
#
# === 正在处理 136/256：20250610 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a33ba2cc）
# ✅ 保存成功：stock_daily_cctvnews_20250610.csv（14条记录）
#
# === 正在处理 137/256：20250611 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_602a3b1e）
# ✅ 保存成功：stock_daily_cctvnews_20250611.csv（14条记录）
#
# === 正在处理 138/256：20250612 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7905a6f1）
# ✅ 保存成功：stock_daily_cctvnews_20250612.csv（17条记录）
#
# === 正在处理 139/256：20250613 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7b5dfd4b）
# ✅ 保存成功：stock_daily_cctvnews_20250613.csv（16条记录）
#
# === 正在处理 140/256：20250614 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_380dfcfc）
# ✅ 保存成功：stock_daily_cctvnews_20250614.csv（13条记录）
#
# === 正在处理 141/256：20250615 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_64bd2ff3）
# ✅ 保存成功：stock_daily_cctvnews_20250615.csv（14条记录）
#
# === 正在处理 142/256：20250616 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_afe40921）
# ✅ 保存成功：stock_daily_cctvnews_20250616.csv（12条记录）
#
# === 正在处理 143/256：20250617 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8dedbf87）
# ✅ 保存成功：stock_daily_cctvnews_20250617.csv（15条记录）
#
# === 正在处理 144/256：20250618 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f7e46bb9）
# ✅ 保存成功：stock_daily_cctvnews_20250618.csv（14条记录）
#
# === 正在处理 145/256：20250619 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_23dacac3）
# ✅ 保存成功：stock_daily_cctvnews_20250619.csv（12条记录）
#
# === 正在处理 146/256：20250620 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cbe7e102）
# ✅ 保存成功：stock_daily_cctvnews_20250620.csv（14条记录）
#
# === 正在处理 147/256：20250621 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_3756ee94）
# ✅ 保存成功：stock_daily_cctvnews_20250621.csv（14条记录）
#
# === 正在处理 148/256：20250622 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8ce40c8e）
# ✅ 保存成功：stock_daily_cctvnews_20250622.csv（12条记录）
#
# === 正在处理 149/256：20250623 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_42c34af8）
# ✅ 保存成功：stock_daily_cctvnews_20250623.csv（16条记录）
#
# === 正在处理 150/256：20250624 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ad5f1a77）
# ✅ 保存成功：stock_daily_cctvnews_20250624.csv（17条记录）
#
# === 正在处理 151/256：20250625 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_76dbca3b）
# ✅ 保存成功：stock_daily_cctvnews_20250625.csv（14条记录）
#
# === 正在处理 152/256：20250626 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7b4aa608）
# ✅ 保存成功：stock_daily_cctvnews_20250626.csv（14条记录）
#
# === 正在处理 153/256：20250627 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_49c58c60）
# ✅ 保存成功：stock_daily_cctvnews_20250627.csv（17条记录）
#
# === 正在处理 154/256：20250628 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d0be3166）
# ✅ 保存成功：stock_daily_cctvnews_20250628.csv（12条记录）
#
# === 正在处理 155/256：20250629 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8614b34f）
# ✅ 保存成功：stock_daily_cctvnews_20250629.csv（14条记录）
#
# === 正在处理 156/256：20250630 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d42ab955）
# ✅ 保存成功：stock_daily_cctvnews_20250630.csv（13条记录）
#
# === 正在处理 157/256：20250701 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4c04154f）
# ✅ 保存成功：stock_daily_cctvnews_20250701.csv（16条记录）
#
# === 正在处理 158/256：20250702 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e4fbaaf3）
# ✅ 保存成功：stock_daily_cctvnews_20250702.csv（12条记录）
#
# === 正在处理 159/256：20250703 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_35dd4786）
# ✅ 保存成功：stock_daily_cctvnews_20250703.csv（13条记录）
#
# === 正在处理 160/256：20250704 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_60f4549a）
# ✅ 保存成功：stock_daily_cctvnews_20250704.csv（14条记录）
#
# === 正在处理 161/256：20250705 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c22d89b6）
# ✅ 保存成功：stock_daily_cctvnews_20250705.csv（12条记录）
#
# === 正在处理 162/256：20250706 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9816d98a）
# ✅ 保存成功：stock_daily_cctvnews_20250706.csv（14条记录）
#
# === 正在处理 163/256：20250707 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9d4a4c7e）
# ✅ 保存成功：stock_daily_cctvnews_20250707.csv（15条记录）
#
# === 正在处理 164/256：20250708 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_988eb5a0）
# ✅ 保存成功：stock_daily_cctvnews_20250708.csv（14条记录）
#
# === 正在处理 165/256：20250709 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c99eb25e）
# ✅ 保存成功：stock_daily_cctvnews_20250709.csv（14条记录）
#
# === 正在处理 166/256：20250710 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d2dd99d3）
# ✅ 保存成功：stock_daily_cctvnews_20250710.csv（18条记录）
#
# === 正在处理 167/256：20250711 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5f64c11c）
# ✅ 保存成功：stock_daily_cctvnews_20250711.csv（18条记录）
#
# === 正在处理 168/256：20250712 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_717452ac）
# ✅ 保存成功：stock_daily_cctvnews_20250712.csv（13条记录）
#
# === 正在处理 169/256：20250713 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_151bfd42）
# ✅ 保存成功：stock_daily_cctvnews_20250713.csv（14条记录）
#
# === 正在处理 170/256：20250714 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_aa97dfe3）
# ✅ 保存成功：stock_daily_cctvnews_20250714.csv（16条记录）
#
# === 正在处理 171/256：20250715 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_679b8e77）
# ✅ 保存成功：stock_daily_cctvnews_20250715.csv（18条记录）
#
# === 正在处理 172/256：20250716 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ac93cb5c）
# ✅ 保存成功：stock_daily_cctvnews_20250716.csv（15条记录）
#
# === 正在处理 173/256：20250717 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9a68b86b）
# ✅ 保存成功：stock_daily_cctvnews_20250717.csv（14条记录）
#
# === 正在处理 174/256：20250718 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_42efcab8）
# ✅ 保存成功：stock_daily_cctvnews_20250718.csv（14条记录）
#
# === 正在处理 175/256：20250719 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fd78521d）
# ✅ 保存成功：stock_daily_cctvnews_20250719.csv（12条记录）
#
# === 正在处理 176/256：20250720 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_cb756b0d）
# ✅ 保存成功：stock_daily_cctvnews_20250720.csv（14条记录）
#
# === 正在处理 177/256：20250721 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_333ad6f4）
# ✅ 保存成功：stock_daily_cctvnews_20250721.csv（14条记录）
#
# === 正在处理 178/256：20250722 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_2af1db4d）
# ✅ 保存成功：stock_daily_cctvnews_20250722.csv（16条记录）
#
# === 正在处理 179/256：20250723 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_1b16bb7e）
# ✅ 保存成功：stock_daily_cctvnews_20250723.csv（12条记录）
#
# === 正在处理 180/256：20250724 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d08c34af）
# ✅ 保存成功：stock_daily_cctvnews_20250724.csv（8条记录）
#
# === 正在处理 181/256：20250725 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d1019478）
# ✅ 保存成功：stock_daily_cctvnews_20250725.csv（9条记录）
#
# === 正在处理 182/256：20250726 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f5a18c4b）
# ✅ 保存成功：stock_daily_cctvnews_20250726.csv（14条记录）
#
# === 正在处理 183/256：20250727 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_45f75aa1）
# ✅ 保存成功：stock_daily_cctvnews_20250727.csv（12条记录）
#
# === 正在处理 184/256：20250728 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_952b99e1）
# ✅ 保存成功：stock_daily_cctvnews_20250728.csv（12条记录）
#
# === 正在处理 185/256：20250729 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_dec9f323）
# ✅ 保存成功：stock_daily_cctvnews_20250729.csv（15条记录）
#
# === 正在处理 186/256：20250730 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_237644b8）
# ✅ 保存成功：stock_daily_cctvnews_20250730.csv（13条记录）
#
# === 正在处理 187/256：20250731 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0428d339）
# ✅ 保存成功：stock_daily_cctvnews_20250731.csv（14条记录）
#
# === 正在处理 188/256：20250801 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_8d2877a8）
# ✅ 保存成功：stock_daily_cctvnews_20250801.csv（10条记录）
#
# === 正在处理 189/256：20250802 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e30603ed）
# ✅ 保存成功：stock_daily_cctvnews_20250802.csv（10条记录）
#
# === 正在处理 190/256：20250803 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e352137f）
# ✅ 保存成功：stock_daily_cctvnews_20250803.csv（12条记录）
#
# === 正在处理 191/256：20250804 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e9c2e0bf）
# ✅ 保存成功：stock_daily_cctvnews_20250804.csv（12条记录）
#
# === 正在处理 192/256：20250805 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f21b45f1）
# ✅ 保存成功：stock_daily_cctvnews_20250805.csv（12条记录）
#
# === 正在处理 193/256：20250806 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_796f9231）
# ✅ 保存成功：stock_daily_cctvnews_20250806.csv（12条记录）
#
# === 正在处理 194/256：20250807 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6fb8cdf7）
# ✅ 保存成功：stock_daily_cctvnews_20250807.csv（12条记录）
#
# === 正在处理 195/256：20250808 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d3b53837）
# ✅ 保存成功：stock_daily_cctvnews_20250808.csv（14条记录）
#
# === 正在处理 196/256：20250809 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6df9e2be）
# ✅ 保存成功：stock_daily_cctvnews_20250809.csv（12条记录）
#
# === 正在处理 197/256：20250810 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_808190d3）
# ✅ 保存成功：stock_daily_cctvnews_20250810.csv（13条记录）
#
# === 正在处理 198/256：20250811 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4bd7b1fa）
# ✅ 保存成功：stock_daily_cctvnews_20250811.csv（13条记录）
#
# === 正在处理 199/256：20250812 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c2d6dc41）
# ✅ 保存成功：stock_daily_cctvnews_20250812.csv（18条记录）
#
# === 正在处理 200/256：20250813 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_136d58b7）
# ✅ 保存成功：stock_daily_cctvnews_20250813.csv（12条记录）
#
# === 正在处理 201/256：20250814 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_794522eb）
# ✅ 保存成功：stock_daily_cctvnews_20250814.csv（13条记录）
#
# === 正在处理 202/256：20250815 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_9ec88ea3）
# ✅ 保存成功：stock_daily_cctvnews_20250815.csv（13条记录）
#
# === 正在处理 203/256：20250816 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f53bf5db）
# ✅ 保存成功：stock_daily_cctvnews_20250816.csv（13条记录）
#
# === 正在处理 204/256：20250817 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_834db708）
# ✅ 保存成功：stock_daily_cctvnews_20250817.csv（14条记录）
#
# === 正在处理 205/256：20250818 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f0889408）
# ✅ 保存成功：stock_daily_cctvnews_20250818.csv（13条记录）
#
# === 正在处理 206/256：20250819 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0ac04df0）
# ✅ 保存成功：stock_daily_cctvnews_20250819.csv（14条记录）
#
# === 正在处理 207/256：20250820 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_741bad93）
# ✅ 保存成功：stock_daily_cctvnews_20250820.csv（12条记录）
#
# === 正在处理 208/256：20250821 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4150c4d4）
# ✅ 保存成功：stock_daily_cctvnews_20250821.csv（12条记录）
#
# === 正在处理 209/256：20250822 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b37ff3ba）
# ✅ 保存成功：stock_daily_cctvnews_20250822.csv（11条记录）
#
# === 正在处理 210/256：20250823 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_559eeca2）
# ✅ 保存成功：stock_daily_cctvnews_20250823.csv（12条记录）
#
# === 正在处理 211/256：20250824 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_c576dc75）
# ✅ 保存成功：stock_daily_cctvnews_20250824.csv（16条记录）
#
# === 正在处理 212/256：20250825 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_da99d974）
# ✅ 保存成功：stock_daily_cctvnews_20250825.csv（12条记录）
#
# === 正在处理 213/256：20250826 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4d775e73）
# ✅ 保存成功：stock_daily_cctvnews_20250826.csv（16条记录）
#
# === 正在处理 214/256：20250827 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e0eaded7）
# ✅ 保存成功：stock_daily_cctvnews_20250827.csv（15条记录）
#
# === 正在处理 215/256：20250828 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_5c3140a5）
# ✅ 保存成功：stock_daily_cctvnews_20250828.csv（13条记录）
#
# === 正在处理 216/256：20250829 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_fe5f28f3）
# ✅ 保存成功：stock_daily_cctvnews_20250829.csv（13条记录）
#
# === 正在处理 217/256：20250830 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_370bf277）
# ✅ 保存成功：stock_daily_cctvnews_20250830.csv（14条记录）
#
# === 正在处理 218/256：20250831 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_ad8d36e2）
# ✅ 保存成功：stock_daily_cctvnews_20250831.csv（17条记录）
#
# === 正在处理 219/256：20250901 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6550c04f）
# ✅ 保存成功：stock_daily_cctvnews_20250901.csv（16条记录）
#
# === 正在处理 220/256：20250902 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_883ba021）
# ✅ 保存成功：stock_daily_cctvnews_20250902.csv（24条记录）
#
# === 正在处理 221/256：20250903 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e1c1e4af）
# ✅ 保存成功：stock_daily_cctvnews_20250903.csv（10条记录）
#
# === 正在处理 222/256：20250904 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_431e3576）
# ✅ 保存成功：stock_daily_cctvnews_20250904.csv（22条记录）
#
# === 正在处理 223/256：20250905 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_6bfa8f06）
# ✅ 保存成功：stock_daily_cctvnews_20250905.csv（18条记录）
#
# === 正在处理 224/256：20250906 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_48bd1802）
# ✅ 保存成功：stock_daily_cctvnews_20250906.csv（17条记录）
#
# === 正在处理 225/256：20250907 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_bb58c5a1）
# ✅ 保存成功：stock_daily_cctvnews_20250907.csv（14条记录）
#
# === 正在处理 226/256：20250908 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b91a4873）
# ✅ 保存成功：stock_daily_cctvnews_20250908.csv（13条记录）
#
# === 正在处理 227/256：20250909 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_17aff5d6）
# ✅ 保存成功：stock_daily_cctvnews_20250909.csv（14条记录）
#
# === 正在处理 228/256：20250910 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_e8596693）
# ✅ 保存成功：stock_daily_cctvnews_20250910.csv（17条记录）
#
# === 正在处理 229/256：20250911 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b023d534）
# ✅ 保存成功：stock_daily_cctvnews_20250911.csv（13条记录）
#
# === 正在处理 230/256：20250912 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a5db9f73）
# ✅ 保存成功：stock_daily_cctvnews_20250912.csv（11条记录）
#
# === 正在处理 231/256：20250913 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d1bbf0bb）
# ✅ 保存成功：stock_daily_cctvnews_20250913.csv（12条记录）
#
# === 正在处理 232/256：20250914 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_d78e1f34）
# ✅ 保存成功：stock_daily_cctvnews_20250914.csv（14条记录）
#
# === 正在处理 233/256：20250915 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b60059b6）
# ✅ 保存成功：stock_daily_cctvnews_20250915.csv（15条记录）
#
# === 正在处理 234/256：20250916 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_846818f7）
# ✅ 保存成功：stock_daily_cctvnews_20250916.csv（12条记录）
#
# === 正在处理 235/256：20250917 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_b6e592e4）
# ✅ 保存成功：stock_daily_cctvnews_20250917.csv（14条记录）
#
# === 正在处理 236/256：20250918 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_044074b8）
# ✅ 保存成功：stock_daily_cctvnews_20250918.csv（13条记录）
#
# === 正在处理 237/256：20250919 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_0680d59e）
# ✅ 保存成功：stock_daily_cctvnews_20250919.csv（11条记录）
#
# === 正在处理 238/256：20250920 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_dfd17bc2）
# ✅ 保存成功：stock_daily_cctvnews_20250920.csv（12条记录）
#
# === 正在处理 239/256：20250921 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_973452bd）
# ✅ 保存成功：stock_daily_cctvnews_20250921.csv（13条记录）
#
# === 正在处理 240/256：20250922 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_143dbf82）
# ✅ 保存成功：stock_daily_cctvnews_20250922.csv（17条记录）
#
# === 正在处理 241/256：20250923 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a27f50cd）
# ✅ 保存成功：stock_daily_cctvnews_20250923.csv（16条记录）
#
# === 正在处理 242/256：20250924 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_35be4667）
# ✅ 保存成功：stock_daily_cctvnews_20250924.csv（15条记录）
#
# === 正在处理 243/256：20250925 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_300adaaf）
# ✅ 保存成功：stock_daily_cctvnews_20250925.csv（16条记录）
#
# === 正在处理 244/256：20250926 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_544ec5df）
# ✅ 保存成功：stock_daily_cctvnews_20250926.csv（14条记录）
#
# === 正在处理 245/256：20250927 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_52a5424f）
# ✅ 保存成功：stock_daily_cctvnews_20250927.csv（11条记录）
#
# === 正在处理 246/256：20250928 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f639380e）
# ✅ 保存成功：stock_daily_cctvnews_20250928.csv（12条记录）
#
# === 正在处理 247/256：20250929 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_79eb33d6）
# ✅ 保存成功：stock_daily_cctvnews_20250929.csv（14条记录）
#
# === 正在处理 248/256：20250930 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7fae9406）
# ✅ 保存成功：stock_daily_cctvnews_20250930.csv（15条记录）
#
# === 正在处理 249/256：20251001 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_15728bcb）
# ✅ 保存成功：stock_daily_cctvnews_20251001.csv（11条记录）
#
# === 正在处理 250/256：20251002 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a22d6da6）
# ✅ 保存成功：stock_daily_cctvnews_20251002.csv（15条记录）
#
# === 正在处理 251/256：20251003 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_52ab1bc1）
# ✅ 保存成功：stock_daily_cctvnews_20251003.csv（13条记录）
#
# === 正在处理 252/256：20251004 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_a186df2b）
# ✅ 保存成功：stock_daily_cctvnews_20251004.csv（11条记录）
#
# === 正在处理 253/256：20251005 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_4b7ecc32）
# ✅ 保存成功：stock_daily_cctvnews_20251005.csv（12条记录）
#
# === 正在处理 254/256：20251006 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_7f5ee35c）
# ✅ 保存成功：stock_daily_cctvnews_20251006.csv（12条记录）
#
# === 正在处理 255/256：20251007 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_96ac9c89）
# ✅ 保存成功：stock_daily_cctvnews_20251007.csv（15条记录）
#
# === 正在处理 256/256：20251008 ===
# 📤 已调用远程函数：fetch_cctv_news（任务ID：task_f854d685）
# ✅ 保存成功：stock_daily_cctvnews_20251008.csv（13条记录）
#
# === 所有日期处理完成 ===

# %% [markdown]
# ## 将csv合并为一个parquet文件

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将 /d:/workspace/xiaoyao/redis/ 目录下的所有 stock_***.csv 文件合并为一个 parquet 文件
确保与现有 /d:/workspace/xiaoyao/data/stock_daily_price.parquet 保持字段、压缩方式一致
"""

import os
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path
import glob


def merge_stock_csv_to_parquet(csv_dir, output_parquet_file):
    """
    合并指定目录下的所有 stock_***.csv 文件到单个 parquet 文件
    
    Args:
        csv_dir: CSV 文件所在目录
        output_parquet_file: 输出的 parquet 文件路径
    """
    print(f"📁 开始处理目录: {csv_dir}")
    
    # 获取所有 stock_***.csv 文件
    csv_pattern = os.path.join(csv_dir, "stock_daily_cctvnews_*.csv")
    csv_files = glob.glob(csv_pattern)
    
    if not csv_files:
        print("❌ 未找到 stock_***.csv 文件")
        return False
    
    print(f"📊 找到 {len(csv_files)} 个 CSV 文件")
    
    # 按文件名排序（确保按日期顺序处理）
    csv_files.sort()
    
    # 读取并合并所有 CSV 文件
    all_dataframes = []
    total_records = 0
    
    for i, csv_file in enumerate(csv_files, 1):
        filename = os.path.basename(csv_file)
        print(f"正在处理 ({i}/{len(csv_files)}): {filename}")
        
        try:
            # 读取 CSV 文件
            df = pd.read_csv(csv_file)
            
            # 数据验证和清洗
            # 确保 date 列是 datetime 类型
            df['date'] = pd.to_datetime(df['date'])
            
            all_dataframes.append(df)
            total_records += len(df)
            print(f"  ✅ 成功读取 {len(df)} 条记录")
            
        except Exception as e:
            print(f"  ❌ 处理失败: {e}")
            continue
    
    if not all_dataframes:
        print("❌ 没有成功读取任何数据")
        return False
    
    print(f"\n📊 合并所有数据...")
    # 合并所有数据框
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    
    # 去重（按 date + stock_code）
    combined_df = combined_df.drop_duplicates(subset=['date', 'id'])
    
    # 按日期和股票代码排序
    combined_df = combined_df.sort_values(['date', 'id']).reset_index(drop=True)
    
    print(f"📈 总计 {len(combined_df)} 条记录（去重后）")
    
    # 确保输出目录存在
    output_dir = os.path.dirname(output_parquet_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")
    
    # 转换为 pyarrow Table
    table = pa.Table.from_pandas(combined_df)
    
    # 使用与目标文件相同的压缩方式 (snappy) 和格式写入 parquet
    try:
        pq.write_table(
            table, 
            output_parquet_file,
            compression='snappy',
            version='2.6',  # 使用较新的 parquet 版本
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024  # 64MB batch size for better performance
        )
        
        print(f"✅ 成功保存到: {output_parquet_file}")
        print(f"📊 文件大小: {os.path.getsize(output_parquet_file) / (1024*1024):.2f} MB")
        
        return True
        
    except Exception as e:
        print(f"❌ 保存 parquet 文件失败: {e}")
        return False


def main():
    """主函数"""
    # 设置路径
    csv_directory = "d:/workspace/xiaoyao/redis/"
    # 确保输出目录存在
    output_dir = os.path.join(csv_directory, 'parquet')
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")

    output_file = os.path.join(output_dir, 'stock_daily_cctvnews_to_merged.parquet')
    
    
    print("=" * 60)
    print("🚀 开始合并 stock_***.csv 文件到 parquet")
    print("=" * 60)
    
    # 执行合并
    success = merge_stock_csv_to_parquet(csv_directory, output_file)
    
    if success:
        print("\n🎉 合并完成！")
        
        # 验证结果
        try:
            print("\n📋 验证结果:")
            result_df = pd.read_parquet(output_file)
            print(f"   总行数: {len(result_df)}")
            print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
            print(f"   股票数量: {result_df['stock_code'].nunique()}")
            print(f"   列名: {list(result_df.columns)}")
            
        except Exception as e:
            print(f"⚠️  验证失败: {e}")
    
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 stock_***.csv 文件到 parquet
# ============================================================
# 📁 开始处理目录: d:/workspace/xiaoyao/redis/
# 📊 找到 256 个 CSV 文件
# 正在处理 (1/256): stock_daily_cctvnews_20250126.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (2/256): stock_daily_cctvnews_20250127.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (3/256): stock_daily_cctvnews_20250128.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (4/256): stock_daily_cctvnews_20250129.csv
#   ✅ 成功读取 9 条记录
# 正在处理 (5/256): stock_daily_cctvnews_20250130.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (6/256): stock_daily_cctvnews_20250131.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (7/256): stock_daily_cctvnews_20250201.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (8/256): stock_daily_cctvnews_20250202.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (9/256): stock_daily_cctvnews_20250203.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (10/256): stock_daily_cctvnews_20250204.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (11/256): stock_daily_cctvnews_20250205.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (12/256): stock_daily_cctvnews_20250206.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (13/256): stock_daily_cctvnews_20250207.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (14/256): stock_daily_cctvnews_20250208.csv
#   ✅ 成功读取 8 条记录
# 正在处理 (15/256): stock_daily_cctvnews_20250209.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (16/256): stock_daily_cctvnews_20250210.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (17/256): stock_daily_cctvnews_20250211.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (18/256): stock_daily_cctvnews_20250212.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (19/256): stock_daily_cctvnews_20250213.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (20/256): stock_daily_cctvnews_20250214.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (21/256): stock_daily_cctvnews_20250215.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (22/256): stock_daily_cctvnews_20250216.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (23/256): stock_daily_cctvnews_20250217.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (24/256): stock_daily_cctvnews_20250218.csv
#   ✅ 成功读取 10 条记录
# 正在处理 (25/256): stock_daily_cctvnews_20250219.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (26/256): stock_daily_cctvnews_20250220.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (27/256): stock_daily_cctvnews_20250221.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (28/256): stock_daily_cctvnews_20250222.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (29/256): stock_daily_cctvnews_20250223.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (30/256): stock_daily_cctvnews_20250224.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (31/256): stock_daily_cctvnews_20250225.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (32/256): stock_daily_cctvnews_20250226.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (33/256): stock_daily_cctvnews_20250227.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (34/256): stock_daily_cctvnews_20250228.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (35/256): stock_daily_cctvnews_20250301.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (36/256): stock_daily_cctvnews_20250302.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (37/256): stock_daily_cctvnews_20250303.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (38/256): stock_daily_cctvnews_20250304.csv
#   ✅ 成功读取 19 条记录
# 正在处理 (39/256): stock_daily_cctvnews_20250305.csv
#   ✅ 成功读取 20 条记录
# 正在处理 (40/256): stock_daily_cctvnews_20250306.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (41/256): stock_daily_cctvnews_20250307.csv
#   ✅ 成功读取 21 条记录
# 正在处理 (42/256): stock_daily_cctvnews_20250308.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (43/256): stock_daily_cctvnews_20250309.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (44/256): stock_daily_cctvnews_20250310.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (45/256): stock_daily_cctvnews_20250311.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (46/256): stock_daily_cctvnews_20250312.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (47/256): stock_daily_cctvnews_20250313.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (48/256): stock_daily_cctvnews_20250314.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (49/256): stock_daily_cctvnews_20250315.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (50/256): stock_daily_cctvnews_20250316.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (51/256): stock_daily_cctvnews_20250317.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (52/256): stock_daily_cctvnews_20250318.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (53/256): stock_daily_cctvnews_20250319.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (54/256): stock_daily_cctvnews_20250320.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (55/256): stock_daily_cctvnews_20250321.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (56/256): stock_daily_cctvnews_20250322.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (57/256): stock_daily_cctvnews_20250323.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (58/256): stock_daily_cctvnews_20250324.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (59/256): stock_daily_cctvnews_20250325.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (60/256): stock_daily_cctvnews_20250326.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (61/256): stock_daily_cctvnews_20250327.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (62/256): stock_daily_cctvnews_20250328.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (63/256): stock_daily_cctvnews_20250329.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (64/256): stock_daily_cctvnews_20250330.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (65/256): stock_daily_cctvnews_20250331.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (66/256): stock_daily_cctvnews_20250401.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (67/256): stock_daily_cctvnews_20250402.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (68/256): stock_daily_cctvnews_20250403.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (69/256): stock_daily_cctvnews_20250404.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (70/256): stock_daily_cctvnews_20250405.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (71/256): stock_daily_cctvnews_20250406.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (72/256): stock_daily_cctvnews_20250407.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (73/256): stock_daily_cctvnews_20250408.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (74/256): stock_daily_cctvnews_20250409.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (75/256): stock_daily_cctvnews_20250410.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (76/256): stock_daily_cctvnews_20250411.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (77/256): stock_daily_cctvnews_20250412.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (78/256): stock_daily_cctvnews_20250413.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (79/256): stock_daily_cctvnews_20250414.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (80/256): stock_daily_cctvnews_20250415.csv
#   ✅ 成功读取 20 条记录
# 正在处理 (81/256): stock_daily_cctvnews_20250416.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (82/256): stock_daily_cctvnews_20250417.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (83/256): stock_daily_cctvnews_20250418.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (84/256): stock_daily_cctvnews_20250419.csv
#   ✅ 成功读取 7 条记录
# 正在处理 (85/256): stock_daily_cctvnews_20250420.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (86/256): stock_daily_cctvnews_20250421.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (87/256): stock_daily_cctvnews_20250422.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (88/256): stock_daily_cctvnews_20250423.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (89/256): stock_daily_cctvnews_20250424.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (90/256): stock_daily_cctvnews_20250425.csv
#   ✅ 成功读取 10 条记录
# 正在处理 (91/256): stock_daily_cctvnews_20250426.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (92/256): stock_daily_cctvnews_20250427.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (93/256): stock_daily_cctvnews_20250428.csv
#   ✅ 成功读取 9 条记录
# 正在处理 (94/256): stock_daily_cctvnews_20250429.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (95/256): stock_daily_cctvnews_20250430.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (96/256): stock_daily_cctvnews_20250501.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (97/256): stock_daily_cctvnews_20250502.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (98/256): stock_daily_cctvnews_20250503.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (99/256): stock_daily_cctvnews_20250504.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (100/256): stock_daily_cctvnews_20250505.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (101/256): stock_daily_cctvnews_20250506.csv
#   ✅ 成功读取 10 条记录
# 正在处理 (102/256): stock_daily_cctvnews_20250507.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (103/256): stock_daily_cctvnews_20250508.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (104/256): stock_daily_cctvnews_20250509.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (105/256): stock_daily_cctvnews_20250510.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (106/256): stock_daily_cctvnews_20250511.csv
#   ✅ 成功读取 10 条记录
# 正在处理 (107/256): stock_daily_cctvnews_20250512.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (108/256): stock_daily_cctvnews_20250513.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (109/256): stock_daily_cctvnews_20250514.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (110/256): stock_daily_cctvnews_20250515.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (111/256): stock_daily_cctvnews_20250516.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (112/256): stock_daily_cctvnews_20250517.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (113/256): stock_daily_cctvnews_20250518.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (114/256): stock_daily_cctvnews_20250519.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (115/256): stock_daily_cctvnews_20250520.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (116/256): stock_daily_cctvnews_20250521.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (117/256): stock_daily_cctvnews_20250522.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (118/256): stock_daily_cctvnews_20250523.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (119/256): stock_daily_cctvnews_20250524.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (120/256): stock_daily_cctvnews_20250525.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (121/256): stock_daily_cctvnews_20250526.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (122/256): stock_daily_cctvnews_20250527.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (123/256): stock_daily_cctvnews_20250528.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (124/256): stock_daily_cctvnews_20250529.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (125/256): stock_daily_cctvnews_20250530.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (126/256): stock_daily_cctvnews_20250531.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (127/256): stock_daily_cctvnews_20250601.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (128/256): stock_daily_cctvnews_20250602.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (129/256): stock_daily_cctvnews_20250603.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (130/256): stock_daily_cctvnews_20250604.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (131/256): stock_daily_cctvnews_20250605.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (132/256): stock_daily_cctvnews_20250606.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (133/256): stock_daily_cctvnews_20250607.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (134/256): stock_daily_cctvnews_20250608.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (135/256): stock_daily_cctvnews_20250609.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (136/256): stock_daily_cctvnews_20250610.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (137/256): stock_daily_cctvnews_20250611.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (138/256): stock_daily_cctvnews_20250612.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (139/256): stock_daily_cctvnews_20250613.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (140/256): stock_daily_cctvnews_20250614.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (141/256): stock_daily_cctvnews_20250615.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (142/256): stock_daily_cctvnews_20250616.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (143/256): stock_daily_cctvnews_20250617.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (144/256): stock_daily_cctvnews_20250618.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (145/256): stock_daily_cctvnews_20250619.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (146/256): stock_daily_cctvnews_20250620.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (147/256): stock_daily_cctvnews_20250621.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (148/256): stock_daily_cctvnews_20250622.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (149/256): stock_daily_cctvnews_20250623.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (150/256): stock_daily_cctvnews_20250624.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (151/256): stock_daily_cctvnews_20250625.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (152/256): stock_daily_cctvnews_20250626.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (153/256): stock_daily_cctvnews_20250627.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (154/256): stock_daily_cctvnews_20250628.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (155/256): stock_daily_cctvnews_20250629.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (156/256): stock_daily_cctvnews_20250630.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (157/256): stock_daily_cctvnews_20250701.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (158/256): stock_daily_cctvnews_20250702.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (159/256): stock_daily_cctvnews_20250703.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (160/256): stock_daily_cctvnews_20250704.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (161/256): stock_daily_cctvnews_20250705.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (162/256): stock_daily_cctvnews_20250706.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (163/256): stock_daily_cctvnews_20250707.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (164/256): stock_daily_cctvnews_20250708.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (165/256): stock_daily_cctvnews_20250709.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (166/256): stock_daily_cctvnews_20250710.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (167/256): stock_daily_cctvnews_20250711.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (168/256): stock_daily_cctvnews_20250712.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (169/256): stock_daily_cctvnews_20250713.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (170/256): stock_daily_cctvnews_20250714.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (171/256): stock_daily_cctvnews_20250715.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (172/256): stock_daily_cctvnews_20250716.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (173/256): stock_daily_cctvnews_20250717.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (174/256): stock_daily_cctvnews_20250718.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (175/256): stock_daily_cctvnews_20250719.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (176/256): stock_daily_cctvnews_20250720.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (177/256): stock_daily_cctvnews_20250721.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (178/256): stock_daily_cctvnews_20250722.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (179/256): stock_daily_cctvnews_20250723.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (180/256): stock_daily_cctvnews_20250724.csv
#   ✅ 成功读取 8 条记录
# 正在处理 (181/256): stock_daily_cctvnews_20250725.csv
#   ✅ 成功读取 9 条记录
# 正在处理 (182/256): stock_daily_cctvnews_20250726.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (183/256): stock_daily_cctvnews_20250727.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (184/256): stock_daily_cctvnews_20250728.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (185/256): stock_daily_cctvnews_20250729.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (186/256): stock_daily_cctvnews_20250730.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (187/256): stock_daily_cctvnews_20250731.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (188/256): stock_daily_cctvnews_20250801.csv
#   ✅ 成功读取 10 条记录
# 正在处理 (189/256): stock_daily_cctvnews_20250802.csv
#   ✅ 成功读取 10 条记录
# 正在处理 (190/256): stock_daily_cctvnews_20250803.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (191/256): stock_daily_cctvnews_20250804.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (192/256): stock_daily_cctvnews_20250805.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (193/256): stock_daily_cctvnews_20250806.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (194/256): stock_daily_cctvnews_20250807.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (195/256): stock_daily_cctvnews_20250808.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (196/256): stock_daily_cctvnews_20250809.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (197/256): stock_daily_cctvnews_20250810.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (198/256): stock_daily_cctvnews_20250811.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (199/256): stock_daily_cctvnews_20250812.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (200/256): stock_daily_cctvnews_20250813.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (201/256): stock_daily_cctvnews_20250814.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (202/256): stock_daily_cctvnews_20250815.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (203/256): stock_daily_cctvnews_20250816.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (204/256): stock_daily_cctvnews_20250817.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (205/256): stock_daily_cctvnews_20250818.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (206/256): stock_daily_cctvnews_20250819.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (207/256): stock_daily_cctvnews_20250820.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (208/256): stock_daily_cctvnews_20250821.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (209/256): stock_daily_cctvnews_20250822.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (210/256): stock_daily_cctvnews_20250823.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (211/256): stock_daily_cctvnews_20250824.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (212/256): stock_daily_cctvnews_20250825.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (213/256): stock_daily_cctvnews_20250826.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (214/256): stock_daily_cctvnews_20250827.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (215/256): stock_daily_cctvnews_20250828.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (216/256): stock_daily_cctvnews_20250829.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (217/256): stock_daily_cctvnews_20250830.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (218/256): stock_daily_cctvnews_20250831.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (219/256): stock_daily_cctvnews_20250901.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (220/256): stock_daily_cctvnews_20250902.csv
#   ✅ 成功读取 24 条记录
# 正在处理 (221/256): stock_daily_cctvnews_20250903.csv
#   ✅ 成功读取 10 条记录
# 正在处理 (222/256): stock_daily_cctvnews_20250904.csv
#   ✅ 成功读取 22 条记录
# 正在处理 (223/256): stock_daily_cctvnews_20250905.csv
#   ✅ 成功读取 18 条记录
# 正在处理 (224/256): stock_daily_cctvnews_20250906.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (225/256): stock_daily_cctvnews_20250907.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (226/256): stock_daily_cctvnews_20250908.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (227/256): stock_daily_cctvnews_20250909.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (228/256): stock_daily_cctvnews_20250910.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (229/256): stock_daily_cctvnews_20250911.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (230/256): stock_daily_cctvnews_20250912.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (231/256): stock_daily_cctvnews_20250913.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (232/256): stock_daily_cctvnews_20250914.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (233/256): stock_daily_cctvnews_20250915.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (234/256): stock_daily_cctvnews_20250916.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (235/256): stock_daily_cctvnews_20250917.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (236/256): stock_daily_cctvnews_20250918.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (237/256): stock_daily_cctvnews_20250919.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (238/256): stock_daily_cctvnews_20250920.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (239/256): stock_daily_cctvnews_20250921.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (240/256): stock_daily_cctvnews_20250922.csv
#   ✅ 成功读取 17 条记录
# 正在处理 (241/256): stock_daily_cctvnews_20250923.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (242/256): stock_daily_cctvnews_20250924.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (243/256): stock_daily_cctvnews_20250925.csv
#   ✅ 成功读取 16 条记录
# 正在处理 (244/256): stock_daily_cctvnews_20250926.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (245/256): stock_daily_cctvnews_20250927.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (246/256): stock_daily_cctvnews_20250928.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (247/256): stock_daily_cctvnews_20250929.csv
#   ✅ 成功读取 14 条记录
# 正在处理 (248/256): stock_daily_cctvnews_20250930.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (249/256): stock_daily_cctvnews_20251001.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (250/256): stock_daily_cctvnews_20251002.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (251/256): stock_daily_cctvnews_20251003.csv
#   ✅ 成功读取 13 条记录
# 正在处理 (252/256): stock_daily_cctvnews_20251004.csv
#   ✅ 成功读取 11 条记录
# 正在处理 (253/256): stock_daily_cctvnews_20251005.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (254/256): stock_daily_cctvnews_20251006.csv
#   ✅ 成功读取 12 条记录
# 正在处理 (255/256): stock_daily_cctvnews_20251007.csv
#   ✅ 成功读取 15 条记录
# 正在处理 (256/256): stock_daily_cctvnews_20251008.csv
#   ✅ 成功读取 13 条记录
#
# 📊 合并所有数据...
# 📈 总计 3554 条记录（去重后）
# ✅ 成功保存到: d:/workspace/xiaoyao/redis/parquet\stock_daily_cctvnews_to_merged.parquet
# 📊 文件大小: 3.26 MB
#
# 🎉 合并完成！
#
# 📋 验证结果:
#    总行数: 3554
#    日期范围: 2025-01-26 00:00:00 到 2025-10-08 00:00:00
# ⚠️  验证失败: 'stock_code'
# ============================================================

# %% [markdown]
# ## 将新生成的 stock_daily_auction_to_merged.parquet.parquet 与现有的 stock_daily_auction.parquet 合并

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将新生成的 stock_daily_marketcap_to_merged.parquet.parquet 与现有的 stock_daily_marketcap.parquet 合并
"""

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import os


def merge_parquet_files(existing_file, new_file, output_file):
    """
    合并两个 parquet 文件
    
    Args:
        existing_file: 现有的 parquet 文件路径
        new_file: 新的 parquet 文件路径  
        output_file: 输出的合并文件路径
    """
    print("📊 开始合并 parquet 文件...")
    
    try:
        # 读取现有数据
        print(f"📖 读取现有文件: {existing_file}")
        existing_df = pd.read_parquet(existing_file)
        print(f"   现有数据行数: {len(existing_df)}")
        
        # 读取新数据
        print(f"📖 读取新文件: {new_file}")
        new_df = pd.read_parquet(new_file)
        print(f"   新数据行数: {len(new_df)}")
        
        # 合并数据
        print("🔄 合并数据中...")
        combined_df = pd.concat([existing_df, new_df], ignore_index=True)
        
        # 去重（按 date + stock_code）
        print("🧹 去重处理...")
        combined_df = combined_df.drop_duplicates(subset=['date', 'id'])
        
        # 排序
        print("📅 按日期排序...")
        combined_df = combined_df.sort_values(['date', 'id']).reset_index(drop=True)
        
        print(f"📈 合并后总行数: {len(combined_df)}")
        
        # 确保输出目录存在
        output_dir = os.path.dirname(output_file)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)
        
        # 转换为 pyarrow Table
        table = pa.Table.from_pandas(combined_df)
        
        # 写入 parquet（使用与源文件相同的格式）
        print(f"💾 保存合并结果: {output_file}")
        pq.write_table(
            table,
            output_file,
            compression='snappy',
            version='2.6',
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024
        )
        
        print(f"✅ 合并完成！文件大小: {os.path.getsize(output_file) / (1024*1024):.2f} MB")
        
        # 验证结果
        print("\n📋 验证结果:")
        result_df = pd.read_parquet(output_file)
        print(f"   最终行数: {len(result_df)}")
        print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
        print(f"   新闻数量: {result_df['id'].nunique()}")
        
        return True
        
    except Exception as e:
        print(f"❌ 合并失败: {e}")
        return False


def main():
    """主函数"""
    # 设置文件路径

    existing_file = "d:/workspace/xiaoyao/data/stock_daily_cctvnews.parquet"
    new_file = "d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews_to_merged.parquet"
    output_file = "d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews.parquet"

    print("=" * 60)
    print("🚀 开始合并 parquet 文件")
    print("=" * 60)
    
    # 检查文件是否存在
    if not os.path.exists(existing_file):
        print(f"❌ 现有文件不存在: {existing_file}")
        return
    
    if not os.path.exists(new_file):
        print(f"❌ 新文件不存在: {new_file}")
        return
    
    # 执行合并
    success = merge_parquet_files(existing_file, new_file, output_file)
    
    if success:
        print("\n🎉 合并成功！")
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 parquet 文件
# ============================================================
# 📊 开始合并 parquet 文件...
# 📖 读取现有文件: d:/workspace/xiaoyao/data/stock_daily_cctvnews.parquet
#    现有数据行数: 341
# 📖 读取新文件: d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews_to_merged.parquet
#    新数据行数: 3554
# 🔄 合并数据中...
# 🧹 去重处理...
# 📅 按日期排序...
# 📈 合并后总行数: 3895
# 💾 保存合并结果: d:/workspace/xiaoyao/redis/parquet/stock_daily_cctvnews.parquet
# ✅ 合并完成！文件大小: 3.57 MB
#
# 📋 验证结果:
#    最终行数: 3895
#    日期范围: 2025-01-01 00:00:00 到 2025-10-08 00:00:00
#    新闻数量: 3895
#
# 🎉 合并成功！
# ============================================================

# %% [markdown]
# ## 删除已使用的csv

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
删除指定目录下的 stock_***.csv 文件
"""

import os
import glob
from pathlib import Path


def delete_stock_csv_files(target_directory, pattern="stock_*.csv"):
    #删除满足模式的所有文件
    files = glob.glob(os.path.join(target_directory, pattern))
    for file in files:
        try:
            os.remove(file)
            print(f"已删除：{file}")
        except Exception as e:
            print(f"删除 {file} 失败：{e}")

if __name__ == "__main__":
    delete_stock_csv_files(r'D:\workspace\xiaoyao\redis','stock_daily_cctvnews_*.csv')
    print("\n" + "=" * 60)
# Out:
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250126.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250127.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250128.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250129.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250130.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250131.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250201.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250202.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250203.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250204.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250205.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250206.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250207.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250208.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250209.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250210.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250211.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250212.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250213.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250214.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250215.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250216.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250217.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250218.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250219.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250220.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250221.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250222.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250223.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250224.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250225.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250226.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250227.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250228.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250301.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250302.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250303.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250304.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250305.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250306.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250307.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250308.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250309.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250310.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250311.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250312.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250313.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250314.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250315.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250316.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250317.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250318.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250319.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250320.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250321.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250322.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250323.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250324.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250325.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250326.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250327.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250328.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250329.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250330.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250331.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250401.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250402.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250403.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250404.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250405.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250406.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250407.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250408.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250409.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250410.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250411.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250412.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250413.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250414.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250415.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250416.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250417.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250418.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250419.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250420.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250421.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250422.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250423.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250424.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250425.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250426.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250427.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250428.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250429.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250430.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250501.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250502.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250503.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250504.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250505.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250506.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250507.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250508.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250509.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250510.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250511.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250512.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250513.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250514.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250515.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250516.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250517.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250518.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250519.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250520.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250521.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250522.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250523.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250524.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250525.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250526.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250527.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250528.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250529.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250530.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250531.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250601.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250602.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250603.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250604.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250605.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250606.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250607.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250608.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250609.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250610.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250611.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250612.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250613.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250614.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250615.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250616.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250617.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250618.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250619.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250620.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250621.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250622.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250623.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250624.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250625.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250626.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250627.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250628.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250629.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250630.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250701.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250702.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250703.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250704.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250705.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250706.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250707.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250708.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250709.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250710.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250711.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250712.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250713.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250714.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250715.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250716.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250717.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250718.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250719.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250720.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250721.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250722.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250723.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250724.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250725.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250726.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250727.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250728.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250729.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250730.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250731.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250801.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250802.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250803.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250804.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250805.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250806.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250807.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250808.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250809.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250810.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250811.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250812.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250813.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250814.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250815.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250816.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250817.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250818.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250819.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250820.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250821.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250822.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250823.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250824.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250825.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250826.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250827.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250828.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250829.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250830.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250831.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250901.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250902.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250903.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250904.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250905.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250906.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250907.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250908.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250909.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250910.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250911.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250912.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250913.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250914.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250915.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250916.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250917.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250918.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250919.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250920.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250921.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250922.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250923.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250924.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250925.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250926.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250927.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250928.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250929.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20250930.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251001.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251002.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251003.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251004.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251005.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251006.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251007.csv
# 已删除：D:\workspace\xiaoyao\redis\stock_daily_cctvnews_20251008.csv
#
# ============================================================

# %% [markdown]
# ## 将新的parquet文件移动到data目录覆盖原文件

# %%
# 将子目录下的某个parquet文件移动到指定目录
import os
import shutil

# 定义源目录和目标目录
source_dir = "D:\\workspace\\xiaoyao\\redis\\parquet"
target_dir = "D:\\workspace\\xiaoyao\\data"

# 确保目标目录存在
os.makedirs(target_dir, exist_ok=True)

# 定义要移动的文件
file_to_move = "stock_daily_cctvnews.parquet"

# 构建源文件的完整路径
source_file_path = os.path.join(source_dir, file_to_move)

# 构建目标文件的完整路径
target_file_path = os.path.join(target_dir, file_to_move)

# 检查源文件是否存在
if os.path.exists(source_file_path):
    # 移动文件
    shutil.move(source_file_path, target_file_path)
    print(f"Moved: {file_to_move} to {target_dir}")
else:
    print(f"File not found: {file_to_move}")

# 删除指定的parquet文件
file_to_delete = os.path.join(source_dir, 'stock_daily_cctvnews_to_merged.parquet')
if os.path.exists(file_to_delete):
    os.remove(file_to_delete)
    print(f"Deleted: {file_to_move} from {source_dir}")
else:
    print(f"File not found: {file_to_move} in {source_dir}")
# Out:
# Moved: stock_daily_cctvnews.parquet to D:\workspace\xiaoyao\data
# Deleted: stock_daily_cctvnews.parquet from D:\workspace\xiaoyao\redis\parquet
