# %% [markdown]
# ## 1.下载数据

# %%
import redis
import pickle
import time
import uuid
import pandas as pd
from io import StringIO
from typing import Any, Optional
from datetime import datetime, timedelta

class RemoteSender:
    def __init__(self, host='*', port=6379, password='*'):
        self.redis = redis.Redis(
            host=host, port=port, password=password,
            decode_responses=False
        )
        self.task_queue = 'function_calls'
        self.result_queue = 'function_results'
        self._test_connection()
        print(f"✅ 发送端pandas版本：{pd.__version__}")

    def _test_connection(self):
        try:
            self.redis.ping()
            print("✅ 发送端：Redis连接成功")
        except Exception as e:
            print(f"❌ 发送端：连接失败 - {e}")
            raise

    def call_remote_function(self, func_name: str, *args, **kwargs) -> Any:
        task_id = f"task_{uuid.uuid4().hex[:8]}"
        task = {
            'func_name': func_name,
            'args': args,
            'kwargs': kwargs,
            'task_id': task_id
        }
        self.redis.rpush(self.task_queue, pickle.dumps(task))
        print(f"📤 已调用远程函数：{func_name}（任务ID：{task_id}）")
        return self._get_result(task_id)

    def _get_result(self, task_id: str, timeout=300) -> Any:
        start_time = time.time()
        while time.time() - start_time < timeout:
            result_data = self.redis.blpop(self.result_queue, timeout=10)
            if not result_data:
                continue

            _, res_bytes = result_data
            result = pickle.loads(res_bytes)
            if result['task_id'] == task_id:
                if result['status'] == 'success':
                    return result['result']  # 返回CSV字符串
                else:
                    raise Exception(f"远程执行失败：{result['error']}")
            self.redis.rpush(self.result_queue, res_bytes)
        raise TimeoutError("任务超时")

    def save_to_csv(self, csv_str: Optional[str], filename: str) -> bool:
        """将CSV字符串保存为本地CSV文件（替代Parquet）"""
        if not csv_str:
            print("⚠️ 数据为空，不保存")
            return False
        try:
            # 从CSV字符串恢复DataFrame（兼容所有pandas版本）
            df = pd.read_csv(StringIO(csv_str))
            # 保存为CSV文件
            df.to_csv(filename, index=False)
            print(f"✅ 保存成功：{filename}（{len(df)}条记录）")
            return True
        except Exception as e:
            print(f"❌ 保存失败：{e}")
            return False

def generate_date_range(start_date_str: str, end_date_str: str) -> list:
    """生成从开始日期到结束日期的所有日期字符串（YYYYMMDD格式）"""
    dates = []
    try:
        start_date = datetime.strptime(start_date_str, '%Y%m%d')
        end_date = datetime.strptime(end_date_str, '%Y%m%d')
        
        if start_date > end_date:
            raise ValueError("开始日期晚于结束日期")
            
        current_date = start_date
        while current_date <= end_date:
            dates.append(current_date.strftime('%Y%m%d'))
            current_date += timedelta(days=1)
    except Exception as e:
        print(f"日期处理错误：{e}")
    return dates

if __name__ == "__main__":

    # 从配置文件读取Redis连接信息
    with open('redis.conf', 'r') as f:
        for line in f:
            if line.startswith('host='):
                host = line.split('=')[1].strip()
            elif line.startswith('port='):
                port = int(line.split('=')[1].strip())
            elif line.startswith('password='):
                password = line.split('=')[1].strip()
    # 初始化Redis发送端
    sender = RemoteSender(host=host, port=port, password=password)
    
    # 定义日期范围：从20250516到20250923
    # 读取../data/stock_daily_price.parquet文件，获取最大的日期+1，是start_date
    #df = pd.read_parquet('../data/index_daily_auction.parquet')
    #start_date = (df['date'].max() + timedelta(days=1)).strftime('%Y%m%d')
    start_date = '20240101' 
    
    # 获取当日日期-1，是end_date
    end_date = (datetime.today() - timedelta(days=1)).strftime('%Y%m%d')
    end_date = '20241231'
    # 生成日期列表
    date_list = generate_date_range(start_date, end_date)
    print(f"=== 共需获取 {len(date_list)} 天的数据 ===")
    
    # 循环调用获取每日数据
    for i, date in enumerate(date_list, 1):
        print(f"\n=== 正在处理 {i}/{len(date_list)}：{date} ===")
        try:
            # 调用远程函数获取当日数据
            csv_data = sender.call_remote_function('fetch_index_auction_data', date)
            # 保存为CSV文件，文件名包含日期
            sender.save_to_csv(csv_data, f'index_daily_auction_{date}.csv')
            
            # 适当延迟，避免请求过于频繁
            time.sleep(0.05)
        except Exception as e:
            print(f"❌ {date} 处理失败：{e}")
            # 失败后也延迟一下，避免快速重试导致的问题
            time.sleep(2)
    
    print("\n=== 所有日期处理完成 ===")
# Out:
# ✅ 发送端：Redis连接成功
# ✅ 发送端pandas版本：2.3.2
# === 共需获取 366 天的数据 ===
#
# === 正在处理 1/366：20240101 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ab6a6177）
# ⚠️ 数据为空，不保存
#
# === 正在处理 2/366：20240102 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f931c376）
# ✅ 保存成功：index_daily_auction_20240102.csv（539条记录）
#
# === 正在处理 3/366：20240103 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5f7d0ee9）
# ✅ 保存成功：index_daily_auction_20240103.csv（539条记录）
#
# === 正在处理 4/366：20240104 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fd25825c）
# ✅ 保存成功：index_daily_auction_20240104.csv（539条记录）
#
# === 正在处理 5/366：20240105 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_418d6f0a）
# ✅ 保存成功：index_daily_auction_20240105.csv（539条记录）
#
# === 正在处理 6/366：20240106 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3ce7971b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 7/366：20240107 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_77cac0b5）
# ⚠️ 数据为空，不保存
#
# === 正在处理 8/366：20240108 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f1d65634）
# ✅ 保存成功：index_daily_auction_20240108.csv（539条记录）
#
# === 正在处理 9/366：20240109 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5faae8cc）
# ✅ 保存成功：index_daily_auction_20240109.csv（539条记录）
#
# === 正在处理 10/366：20240110 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a849ba7c）
# ✅ 保存成功：index_daily_auction_20240110.csv（539条记录）
#
# === 正在处理 11/366：20240111 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_70945985）
# ✅ 保存成功：index_daily_auction_20240111.csv（539条记录）
#
# === 正在处理 12/366：20240112 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_1cc03621）
# ✅ 保存成功：index_daily_auction_20240112.csv（539条记录）
#
# === 正在处理 13/366：20240113 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_71ce3b79）
# ⚠️ 数据为空，不保存
#
# === 正在处理 14/366：20240114 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6040fd2d）
# ⚠️ 数据为空，不保存
#
# === 正在处理 15/366：20240115 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_b18dfe40）
# ✅ 保存成功：index_daily_auction_20240115.csv（539条记录）
#
# === 正在处理 16/366：20240116 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_bcc54e5f）
# ✅ 保存成功：index_daily_auction_20240116.csv（539条记录）
#
# === 正在处理 17/366：20240117 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_cc6ef091）
# ✅ 保存成功：index_daily_auction_20240117.csv（539条记录）
#
# === 正在处理 18/366：20240118 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_44f95f31）
# ✅ 保存成功：index_daily_auction_20240118.csv（539条记录）
#
# === 正在处理 19/366：20240119 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d654e195）
# ✅ 保存成功：index_daily_auction_20240119.csv（539条记录）
#
# === 正在处理 20/366：20240120 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_54035ab1）
# ⚠️ 数据为空，不保存
#
# === 正在处理 21/366：20240121 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5a703697）
# ⚠️ 数据为空，不保存
#
# === 正在处理 22/366：20240122 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4ef4774b）
# ✅ 保存成功：index_daily_auction_20240122.csv（539条记录）
#
# === 正在处理 23/366：20240123 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8a91079e）
# ✅ 保存成功：index_daily_auction_20240123.csv（539条记录）
#
# === 正在处理 24/366：20240124 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f69f0661）
# ✅ 保存成功：index_daily_auction_20240124.csv（539条记录）
#
# === 正在处理 25/366：20240125 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0025e604）
# ✅ 保存成功：index_daily_auction_20240125.csv（539条记录）
#
# === 正在处理 26/366：20240126 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fe5d05a9）
# ✅ 保存成功：index_daily_auction_20240126.csv（539条记录）
#
# === 正在处理 27/366：20240127 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6274c340）
# ⚠️ 数据为空，不保存
#
# === 正在处理 28/366：20240128 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e786e131）
# ⚠️ 数据为空，不保存
#
# === 正在处理 29/366：20240129 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4325d207）
# ✅ 保存成功：index_daily_auction_20240129.csv（539条记录）
#
# === 正在处理 30/366：20240130 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ecd94b74）
# ✅ 保存成功：index_daily_auction_20240130.csv（539条记录）
#
# === 正在处理 31/366：20240131 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_06c6a5d3）
# ✅ 保存成功：index_daily_auction_20240131.csv（539条记录）
#
# === 正在处理 32/366：20240201 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d99d141a）
# ✅ 保存成功：index_daily_auction_20240201.csv（539条记录）
#
# === 正在处理 33/366：20240202 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a7a7df0c）
# ✅ 保存成功：index_daily_auction_20240202.csv（539条记录）
#
# === 正在处理 34/366：20240203 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_7344051f）
# ⚠️ 数据为空，不保存
#
# === 正在处理 35/366：20240204 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fdbbefef）
# ⚠️ 数据为空，不保存
#
# === 正在处理 36/366：20240205 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6f2bec28）
# ✅ 保存成功：index_daily_auction_20240205.csv（539条记录）
#
# === 正在处理 37/366：20240206 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_55f11ad2）
# ✅ 保存成功：index_daily_auction_20240206.csv（539条记录）
#
# === 正在处理 38/366：20240207 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_330ef502）
# ✅ 保存成功：index_daily_auction_20240207.csv（539条记录）
#
# === 正在处理 39/366：20240208 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f488d04d）
# ✅ 保存成功：index_daily_auction_20240208.csv（539条记录）
#
# === 正在处理 40/366：20240209 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_dccc0daf）
# ⚠️ 数据为空，不保存
#
# === 正在处理 41/366：20240210 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e1400739）
# ⚠️ 数据为空，不保存
#
# === 正在处理 42/366：20240211 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_009fbe17）
# ⚠️ 数据为空，不保存
#
# === 正在处理 43/366：20240212 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9d5bcd5b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 44/366：20240213 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ccfcfaad）
# ⚠️ 数据为空，不保存
#
# === 正在处理 45/366：20240214 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_c06197c6）
# ⚠️ 数据为空，不保存
#
# === 正在处理 46/366：20240215 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_b3b015e7）
# ⚠️ 数据为空，不保存
#
# === 正在处理 47/366：20240216 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f4906238）
# ⚠️ 数据为空，不保存
#
# === 正在处理 48/366：20240217 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f5f03b0e）
# ⚠️ 数据为空，不保存
#
# === 正在处理 49/366：20240218 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_860f6c1c）
# ⚠️ 数据为空，不保存
#
# === 正在处理 50/366：20240219 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_22e5ecc7）
# ✅ 保存成功：index_daily_auction_20240219.csv（539条记录）
#
# === 正在处理 51/366：20240220 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_c0eba404）
# ✅ 保存成功：index_daily_auction_20240220.csv（539条记录）
#
# === 正在处理 52/366：20240221 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_da49807e）
# ✅ 保存成功：index_daily_auction_20240221.csv（539条记录）
#
# === 正在处理 53/366：20240222 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3398b52f）
# ✅ 保存成功：index_daily_auction_20240222.csv（539条记录）
#
# === 正在处理 54/366：20240223 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0cf07190）
# ✅ 保存成功：index_daily_auction_20240223.csv（539条记录）
#
# === 正在处理 55/366：20240224 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_44cf70d8）
# ⚠️ 数据为空，不保存
#
# === 正在处理 56/366：20240225 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_87006f26）
# ⚠️ 数据为空，不保存
#
# === 正在处理 57/366：20240226 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_1f957455）
# ✅ 保存成功：index_daily_auction_20240226.csv（539条记录）
#
# === 正在处理 58/366：20240227 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0d9a93f2）
# ✅ 保存成功：index_daily_auction_20240227.csv（539条记录）
#
# === 正在处理 59/366：20240228 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fdf4bde1）
# ✅ 保存成功：index_daily_auction_20240228.csv（539条记录）
#
# === 正在处理 60/366：20240229 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8a5be96c）
# ✅ 保存成功：index_daily_auction_20240229.csv（539条记录）
#
# === 正在处理 61/366：20240301 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_66dc1391）
# ✅ 保存成功：index_daily_auction_20240301.csv（539条记录）
#
# === 正在处理 62/366：20240302 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_14a6a38d）
# ⚠️ 数据为空，不保存
#
# === 正在处理 63/366：20240303 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8250ed3d）
# ⚠️ 数据为空，不保存
#
# === 正在处理 64/366：20240304 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_30f77d24）
# ✅ 保存成功：index_daily_auction_20240304.csv（539条记录）
#
# === 正在处理 65/366：20240305 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_b9f0ce72）
# ✅ 保存成功：index_daily_auction_20240305.csv（539条记录）
#
# === 正在处理 66/366：20240306 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e4e600ce）
# ✅ 保存成功：index_daily_auction_20240306.csv（539条记录）
#
# === 正在处理 67/366：20240307 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_1f104287）
# ✅ 保存成功：index_daily_auction_20240307.csv（539条记录）
#
# === 正在处理 68/366：20240308 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_12de2222）
# ✅ 保存成功：index_daily_auction_20240308.csv（539条记录）
#
# === 正在处理 69/366：20240309 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_c7350647）
# ⚠️ 数据为空，不保存
#
# === 正在处理 70/366：20240310 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_11717231）
# ⚠️ 数据为空，不保存
#
# === 正在处理 71/366：20240311 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fcdeb010）
# ✅ 保存成功：index_daily_auction_20240311.csv（539条记录）
#
# === 正在处理 72/366：20240312 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_57d138a1）
# ✅ 保存成功：index_daily_auction_20240312.csv（539条记录）
#
# === 正在处理 73/366：20240313 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_22965116）
# ✅ 保存成功：index_daily_auction_20240313.csv（539条记录）
#
# === 正在处理 74/366：20240314 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_84359d25）
# ✅ 保存成功：index_daily_auction_20240314.csv（539条记录）
#
# === 正在处理 75/366：20240315 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_13aab326）
# ✅ 保存成功：index_daily_auction_20240315.csv（539条记录）
#
# === 正在处理 76/366：20240316 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ced5d4fc）
# ⚠️ 数据为空，不保存
#
# === 正在处理 77/366：20240317 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2ce6c786）
# ⚠️ 数据为空，不保存
#
# === 正在处理 78/366：20240318 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a9033a2c）
# ✅ 保存成功：index_daily_auction_20240318.csv（539条记录）
#
# === 正在处理 79/366：20240319 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e3cc3a64）
# ✅ 保存成功：index_daily_auction_20240319.csv（539条记录）
#
# === 正在处理 80/366：20240320 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_97396d15）
# ✅ 保存成功：index_daily_auction_20240320.csv（539条记录）
#
# === 正在处理 81/366：20240321 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_abbcaa7c）
# ✅ 保存成功：index_daily_auction_20240321.csv（540条记录）
#
# === 正在处理 82/366：20240322 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2aeaee75）
# ✅ 保存成功：index_daily_auction_20240322.csv（540条记录）
#
# === 正在处理 83/366：20240323 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d3ab9f2f）
# ⚠️ 数据为空，不保存
#
# === 正在处理 84/366：20240324 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2dff816e）
# ⚠️ 数据为空，不保存
#
# === 正在处理 85/366：20240325 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_201a5c56）
# ✅ 保存成功：index_daily_auction_20240325.csv（540条记录）
#
# === 正在处理 86/366：20240326 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a5b1ddbe）
# ✅ 保存成功：index_daily_auction_20240326.csv（540条记录）
#
# === 正在处理 87/366：20240327 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ac4aa6d0）
# ✅ 保存成功：index_daily_auction_20240327.csv（540条记录）
#
# === 正在处理 88/366：20240328 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_03c31787）
# ✅ 保存成功：index_daily_auction_20240328.csv（540条记录）
#
# === 正在处理 89/366：20240329 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4d9aacc4）
# ✅ 保存成功：index_daily_auction_20240329.csv（540条记录）
#
# === 正在处理 90/366：20240330 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_50798594）
# ⚠️ 数据为空，不保存
#
# === 正在处理 91/366：20240331 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_27ef22bf）
# ⚠️ 数据为空，不保存
#
# === 正在处理 92/366：20240401 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8ad4fff0）
# ✅ 保存成功：index_daily_auction_20240401.csv（540条记录）
#
# === 正在处理 93/366：20240402 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ae02f5ec）
# ✅ 保存成功：index_daily_auction_20240402.csv（540条记录）
#
# === 正在处理 94/366：20240403 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8f2c7328）
# ✅ 保存成功：index_daily_auction_20240403.csv（540条记录）
#
# === 正在处理 95/366：20240404 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3ddd3951）
# ⚠️ 数据为空，不保存
#
# === 正在处理 96/366：20240405 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0ce89a50）
# ⚠️ 数据为空，不保存
#
# === 正在处理 97/366：20240406 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0ddc0d5d）
# ⚠️ 数据为空，不保存
#
# === 正在处理 98/366：20240407 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4faaa6c9）
# ⚠️ 数据为空，不保存
#
# === 正在处理 99/366：20240408 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_41bdd507）
# ✅ 保存成功：index_daily_auction_20240408.csv（540条记录）
#
# === 正在处理 100/366：20240409 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0966dee5）
# ✅ 保存成功：index_daily_auction_20240409.csv（540条记录）
#
# === 正在处理 101/366：20240410 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_98035598）
# ✅ 保存成功：index_daily_auction_20240410.csv（540条记录）
#
# === 正在处理 102/366：20240411 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ba52143a）
# ✅ 保存成功：index_daily_auction_20240411.csv（540条记录）
#
# === 正在处理 103/366：20240412 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_df1b623d）
# ✅ 保存成功：index_daily_auction_20240412.csv（540条记录）
#
# === 正在处理 104/366：20240413 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d0162e87）
# ⚠️ 数据为空，不保存
#
# === 正在处理 105/366：20240414 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2e46c2f4）
# ⚠️ 数据为空，不保存
#
# === 正在处理 106/366：20240415 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_68382f37）
# ✅ 保存成功：index_daily_auction_20240415.csv（540条记录）
#
# === 正在处理 107/366：20240416 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5d783ccd）
# ✅ 保存成功：index_daily_auction_20240416.csv（540条记录）
#
# === 正在处理 108/366：20240417 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_93f1a8df）
# ✅ 保存成功：index_daily_auction_20240417.csv（540条记录）
#
# === 正在处理 109/366：20240418 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_13727120）
# ✅ 保存成功：index_daily_auction_20240418.csv（540条记录）
#
# === 正在处理 110/366：20240419 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e71d1d97）
# ✅ 保存成功：index_daily_auction_20240419.csv（540条记录）
#
# === 正在处理 111/366：20240420 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ed0ac6b8）
# ⚠️ 数据为空，不保存
#
# === 正在处理 112/366：20240421 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5e9191ad）
# ⚠️ 数据为空，不保存
#
# === 正在处理 113/366：20240422 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_87d64512）
# ✅ 保存成功：index_daily_auction_20240422.csv（540条记录）
#
# === 正在处理 114/366：20240423 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_57d81249）
# ✅ 保存成功：index_daily_auction_20240423.csv（537条记录）
#
# === 正在处理 115/366：20240424 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0857d657）
# ✅ 保存成功：index_daily_auction_20240424.csv（537条记录）
#
# === 正在处理 116/366：20240425 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_52a25969）
# ✅ 保存成功：index_daily_auction_20240425.csv（537条记录）
#
# === 正在处理 117/366：20240426 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d9d9d7f6）
# ✅ 保存成功：index_daily_auction_20240426.csv（537条记录）
#
# === 正在处理 118/366：20240427 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e7a8f38b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 119/366：20240428 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3c7d0f30）
# ⚠️ 数据为空，不保存
#
# === 正在处理 120/366：20240429 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_aa893b22）
# ✅ 保存成功：index_daily_auction_20240429.csv（537条记录）
#
# === 正在处理 121/366：20240430 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_882dea22）
# ✅ 保存成功：index_daily_auction_20240430.csv（537条记录）
#
# === 正在处理 122/366：20240501 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8e63db24）
# ⚠️ 数据为空，不保存
#
# === 正在处理 123/366：20240502 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_85b1f105）
# ⚠️ 数据为空，不保存
#
# === 正在处理 124/366：20240503 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3fbb3318）
# ⚠️ 数据为空，不保存
#
# === 正在处理 125/366：20240504 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_bd1e5d37）
# ⚠️ 数据为空，不保存
#
# === 正在处理 126/366：20240505 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6cc74f7e）
# ⚠️ 数据为空，不保存
#
# === 正在处理 127/366：20240506 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5533a159）
# ✅ 保存成功：index_daily_auction_20240506.csv（537条记录）
#
# === 正在处理 128/366：20240507 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d842600f）
# ✅ 保存成功：index_daily_auction_20240507.csv（537条记录）
#
# === 正在处理 129/366：20240508 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_06cbba3b）
# ✅ 保存成功：index_daily_auction_20240508.csv（537条记录）
#
# === 正在处理 130/366：20240509 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_c199401a）
# ✅ 保存成功：index_daily_auction_20240509.csv（537条记录）
#
# === 正在处理 131/366：20240510 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_51ee0ee4）
# ✅ 保存成功：index_daily_auction_20240510.csv（537条记录）
#
# === 正在处理 132/366：20240511 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_257b6a0a）
# ⚠️ 数据为空，不保存
#
# === 正在处理 133/366：20240512 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0ae208a0）
# ⚠️ 数据为空，不保存
#
# === 正在处理 134/366：20240513 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fe3e3aac）
# ✅ 保存成功：index_daily_auction_20240513.csv（537条记录）
#
# === 正在处理 135/366：20240514 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9ffb5b81）
# ✅ 保存成功：index_daily_auction_20240514.csv（537条记录）
#
# === 正在处理 136/366：20240515 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_cd518943）
# ✅ 保存成功：index_daily_auction_20240515.csv（537条记录）
#
# === 正在处理 137/366：20240516 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2a9d2308）
# ✅ 保存成功：index_daily_auction_20240516.csv（537条记录）
#
# === 正在处理 138/366：20240517 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f28273e4）
# ✅ 保存成功：index_daily_auction_20240517.csv（537条记录）
#
# === 正在处理 139/366：20240518 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fd6edc0b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 140/366：20240519 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_55daa744）
# ⚠️ 数据为空，不保存
#
# === 正在处理 141/366：20240520 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f73bd6d4）
# ✅ 保存成功：index_daily_auction_20240520.csv（537条记录）
#
# === 正在处理 142/366：20240521 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2be9c896）
# ✅ 保存成功：index_daily_auction_20240521.csv（537条记录）
#
# === 正在处理 143/366：20240522 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3e21624d）
# ✅ 保存成功：index_daily_auction_20240522.csv（537条记录）
#
# === 正在处理 144/366：20240523 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_b8d4632b）
# ✅ 保存成功：index_daily_auction_20240523.csv（537条记录）
#
# === 正在处理 145/366：20240524 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8d3c2eb2）
# ✅ 保存成功：index_daily_auction_20240524.csv（537条记录）
#
# === 正在处理 146/366：20240525 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ae1d2e98）
# ⚠️ 数据为空，不保存
#
# === 正在处理 147/366：20240526 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ca5bd2c7）
# ⚠️ 数据为空，不保存
#
# === 正在处理 148/366：20240527 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_c05ffb3d）
# ✅ 保存成功：index_daily_auction_20240527.csv（537条记录）
#
# === 正在处理 149/366：20240528 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a41bb886）
# ✅ 保存成功：index_daily_auction_20240528.csv（537条记录）
#
# === 正在处理 150/366：20240529 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_24e6e0b1）
# ✅ 保存成功：index_daily_auction_20240529.csv（537条记录）
#
# === 正在处理 151/366：20240530 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8e20b0ba）
# ✅ 保存成功：index_daily_auction_20240530.csv（537条记录）
#
# === 正在处理 152/366：20240531 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_b3142d80）
# ✅ 保存成功：index_daily_auction_20240531.csv（537条记录）
#
# === 正在处理 153/366：20240601 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a1315120）
# ⚠️ 数据为空，不保存
#
# === 正在处理 154/366：20240602 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_337ad06c）
# ⚠️ 数据为空，不保存
#
# === 正在处理 155/366：20240603 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e41cae1c）
# ✅ 保存成功：index_daily_auction_20240603.csv（537条记录）
#
# === 正在处理 156/366：20240604 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6069f34f）
# ✅ 保存成功：index_daily_auction_20240604.csv（537条记录）
#
# === 正在处理 157/366：20240605 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e6fd1f4e）
# ✅ 保存成功：index_daily_auction_20240605.csv（537条记录）
#
# === 正在处理 158/366：20240606 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f12fa955）
# ✅ 保存成功：index_daily_auction_20240606.csv（537条记录）
#
# === 正在处理 159/366：20240607 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e4a6e0c4）
# ✅ 保存成功：index_daily_auction_20240607.csv（537条记录）
#
# === 正在处理 160/366：20240608 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9d99a70c）
# ⚠️ 数据为空，不保存
#
# === 正在处理 161/366：20240609 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_52242d8f）
# ⚠️ 数据为空，不保存
#
# === 正在处理 162/366：20240610 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2d0197aa）
# ⚠️ 数据为空，不保存
#
# === 正在处理 163/366：20240611 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_59dd4337）
# ✅ 保存成功：index_daily_auction_20240611.csv（537条记录）
#
# === 正在处理 164/366：20240612 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_799a3c26）
# ✅ 保存成功：index_daily_auction_20240612.csv（537条记录）
#
# === 正在处理 165/366：20240613 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_19701677）
# ✅ 保存成功：index_daily_auction_20240613.csv（537条记录）
#
# === 正在处理 166/366：20240614 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d5123cf7）
# ✅ 保存成功：index_daily_auction_20240614.csv（537条记录）
#
# === 正在处理 167/366：20240615 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_11c6ead8）
# ⚠️ 数据为空，不保存
#
# === 正在处理 168/366：20240616 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6fbdd0a0）
# ⚠️ 数据为空，不保存
#
# === 正在处理 169/366：20240617 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9f784862）
# ✅ 保存成功：index_daily_auction_20240617.csv（537条记录）
#
# === 正在处理 170/366：20240618 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_568c6dbf）
# ✅ 保存成功：index_daily_auction_20240618.csv（537条记录）
#
# === 正在处理 171/366：20240619 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e44d3ff9）
# ✅ 保存成功：index_daily_auction_20240619.csv（537条记录）
#
# === 正在处理 172/366：20240620 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_477a5cf2）
# ✅ 保存成功：index_daily_auction_20240620.csv（537条记录）
#
# === 正在处理 173/366：20240621 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d2631bcb）
# ✅ 保存成功：index_daily_auction_20240621.csv（537条记录）
#
# === 正在处理 174/366：20240622 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5339cccf）
# ⚠️ 数据为空，不保存
#
# === 正在处理 175/366：20240623 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_bf68f488）
# ⚠️ 数据为空，不保存
#
# === 正在处理 176/366：20240624 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_36568f4b）
# ✅ 保存成功：index_daily_auction_20240624.csv（537条记录）
#
# === 正在处理 177/366：20240625 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fb0779f8）
# ✅ 保存成功：index_daily_auction_20240625.csv（537条记录）
#
# === 正在处理 178/366：20240626 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_29255de8）
# ✅ 保存成功：index_daily_auction_20240626.csv（537条记录）
#
# === 正在处理 179/366：20240627 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_7cb7e106）
# ✅ 保存成功：index_daily_auction_20240627.csv（537条记录）
#
# === 正在处理 180/366：20240628 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_1530c714）
# ✅ 保存成功：index_daily_auction_20240628.csv（537条记录）
#
# === 正在处理 181/366：20240629 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_45a3776e）
# ⚠️ 数据为空，不保存
#
# === 正在处理 182/366：20240630 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6f5476f3）
# ⚠️ 数据为空，不保存
#
# === 正在处理 183/366：20240701 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_dba49d04）
# ✅ 保存成功：index_daily_auction_20240701.csv（537条记录）
#
# === 正在处理 184/366：20240702 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ad0b8a38）
# ✅ 保存成功：index_daily_auction_20240702.csv（537条记录）
#
# === 正在处理 185/366：20240703 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f128c744）
# ✅ 保存成功：index_daily_auction_20240703.csv（537条记录）
#
# === 正在处理 186/366：20240704 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3080b59c）
# ✅ 保存成功：index_daily_auction_20240704.csv（537条记录）
#
# === 正在处理 187/366：20240705 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a4924694）
# ✅ 保存成功：index_daily_auction_20240705.csv（537条记录）
#
# === 正在处理 188/366：20240706 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a9aecaf6）
# ⚠️ 数据为空，不保存
#
# === 正在处理 189/366：20240707 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_014015c9）
# ⚠️ 数据为空，不保存
#
# === 正在处理 190/366：20240708 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_88d2aab0）
# ✅ 保存成功：index_daily_auction_20240708.csv（537条记录）
#
# === 正在处理 191/366：20240709 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4a9f8d77）
# ✅ 保存成功：index_daily_auction_20240709.csv（537条记录）
#
# === 正在处理 192/366：20240710 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_82f504a7）
# ✅ 保存成功：index_daily_auction_20240710.csv（537条记录）
#
# === 正在处理 193/366：20240711 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ba672b29）
# ✅ 保存成功：index_daily_auction_20240711.csv（537条记录）
#
# === 正在处理 194/366：20240712 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6441dfc0）
# ✅ 保存成功：index_daily_auction_20240712.csv（537条记录）
#
# === 正在处理 195/366：20240713 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f17b2fb9）
# ⚠️ 数据为空，不保存
#
# === 正在处理 196/366：20240714 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_981285ed）
# ⚠️ 数据为空，不保存
#
# === 正在处理 197/366：20240715 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_39e87105）
# ✅ 保存成功：index_daily_auction_20240715.csv（537条记录）
#
# === 正在处理 198/366：20240716 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a12c5228）
# ✅ 保存成功：index_daily_auction_20240716.csv（537条记录）
#
# === 正在处理 199/366：20240717 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_7c477437）
# ✅ 保存成功：index_daily_auction_20240717.csv（537条记录）
#
# === 正在处理 200/366：20240718 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ff669bcc）
# ✅ 保存成功：index_daily_auction_20240718.csv（537条记录）
#
# === 正在处理 201/366：20240719 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4a416b8d）
# ✅ 保存成功：index_daily_auction_20240719.csv（537条记录）
#
# === 正在处理 202/366：20240720 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0defca8e）
# ⚠️ 数据为空，不保存
#
# === 正在处理 203/366：20240721 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_1fa5d3a9）
# ⚠️ 数据为空，不保存
#
# === 正在处理 204/366：20240722 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_00fb98ec）
# ✅ 保存成功：index_daily_auction_20240722.csv（537条记录）
#
# === 正在处理 205/366：20240723 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e046bc53）
# ✅ 保存成功：index_daily_auction_20240723.csv（537条记录）
#
# === 正在处理 206/366：20240724 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_dac4f8f6）
# ✅ 保存成功：index_daily_auction_20240724.csv（537条记录）
#
# === 正在处理 207/366：20240725 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_13c3f2b5）
# ✅ 保存成功：index_daily_auction_20240725.csv（537条记录）
#
# === 正在处理 208/366：20240726 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d40dd751）
# ✅ 保存成功：index_daily_auction_20240726.csv（537条记录）
#
# === 正在处理 209/366：20240727 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a82c2d09）
# ⚠️ 数据为空，不保存
#
# === 正在处理 210/366：20240728 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6a630045）
# ⚠️ 数据为空，不保存
#
# === 正在处理 211/366：20240729 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_19d1060d）
# ✅ 保存成功：index_daily_auction_20240729.csv（538条记录）
#
# === 正在处理 212/366：20240730 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3a012476）
# ✅ 保存成功：index_daily_auction_20240730.csv（538条记录）
#
# === 正在处理 213/366：20240731 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_dc092cd5）
# ✅ 保存成功：index_daily_auction_20240731.csv（538条记录）
#
# === 正在处理 214/366：20240801 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a0668206）
# ✅ 保存成功：index_daily_auction_20240801.csv（538条记录）
#
# === 正在处理 215/366：20240802 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_7e7c8e7f）
# ✅ 保存成功：index_daily_auction_20240802.csv（538条记录）
#
# === 正在处理 216/366：20240803 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fd15f275）
# ⚠️ 数据为空，不保存
#
# === 正在处理 217/366：20240804 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_df20a5be）
# ⚠️ 数据为空，不保存
#
# === 正在处理 218/366：20240805 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8b5fb172）
# ✅ 保存成功：index_daily_auction_20240805.csv（538条记录）
#
# === 正在处理 219/366：20240806 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8323f0ae）
# ✅ 保存成功：index_daily_auction_20240806.csv（538条记录）
#
# === 正在处理 220/366：20240807 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_62adf301）
# ✅ 保存成功：index_daily_auction_20240807.csv（538条记录）
#
# === 正在处理 221/366：20240808 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_97c3c846）
# ✅ 保存成功：index_daily_auction_20240808.csv（538条记录）
#
# === 正在处理 222/366：20240809 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4770b3ee）
# ✅ 保存成功：index_daily_auction_20240809.csv（538条记录）
#
# === 正在处理 223/366：20240810 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_dcd4d291）
# ⚠️ 数据为空，不保存
#
# === 正在处理 224/366：20240811 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_11e1b068）
# ⚠️ 数据为空，不保存
#
# === 正在处理 225/366：20240812 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_b581bf7f）
# ✅ 保存成功：index_daily_auction_20240812.csv（538条记录）
#
# === 正在处理 226/366：20240813 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0e896ba2）
# ✅ 保存成功：index_daily_auction_20240813.csv（538条记录）
#
# === 正在处理 227/366：20240814 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5cce8881）
# ✅ 保存成功：index_daily_auction_20240814.csv（538条记录）
#
# === 正在处理 228/366：20240815 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2b9f5256）
# ✅ 保存成功：index_daily_auction_20240815.csv（538条记录）
#
# === 正在处理 229/366：20240816 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6d02eff5）
# ✅ 保存成功：index_daily_auction_20240816.csv（538条记录）
#
# === 正在处理 230/366：20240817 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f559ad1b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 231/366：20240818 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ea26324d）
# ⚠️ 数据为空，不保存
#
# === 正在处理 232/366：20240819 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9a50a687）
# ✅ 保存成功：index_daily_auction_20240819.csv（538条记录）
#
# === 正在处理 233/366：20240820 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_07b049fd）
# ✅ 保存成功：index_daily_auction_20240820.csv（539条记录）
#
# === 正在处理 234/366：20240821 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a258ce1a）
# ✅ 保存成功：index_daily_auction_20240821.csv（539条记录）
#
# === 正在处理 235/366：20240822 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3b7a9681）
# ✅ 保存成功：index_daily_auction_20240822.csv（539条记录）
#
# === 正在处理 236/366：20240823 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d17c34ae）
# ✅ 保存成功：index_daily_auction_20240823.csv（539条记录）
#
# === 正在处理 237/366：20240824 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_be3453ec）
# ⚠️ 数据为空，不保存
#
# === 正在处理 238/366：20240825 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6da2fc21）
# ⚠️ 数据为空，不保存
#
# === 正在处理 239/366：20240826 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_1b705b4f）
# ✅ 保存成功：index_daily_auction_20240826.csv（539条记录）
#
# === 正在处理 240/366：20240827 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a47a57d0）
# ✅ 保存成功：index_daily_auction_20240827.csv（539条记录）
#
# === 正在处理 241/366：20240828 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0ed30861）
# ✅ 保存成功：index_daily_auction_20240828.csv（539条记录）
#
# === 正在处理 242/366：20240829 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f06602ff）
# ✅ 保存成功：index_daily_auction_20240829.csv（539条记录）
#
# === 正在处理 243/366：20240830 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_911ae604）
# ✅ 保存成功：index_daily_auction_20240830.csv（539条记录）
#
# === 正在处理 244/366：20240831 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_bb961406）
# ⚠️ 数据为空，不保存
#
# === 正在处理 245/366：20240901 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_af6b000b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 246/366：20240902 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_7d0c9bb6）
# ✅ 保存成功：index_daily_auction_20240902.csv（539条记录）
#
# === 正在处理 247/366：20240903 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_059407e5）
# ✅ 保存成功：index_daily_auction_20240903.csv（539条记录）
#
# === 正在处理 248/366：20240904 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9740cd34）
# ✅ 保存成功：index_daily_auction_20240904.csv（539条记录）
#
# === 正在处理 249/366：20240905 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_406763ed）
# ✅ 保存成功：index_daily_auction_20240905.csv（539条记录）
#
# === 正在处理 250/366：20240906 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f67c6183）
# ✅ 保存成功：index_daily_auction_20240906.csv（539条记录）
#
# === 正在处理 251/366：20240907 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0119f012）
# ⚠️ 数据为空，不保存
#
# === 正在处理 252/366：20240908 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_cd16f790）
# ⚠️ 数据为空，不保存
#
# === 正在处理 253/366：20240909 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4310db8b）
# ✅ 保存成功：index_daily_auction_20240909.csv（539条记录）
#
# === 正在处理 254/366：20240910 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3f91cb9d）
# ✅ 保存成功：index_daily_auction_20240910.csv（539条记录）
#
# === 正在处理 255/366：20240911 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_556a699d）
# ✅ 保存成功：index_daily_auction_20240911.csv（539条记录）
#
# === 正在处理 256/366：20240912 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0c962eac）
# ✅ 保存成功：index_daily_auction_20240912.csv（539条记录）
#
# === 正在处理 257/366：20240913 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5f4809dc）
# ✅ 保存成功：index_daily_auction_20240913.csv（539条记录）
#
# === 正在处理 258/366：20240914 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5eabd46d）
# ⚠️ 数据为空，不保存
#
# === 正在处理 259/366：20240915 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_df0d8674）
# ⚠️ 数据为空，不保存
#
# === 正在处理 260/366：20240916 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8c535e15）
# ⚠️ 数据为空，不保存
#
# === 正在处理 261/366：20240917 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d61c4e41）
# ⚠️ 数据为空，不保存
#
# === 正在处理 262/366：20240918 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5cdb7e6b）
# ✅ 保存成功：index_daily_auction_20240918.csv（539条记录）
#
# === 正在处理 263/366：20240919 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0eb3e433）
# ✅ 保存成功：index_daily_auction_20240919.csv（539条记录）
#
# === 正在处理 264/366：20240920 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f9bc903f）
# ✅ 保存成功：index_daily_auction_20240920.csv（539条记录）
#
# === 正在处理 265/366：20240921 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_82d78e0f）
# ⚠️ 数据为空，不保存
#
# === 正在处理 266/366：20240922 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_39425085）
# ⚠️ 数据为空，不保存
#
# === 正在处理 267/366：20240923 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_be778c92）
# ✅ 保存成功：index_daily_auction_20240923.csv（540条记录）
#
# === 正在处理 268/366：20240924 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_30adb4d7）
# ✅ 保存成功：index_daily_auction_20240924.csv（540条记录）
#
# === 正在处理 269/366：20240925 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d40be0f2）
# ✅ 保存成功：index_daily_auction_20240925.csv（540条记录）
#
# === 正在处理 270/366：20240926 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_57020e05）
# ✅ 保存成功：index_daily_auction_20240926.csv（540条记录）
#
# === 正在处理 271/366：20240927 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_18f394cc）
# ✅ 保存成功：index_daily_auction_20240927.csv（540条记录）
#
# === 正在处理 272/366：20240928 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2d13b5ad）
# ⚠️ 数据为空，不保存
#
# === 正在处理 273/366：20240929 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_225015fe）
# ⚠️ 数据为空，不保存
#
# === 正在处理 274/366：20240930 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_49eb1fdc）
# ✅ 保存成功：index_daily_auction_20240930.csv（540条记录）
#
# === 正在处理 275/366：20241001 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d77add02）
# ⚠️ 数据为空，不保存
#
# === 正在处理 276/366：20241002 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4106421b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 277/366：20241003 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a400586d）
# ⚠️ 数据为空，不保存
#
# === 正在处理 278/366：20241004 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_c875429c）
# ⚠️ 数据为空，不保存
#
# === 正在处理 279/366：20241005 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_577fd6e5）
# ⚠️ 数据为空，不保存
#
# === 正在处理 280/366：20241006 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_cd1948f8）
# ⚠️ 数据为空，不保存
#
# === 正在处理 281/366：20241007 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_bf53678f）
# ⚠️ 数据为空，不保存
#
# === 正在处理 282/366：20241008 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_84c69cc6）
# ✅ 保存成功：index_daily_auction_20241008.csv（540条记录）
#
# === 正在处理 283/366：20241009 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2efc439d）
# ✅ 保存成功：index_daily_auction_20241009.csv（540条记录）
#
# === 正在处理 284/366：20241010 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ea9015fa）
# ✅ 保存成功：index_daily_auction_20241010.csv（540条记录）
#
# === 正在处理 285/366：20241011 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_317a02eb）
# ✅ 保存成功：index_daily_auction_20241011.csv（540条记录）
#
# === 正在处理 286/366：20241012 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_86317195）
# ⚠️ 数据为空，不保存
#
# === 正在处理 287/366：20241013 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d237b28b）
# ⚠️ 数据为空，不保存
#
# === 正在处理 288/366：20241014 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6d91549a）
# ✅ 保存成功：index_daily_auction_20241014.csv（540条记录）
#
# === 正在处理 289/366：20241015 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_0809fc47）
# ✅ 保存成功：index_daily_auction_20241015.csv（540条记录）
#
# === 正在处理 290/366：20241016 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_09ec701a）
# ✅ 保存成功：index_daily_auction_20241016.csv（540条记录）
#
# === 正在处理 291/366：20241017 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e8221db3）
# ✅ 保存成功：index_daily_auction_20241017.csv（540条记录）
#
# === 正在处理 292/366：20241018 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2a51d426）
# ✅ 保存成功：index_daily_auction_20241018.csv（540条记录）
#
# === 正在处理 293/366：20241019 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a58c7431）
# ⚠️ 数据为空，不保存
#
# === 正在处理 294/366：20241020 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9ab18412）
# ⚠️ 数据为空，不保存
#
# === 正在处理 295/366：20241021 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9e4f2931）
# ✅ 保存成功：index_daily_auction_20241021.csv（540条记录）
#
# === 正在处理 296/366：20241022 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_95e5b872）
# ✅ 保存成功：index_daily_auction_20241022.csv（540条记录）
#
# === 正在处理 297/366：20241023 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_c3a115a5）
# ✅ 保存成功：index_daily_auction_20241023.csv（540条记录）
#
# === 正在处理 298/366：20241024 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_1561c53a）
# ✅ 保存成功：index_daily_auction_20241024.csv（540条记录）
#
# === 正在处理 299/366：20241025 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_48896a2a）
# ✅ 保存成功：index_daily_auction_20241025.csv（540条记录）
#
# === 正在处理 300/366：20241026 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_43ab349f）
# ⚠️ 数据为空，不保存
#
# === 正在处理 301/366：20241027 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_b9cb9d2a）
# ⚠️ 数据为空，不保存
#
# === 正在处理 302/366：20241028 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_48b9e90e）
# ✅ 保存成功：index_daily_auction_20241028.csv（540条记录）
#
# === 正在处理 303/366：20241029 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_80480747）
# ✅ 保存成功：index_daily_auction_20241029.csv（540条记录）
#
# === 正在处理 304/366：20241030 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8b51e020）
# ✅ 保存成功：index_daily_auction_20241030.csv（540条记录）
#
# === 正在处理 305/366：20241031 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9cfec65a）
# ✅ 保存成功：index_daily_auction_20241031.csv（540条记录）
#
# === 正在处理 306/366：20241101 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8a3e55e3）
# ✅ 保存成功：index_daily_auction_20241101.csv（540条记录）
#
# === 正在处理 307/366：20241102 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_15a89b12）
# ⚠️ 数据为空，不保存
#
# === 正在处理 308/366：20241103 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_bfad6798）
# ⚠️ 数据为空，不保存
#
# === 正在处理 309/366：20241104 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_e3753717）
# ✅ 保存成功：index_daily_auction_20241104.csv（540条记录）
#
# === 正在处理 310/366：20241105 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a7f1a335）
# ✅ 保存成功：index_daily_auction_20241105.csv（540条记录）
#
# === 正在处理 311/366：20241106 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a184a892）
# ✅ 保存成功：index_daily_auction_20241106.csv（540条记录）
#
# === 正在处理 312/366：20241107 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_7c14665c）
# ✅ 保存成功：index_daily_auction_20241107.csv（540条记录）
#
# === 正在处理 313/366：20241108 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_18d1c381）
# ✅ 保存成功：index_daily_auction_20241108.csv（540条记录）
#
# === 正在处理 314/366：20241109 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_da1e7a2a）
# ⚠️ 数据为空，不保存
#
# === 正在处理 315/366：20241110 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5e702f70）
# ⚠️ 数据为空，不保存
#
# === 正在处理 316/366：20241111 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5f27c8c8）
# ✅ 保存成功：index_daily_auction_20241111.csv（540条记录）
#
# === 正在处理 317/366：20241112 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_7885f9c3）
# ✅ 保存成功：index_daily_auction_20241112.csv（540条记录）
#
# === 正在处理 318/366：20241113 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_cbe7d00a）
# ✅ 保存成功：index_daily_auction_20241113.csv（540条记录）
#
# === 正在处理 319/366：20241114 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_3652d6be）
# ✅ 保存成功：index_daily_auction_20241114.csv（540条记录）
#
# === 正在处理 320/366：20241115 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_becf694c）
# ✅ 保存成功：index_daily_auction_20241115.csv（540条记录）
#
# === 正在处理 321/366：20241116 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fbb57e66）
# ⚠️ 数据为空，不保存
#
# === 正在处理 322/366：20241117 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f1183c11）
# ⚠️ 数据为空，不保存
#
# === 正在处理 323/366：20241118 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fb5f14a0）
# ✅ 保存成功：index_daily_auction_20241118.csv（540条记录）
#
# === 正在处理 324/366：20241119 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_dc1c5243）
# ✅ 保存成功：index_daily_auction_20241119.csv（540条记录）
#
# === 正在处理 325/366：20241120 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5c9bada6）
# ✅ 保存成功：index_daily_auction_20241120.csv（540条记录）
#
# === 正在处理 326/366：20241121 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_9402db9f）
# ✅ 保存成功：index_daily_auction_20241121.csv（540条记录）
#
# === 正在处理 327/366：20241122 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_a977c9a7）
# ✅ 保存成功：index_daily_auction_20241122.csv（540条记录）
#
# === 正在处理 328/366：20241123 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_489d7a8c）
# ⚠️ 数据为空，不保存
#
# === 正在处理 329/366：20241124 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4d721707）
# ⚠️ 数据为空，不保存
#
# === 正在处理 330/366：20241125 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f6a80052）
# ✅ 保存成功：index_daily_auction_20241125.csv（540条记录）
#
# === 正在处理 331/366：20241126 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2e0330b9）
# ✅ 保存成功：index_daily_auction_20241126.csv（540条记录）
#
# === 正在处理 332/366：20241127 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_afe54ed1）
# ✅ 保存成功：index_daily_auction_20241127.csv（540条记录）
#
# === 正在处理 333/366：20241128 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_75c77352）
# ✅ 保存成功：index_daily_auction_20241128.csv（540条记录）
#
# === 正在处理 334/366：20241129 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_24217015）
# ✅ 保存成功：index_daily_auction_20241129.csv（540条记录）
#
# === 正在处理 335/366：20241130 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_843e46e1）
# ⚠️ 数据为空，不保存
#
# === 正在处理 336/366：20241201 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5cc83d07）
# ⚠️ 数据为空，不保存
#
# === 正在处理 337/366：20241202 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6e29e6b0）
# ✅ 保存成功：index_daily_auction_20241202.csv（540条记录）
#
# === 正在处理 338/366：20241203 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_fae36891）
# ✅ 保存成功：index_daily_auction_20241203.csv（540条记录）
#
# === 正在处理 339/366：20241204 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8657e82f）
# ✅ 保存成功：index_daily_auction_20241204.csv（540条记录）
#
# === 正在处理 340/366：20241205 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2fa88815）
# ✅ 保存成功：index_daily_auction_20241205.csv（540条记录）
#
# === 正在处理 341/366：20241206 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_902dd247）
# ✅ 保存成功：index_daily_auction_20241206.csv（540条记录）
#
# === 正在处理 342/366：20241207 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_864743bd）
# ⚠️ 数据为空，不保存
#
# === 正在处理 343/366：20241208 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_5f3c4f5c）
# ⚠️ 数据为空，不保存
#
# === 正在处理 344/366：20241209 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_31ccc90e）
# ✅ 保存成功：index_daily_auction_20241209.csv（540条记录）
#
# === 正在处理 345/366：20241210 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2c7ab20a）
# ✅ 保存成功：index_daily_auction_20241210.csv（540条记录）
#
# === 正在处理 346/366：20241211 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6a997b2a）
# ✅ 保存成功：index_daily_auction_20241211.csv（540条记录）
#
# === 正在处理 347/366：20241212 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_6c83c902）
# ✅ 保存成功：index_daily_auction_20241212.csv（540条记录）
#
# === 正在处理 348/366：20241213 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_d8dae0a6）
# ✅ 保存成功：index_daily_auction_20241213.csv（540条记录）
#
# === 正在处理 349/366：20241214 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_ed2ec7c6）
# ⚠️ 数据为空，不保存
#
# === 正在处理 350/366：20241215 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f16d8684）
# ⚠️ 数据为空，不保存
#
# === 正在处理 351/366：20241216 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_612b7a54）
# ✅ 保存成功：index_daily_auction_20241216.csv（540条记录）
#
# === 正在处理 352/366：20241217 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2946a255）
# ✅ 保存成功：index_daily_auction_20241217.csv（540条记录）
#
# === 正在处理 353/366：20241218 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_61aae029）
# ✅ 保存成功：index_daily_auction_20241218.csv（540条记录）
#
# === 正在处理 354/366：20241219 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_23cd862e）
# ✅ 保存成功：index_daily_auction_20241219.csv（540条记录）
#
# === 正在处理 355/366：20241220 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_18dc0ba3）
# ✅ 保存成功：index_daily_auction_20241220.csv（540条记录）
#
# === 正在处理 356/366：20241221 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_488cc66a）
# ⚠️ 数据为空，不保存
#
# === 正在处理 357/366：20241222 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_2e2ace22）
# ⚠️ 数据为空，不保存
#
# === 正在处理 358/366：20241223 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f653ce35）
# ✅ 保存成功：index_daily_auction_20241223.csv（540条记录）
#
# === 正在处理 359/366：20241224 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_aba24d79）
# ✅ 保存成功：index_daily_auction_20241224.csv（540条记录）
#
# === 正在处理 360/366：20241225 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_f872a9b1）
# ✅ 保存成功：index_daily_auction_20241225.csv（540条记录）
#
# === 正在处理 361/366：20241226 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_51b95c7a）
# ✅ 保存成功：index_daily_auction_20241226.csv（540条记录）
#
# === 正在处理 362/366：20241227 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_4d9dda7e）
# ✅ 保存成功：index_daily_auction_20241227.csv（540条记录）
#
# === 正在处理 363/366：20241228 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_18a003d1）
# ⚠️ 数据为空，不保存
#
# === 正在处理 364/366：20241229 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_dd15c9ec）
# ⚠️ 数据为空，不保存
#
# === 正在处理 365/366：20241230 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_947c4ee2）
# ✅ 保存成功：index_daily_auction_20241230.csv（540条记录）
#
# === 正在处理 366/366：20241231 ===
# 📤 已调用远程函数：fetch_index_auction_data（任务ID：task_8da260bc）
# ✅ 保存成功：index_daily_auction_20241231.csv（540条记录）
#
# === 所有日期处理完成 ===

# %% [markdown]
# ## 将csv合并为一个parquet文件

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将 /d:/workspace/xiaoyao/redis/ 目录下的所有 stock_***.csv 文件合并为一个 parquet 文件
确保与现有 /d:/workspace/xiaoyao/data/stock_daily_price.parquet 保持字段、压缩方式一致
"""

import os
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path
import glob


def merge_stock_csv_to_parquet(csv_dir, output_parquet_file):
    """
    
    Args:
        csv_dir: CSV 文件所在目录
        output_parquet_file: 输出的 parquet 文件路径
    """
    print(f"📁 开始处理目录: {csv_dir}")
    
    # 获取所有 stock_***.csv 文件
    csv_pattern = os.path.join(csv_dir, "index_daily_auction_*.csv")
    csv_files = glob.glob(csv_pattern)
    
    if not csv_files:
        print("❌ 未找到 stock_***.csv 文件")
        return False
    
    print(f"📊 找到 {len(csv_files)} 个 CSV 文件")
    
    # 按文件名排序（确保按日期顺序处理）
    csv_files.sort()
    
    # 读取并合并所有 CSV 文件
    all_dataframes = []
    total_records = 0
    
    for i, csv_file in enumerate(csv_files, 1):
        filename = os.path.basename(csv_file)
        print(f"正在处理 ({i}/{len(csv_files)}): {filename}")
        
        try:
            # 读取 CSV 文件
            df = pd.read_csv(csv_file)
            
            # 数据验证和清洗
            # 确保 date 列是 datetime 类型
            df['date'] = pd.to_datetime(df['date'])
            
            # 确保数值列的数据类型正确
            numeric_columns = ['current','volume','money']
            
            for col in numeric_columns:
                if col in df.columns:
                    df[col] = pd.to_numeric(df[col], errors='coerce')
            
            # 删除无效数据
            df = df.dropna(subset=['date', 'index_code'])
            
            all_dataframes.append(df)
            total_records += len(df)
            print(f"  ✅ 成功读取 {len(df)} 条记录")
            
        except Exception as e:
            print(f"  ❌ 处理失败: {e}")
            continue
    
    if not all_dataframes:
        print("❌ 没有成功读取任何数据")
        return False
    
    print(f"\n📊 合并所有数据...")
    # 合并所有数据框
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    
    # 去重（按 date + stock_code）
    combined_df = combined_df.drop_duplicates(subset=['date', 'index_code'])
    
    # 按日期和股票代码排序
    combined_df = combined_df.sort_values(['date', 'index_code']).reset_index(drop=True)
    
    print(f"📈 总计 {len(combined_df)} 条记录（去重后）")
    
    # 确保输出目录存在
    output_dir = os.path.dirname(output_parquet_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")
    
    # 转换为 pyarrow Table
    table = pa.Table.from_pandas(combined_df)
    
    # 使用与目标文件相同的压缩方式 (snappy) 和格式写入 parquet
    try:
        pq.write_table(
            table, 
            output_parquet_file,
            compression='snappy',
            version='2.6',  # 使用较新的 parquet 版本
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024  # 64MB batch size for better performance
        )
        
        print(f"✅ 成功保存到: {output_parquet_file}")
        print(f"📊 文件大小: {os.path.getsize(output_parquet_file) / (1024*1024):.2f} MB")
        
        return True
        
    except Exception as e:
        print(f"❌ 保存 parquet 文件失败: {e}")
        return False


def main():
    """主函数"""
    # 设置路径
    csv_directory = "d:/workspace/xiaoyao/redis/"
    # 确保输出目录存在
    output_dir = os.path.join(csv_directory, 'parquet')
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 创建输出目录: {output_dir}")

    output_file = os.path.join(output_dir, 'index_daily_auction_to_merged.parquet')
    
    
    print("=" * 60)
    print("🚀 开始合并 index_***.csv 文件到 parquet")
    print("=" * 60)
    
    # 执行合并
    success = merge_stock_csv_to_parquet(csv_directory, output_file)
    
    if success:
        print("\n🎉 合并完成！")
        
        # 验证结果
        try:
            print("\n📋 验证结果:")
            result_df = pd.read_parquet(output_file)
            print(f"   总行数: {len(result_df)}")
            print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
            print(f"   股票数量: {result_df['index_code'].nunique()}")
            print(f"   列名: {list(result_df.columns)}")
            
        except Exception as e:
            print(f"⚠️  验证失败: {e}")
    
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 index_***.csv 文件到 parquet
# ============================================================
# 📁 开始处理目录: d:/workspace/xiaoyao/redis/
# 📊 找到 242 个 CSV 文件
# 正在处理 (1/242): index_daily_auction_20240102.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (2/242): index_daily_auction_20240103.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (3/242): index_daily_auction_20240104.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (4/242): index_daily_auction_20240105.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (5/242): index_daily_auction_20240108.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (6/242): index_daily_auction_20240109.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (7/242): index_daily_auction_20240110.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (8/242): index_daily_auction_20240111.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (9/242): index_daily_auction_20240112.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (10/242): index_daily_auction_20240115.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (11/242): index_daily_auction_20240116.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (12/242): index_daily_auction_20240117.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (13/242): index_daily_auction_20240118.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (14/242): index_daily_auction_20240119.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (15/242): index_daily_auction_20240122.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (16/242): index_daily_auction_20240123.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (17/242): index_daily_auction_20240124.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (18/242): index_daily_auction_20240125.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (19/242): index_daily_auction_20240126.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (20/242): index_daily_auction_20240129.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (21/242): index_daily_auction_20240130.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (22/242): index_daily_auction_20240131.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (23/242): index_daily_auction_20240201.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (24/242): index_daily_auction_20240202.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (25/242): index_daily_auction_20240205.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (26/242): index_daily_auction_20240206.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (27/242): index_daily_auction_20240207.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (28/242): index_daily_auction_20240208.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (29/242): index_daily_auction_20240219.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (30/242): index_daily_auction_20240220.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (31/242): index_daily_auction_20240221.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (32/242): index_daily_auction_20240222.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (33/242): index_daily_auction_20240223.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (34/242): index_daily_auction_20240226.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (35/242): index_daily_auction_20240227.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (36/242): index_daily_auction_20240228.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (37/242): index_daily_auction_20240229.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (38/242): index_daily_auction_20240301.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (39/242): index_daily_auction_20240304.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (40/242): index_daily_auction_20240305.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (41/242): index_daily_auction_20240306.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (42/242): index_daily_auction_20240307.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (43/242): index_daily_auction_20240308.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (44/242): index_daily_auction_20240311.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (45/242): index_daily_auction_20240312.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (46/242): index_daily_auction_20240313.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (47/242): index_daily_auction_20240314.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (48/242): index_daily_auction_20240315.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (49/242): index_daily_auction_20240318.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (50/242): index_daily_auction_20240319.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (51/242): index_daily_auction_20240320.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (52/242): index_daily_auction_20240321.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (53/242): index_daily_auction_20240322.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (54/242): index_daily_auction_20240325.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (55/242): index_daily_auction_20240326.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (56/242): index_daily_auction_20240327.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (57/242): index_daily_auction_20240328.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (58/242): index_daily_auction_20240329.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (59/242): index_daily_auction_20240401.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (60/242): index_daily_auction_20240402.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (61/242): index_daily_auction_20240403.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (62/242): index_daily_auction_20240408.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (63/242): index_daily_auction_20240409.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (64/242): index_daily_auction_20240410.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (65/242): index_daily_auction_20240411.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (66/242): index_daily_auction_20240412.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (67/242): index_daily_auction_20240415.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (68/242): index_daily_auction_20240416.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (69/242): index_daily_auction_20240417.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (70/242): index_daily_auction_20240418.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (71/242): index_daily_auction_20240419.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (72/242): index_daily_auction_20240422.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (73/242): index_daily_auction_20240423.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (74/242): index_daily_auction_20240424.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (75/242): index_daily_auction_20240425.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (76/242): index_daily_auction_20240426.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (77/242): index_daily_auction_20240429.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (78/242): index_daily_auction_20240430.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (79/242): index_daily_auction_20240506.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (80/242): index_daily_auction_20240507.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (81/242): index_daily_auction_20240508.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (82/242): index_daily_auction_20240509.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (83/242): index_daily_auction_20240510.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (84/242): index_daily_auction_20240513.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (85/242): index_daily_auction_20240514.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (86/242): index_daily_auction_20240515.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (87/242): index_daily_auction_20240516.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (88/242): index_daily_auction_20240517.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (89/242): index_daily_auction_20240520.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (90/242): index_daily_auction_20240521.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (91/242): index_daily_auction_20240522.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (92/242): index_daily_auction_20240523.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (93/242): index_daily_auction_20240524.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (94/242): index_daily_auction_20240527.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (95/242): index_daily_auction_20240528.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (96/242): index_daily_auction_20240529.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (97/242): index_daily_auction_20240530.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (98/242): index_daily_auction_20240531.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (99/242): index_daily_auction_20240603.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (100/242): index_daily_auction_20240604.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (101/242): index_daily_auction_20240605.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (102/242): index_daily_auction_20240606.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (103/242): index_daily_auction_20240607.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (104/242): index_daily_auction_20240611.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (105/242): index_daily_auction_20240612.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (106/242): index_daily_auction_20240613.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (107/242): index_daily_auction_20240614.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (108/242): index_daily_auction_20240617.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (109/242): index_daily_auction_20240618.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (110/242): index_daily_auction_20240619.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (111/242): index_daily_auction_20240620.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (112/242): index_daily_auction_20240621.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (113/242): index_daily_auction_20240624.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (114/242): index_daily_auction_20240625.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (115/242): index_daily_auction_20240626.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (116/242): index_daily_auction_20240627.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (117/242): index_daily_auction_20240628.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (118/242): index_daily_auction_20240701.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (119/242): index_daily_auction_20240702.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (120/242): index_daily_auction_20240703.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (121/242): index_daily_auction_20240704.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (122/242): index_daily_auction_20240705.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (123/242): index_daily_auction_20240708.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (124/242): index_daily_auction_20240709.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (125/242): index_daily_auction_20240710.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (126/242): index_daily_auction_20240711.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (127/242): index_daily_auction_20240712.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (128/242): index_daily_auction_20240715.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (129/242): index_daily_auction_20240716.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (130/242): index_daily_auction_20240717.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (131/242): index_daily_auction_20240718.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (132/242): index_daily_auction_20240719.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (133/242): index_daily_auction_20240722.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (134/242): index_daily_auction_20240723.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (135/242): index_daily_auction_20240724.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (136/242): index_daily_auction_20240725.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (137/242): index_daily_auction_20240726.csv
#   ✅ 成功读取 537 条记录
# 正在处理 (138/242): index_daily_auction_20240729.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (139/242): index_daily_auction_20240730.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (140/242): index_daily_auction_20240731.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (141/242): index_daily_auction_20240801.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (142/242): index_daily_auction_20240802.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (143/242): index_daily_auction_20240805.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (144/242): index_daily_auction_20240806.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (145/242): index_daily_auction_20240807.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (146/242): index_daily_auction_20240808.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (147/242): index_daily_auction_20240809.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (148/242): index_daily_auction_20240812.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (149/242): index_daily_auction_20240813.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (150/242): index_daily_auction_20240814.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (151/242): index_daily_auction_20240815.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (152/242): index_daily_auction_20240816.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (153/242): index_daily_auction_20240819.csv
#   ✅ 成功读取 538 条记录
# 正在处理 (154/242): index_daily_auction_20240820.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (155/242): index_daily_auction_20240821.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (156/242): index_daily_auction_20240822.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (157/242): index_daily_auction_20240823.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (158/242): index_daily_auction_20240826.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (159/242): index_daily_auction_20240827.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (160/242): index_daily_auction_20240828.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (161/242): index_daily_auction_20240829.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (162/242): index_daily_auction_20240830.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (163/242): index_daily_auction_20240902.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (164/242): index_daily_auction_20240903.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (165/242): index_daily_auction_20240904.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (166/242): index_daily_auction_20240905.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (167/242): index_daily_auction_20240906.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (168/242): index_daily_auction_20240909.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (169/242): index_daily_auction_20240910.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (170/242): index_daily_auction_20240911.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (171/242): index_daily_auction_20240912.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (172/242): index_daily_auction_20240913.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (173/242): index_daily_auction_20240918.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (174/242): index_daily_auction_20240919.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (175/242): index_daily_auction_20240920.csv
#   ✅ 成功读取 539 条记录
# 正在处理 (176/242): index_daily_auction_20240923.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (177/242): index_daily_auction_20240924.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (178/242): index_daily_auction_20240925.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (179/242): index_daily_auction_20240926.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (180/242): index_daily_auction_20240927.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (181/242): index_daily_auction_20240930.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (182/242): index_daily_auction_20241008.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (183/242): index_daily_auction_20241009.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (184/242): index_daily_auction_20241010.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (185/242): index_daily_auction_20241011.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (186/242): index_daily_auction_20241014.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (187/242): index_daily_auction_20241015.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (188/242): index_daily_auction_20241016.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (189/242): index_daily_auction_20241017.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (190/242): index_daily_auction_20241018.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (191/242): index_daily_auction_20241021.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (192/242): index_daily_auction_20241022.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (193/242): index_daily_auction_20241023.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (194/242): index_daily_auction_20241024.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (195/242): index_daily_auction_20241025.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (196/242): index_daily_auction_20241028.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (197/242): index_daily_auction_20241029.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (198/242): index_daily_auction_20241030.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (199/242): index_daily_auction_20241031.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (200/242): index_daily_auction_20241101.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (201/242): index_daily_auction_20241104.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (202/242): index_daily_auction_20241105.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (203/242): index_daily_auction_20241106.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (204/242): index_daily_auction_20241107.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (205/242): index_daily_auction_20241108.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (206/242): index_daily_auction_20241111.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (207/242): index_daily_auction_20241112.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (208/242): index_daily_auction_20241113.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (209/242): index_daily_auction_20241114.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (210/242): index_daily_auction_20241115.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (211/242): index_daily_auction_20241118.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (212/242): index_daily_auction_20241119.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (213/242): index_daily_auction_20241120.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (214/242): index_daily_auction_20241121.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (215/242): index_daily_auction_20241122.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (216/242): index_daily_auction_20241125.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (217/242): index_daily_auction_20241126.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (218/242): index_daily_auction_20241127.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (219/242): index_daily_auction_20241128.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (220/242): index_daily_auction_20241129.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (221/242): index_daily_auction_20241202.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (222/242): index_daily_auction_20241203.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (223/242): index_daily_auction_20241204.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (224/242): index_daily_auction_20241205.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (225/242): index_daily_auction_20241206.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (226/242): index_daily_auction_20241209.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (227/242): index_daily_auction_20241210.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (228/242): index_daily_auction_20241211.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (229/242): index_daily_auction_20241212.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (230/242): index_daily_auction_20241213.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (231/242): index_daily_auction_20241216.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (232/242): index_daily_auction_20241217.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (233/242): index_daily_auction_20241218.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (234/242): index_daily_auction_20241219.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (235/242): index_daily_auction_20241220.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (236/242): index_daily_auction_20241223.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (237/242): index_daily_auction_20241224.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (238/242): index_daily_auction_20241225.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (239/242): index_daily_auction_20241226.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (240/242): index_daily_auction_20241227.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (241/242): index_daily_auction_20241230.csv
#   ✅ 成功读取 540 条记录
# 正在处理 (242/242): index_daily_auction_20241231.csv
#   ✅ 成功读取 540 条记录
#
# 📊 合并所有数据...
# 📈 总计 130380 条记录（去重后）
# ✅ 成功保存到: d:/workspace/xiaoyao/redis/parquet\index_daily_auction_to_merged.parquet
# 📊 文件大小: 2.88 MB
#
# 🎉 合并完成！
#
# 📋 验证结果:
#    总行数: 130380
#    日期范围: 2024-01-02 09:25:00 到 2024-12-31 09:25:39
#    股票数量: 543
#    列名: ['index_code', 'date', 'current', 'volume', 'money']
# ============================================================

# %% [markdown]
# ## 将新生成的 index_daily_auction_to_merged.parquet 与现有的 index_daily_auction.parquet 合并

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
将新生成的 index_daily_auction_to_merged.parquet 与现有的 index_daily_auction.parquet 合并
"""

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import os


def merge_parquet_files(existing_file, new_file, output_file):
    """
    合并两个 parquet 文件
    
    Args:
        existing_file: 现有的 parquet 文件路径
        new_file: 新的 parquet 文件路径  
        output_file: 输出的合并文件路径
    """
    print("📊 开始合并 parquet 文件...")
    
    try:
        # 读取现有数据
        print(f"📖 读取现有文件: {existing_file}")
        existing_df = pd.read_parquet(existing_file)
        print(f"   现有数据行数: {len(existing_df)}")
        
        # 读取新数据
        print(f"📖 读取新文件: {new_file}")
        new_df = pd.read_parquet(new_file)
        print(f"   新数据行数: {len(new_df)}")
        
        # 合并数据
        print("🔄 合并数据中...")
        combined_df = pd.concat([existing_df, new_df], ignore_index=True)
        
        # 去重（按 date + index_code）
        print("🧹 去重处理...")
        combined_df = combined_df.drop_duplicates(subset=['date', 'index_code'])
        
        # 排序
        print("📅 按日期排序...")
        combined_df = combined_df.sort_values(['date', 'index_code']).reset_index(drop=True)
        
        print(f"📈 合并后总行数: {len(combined_df)}")
        
        # 确保输出目录存在
        output_dir = os.path.dirname(output_file)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)
        
        # 转换为 pyarrow Table
        table = pa.Table.from_pandas(combined_df)
        
        # 写入 parquet（使用与源文件相同的格式）
        print(f"💾 保存合并结果: {output_file}")
        pq.write_table(
            table,
            output_file,
            compression='snappy',
            version='2.6',
            use_dictionary=True,
            write_batch_size=64 * 1024 * 1024
        )
        
        print(f"✅ 合并完成！文件大小: {os.path.getsize(output_file) / (1024*1024):.2f} MB")
        
        # 验证结果
        print("\n📋 验证结果:")
        result_df = pd.read_parquet(output_file)
        print(f"   最终行数: {len(result_df)}")
        print(f"   日期范围: {result_df['date'].min()} 到 {result_df['date'].max()}")
        print(f"   股票数量: {result_df['index_code'].nunique()}")
        
        return True
        
    except Exception as e:
        print(f"❌ 合并失败: {e}")
        return False


def main():
    """主函数"""
    # 设置文件路径

    existing_file = "d:/workspace/xiaoyao/data/index_daily_auction.parquet"
    new_file = "d:/workspace/xiaoyao/redis/parquet/index_daily_auction_to_merged.parquet"
    output_file = "d:/workspace/xiaoyao/redis/parquet/index_daily_auction.parquet"

    print("=" * 60)
    print("🚀 开始合并 parquet 文件")
    print("=" * 60)
    
    # 检查文件是否存在
    if not os.path.exists(existing_file):
        print(f"❌ 现有文件不存在: {existing_file}")
        return
    
    if not os.path.exists(new_file):
        print(f"❌ 新文件不存在: {new_file}")
        return
    
    # 执行合并
    success = merge_parquet_files(existing_file, new_file, output_file)
    
    if success:
        print("\n🎉 合并成功！")
    else:
        print("\n❌ 合并失败！")
    
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🚀 开始合并 parquet 文件
# ============================================================
# 📊 开始合并 parquet 文件...
# 📖 读取现有文件: d:/workspace/xiaoyao/data/index_daily_auction.parquet
#    现有数据行数: 96982
# 📖 读取新文件: d:/workspace/xiaoyao/redis/parquet/index_daily_auction_to_merged.parquet
#    新数据行数: 130380
# 🔄 合并数据中...
# 🧹 去重处理...
# 📅 按日期排序...
# 📈 合并后总行数: 227362
# 💾 保存合并结果: d:/workspace/xiaoyao/redis/parquet/index_daily_auction.parquet
# ✅ 合并完成！文件大小: 5.22 MB
#
# 📋 验证结果:
#    最终行数: 227362
#    日期范围: 2024-01-02 09:25:00 到 2025-09-24 09:25:36
#    股票数量: 546
#
# 🎉 合并成功！
# ============================================================

# %% [markdown]
# ## 删除已使用的csv

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
删除指定目录下的 stock_***.csv 文件
"""

import os
import glob
from pathlib import Path


def delete_stock_csv_files(target_directory, pattern="stock_*.csv"):
    #删除满足模式的所有文件
    files = glob.glob(os.path.join(target_directory, pattern))
    for file in files:
        try:
            os.remove(file)
            print(f"已删除：{file}")
        except Exception as e:
            print(f"删除 {file} 失败：{e}")

if __name__ == "__main__":
    delete_stock_csv_files(r'D:\workspace\xiaoyao\redis','index_daily_auction_*.csv')
    print("\n" + "=" * 60)
# Out:
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240102.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240103.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240104.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240105.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240108.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240109.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240110.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240111.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240112.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240115.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240116.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240117.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240118.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240119.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240122.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240123.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240124.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240125.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240126.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240129.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240130.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240131.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240201.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240202.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240205.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240206.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240207.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240208.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240219.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240220.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240221.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240222.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240223.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240226.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240227.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240228.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240229.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240301.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240304.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240305.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240306.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240307.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240308.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240311.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240312.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240313.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240314.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240315.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240318.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240319.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240320.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240321.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240322.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240325.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240326.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240327.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240328.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240329.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240401.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240402.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240403.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240408.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240409.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240410.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240411.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240412.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240415.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240416.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240417.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240418.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240419.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240422.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240423.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240424.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240425.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240426.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240429.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240430.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240506.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240507.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240508.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240509.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240510.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240513.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240514.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240515.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240516.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240517.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240520.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240521.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240522.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240523.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240524.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240527.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240528.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240529.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240530.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240531.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240603.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240604.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240605.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240606.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240607.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240611.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240612.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240613.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240614.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240617.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240618.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240619.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240620.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240621.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240624.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240625.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240626.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240627.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240628.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240701.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240702.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240703.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240704.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240705.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240708.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240709.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240710.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240711.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240712.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240715.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240716.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240717.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240718.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240719.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240722.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240723.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240724.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240725.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240726.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240729.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240730.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240731.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240801.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240802.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240805.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240806.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240807.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240808.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240809.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240812.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240813.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240814.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240815.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240816.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240819.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240820.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240821.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240822.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240823.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240826.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240827.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240828.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240829.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240830.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240902.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240903.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240904.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240905.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240906.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240909.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240910.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240911.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240912.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240913.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240918.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240919.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240920.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240923.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240924.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240925.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240926.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240927.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20240930.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241008.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241009.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241010.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241011.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241014.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241015.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241016.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241017.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241018.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241021.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241022.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241023.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241024.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241025.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241028.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241029.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241030.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241031.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241101.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241104.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241105.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241106.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241107.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241108.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241111.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241112.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241113.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241114.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241115.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241118.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241119.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241120.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241121.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241122.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241125.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241126.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241127.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241128.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241129.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241202.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241203.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241204.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241205.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241206.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241209.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241210.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241211.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241212.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241213.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241216.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241217.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241218.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241219.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241220.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241223.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241224.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241225.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241226.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241227.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241230.csv
# 已删除：D:\workspace\xiaoyao\redis\index_daily_auction_20241231.csv
#
# ============================================================

# %% [markdown]
# ## 将新的parquet文件移动到data目录覆盖原文件

# %%
# 将子目录下的某个parquet文件移动到指定目录
import os
import shutil

# 定义源目录和目标目录
source_dir = "D:\\workspace\\xiaoyao\\redis\\parquet"
target_dir = "D:\\workspace\\xiaoyao\\data"

# 确保目标目录存在
os.makedirs(target_dir, exist_ok=True)

# 定义要移动的文件
file_to_move = "index_daily_auction.parquet"

# 构建源文件的完整路径
source_file_path = os.path.join(source_dir, file_to_move)

# 构建目标文件的完整路径
target_file_path = os.path.join(target_dir, file_to_move)

# 检查源文件是否存在
if os.path.exists(source_file_path):
    # 移动文件
    shutil.move(source_file_path, target_file_path)
    print(f"Moved: {file_to_move} to {target_dir}")
else:
    print(f"File not found: {file_to_move}")

# 删除指定的parquet文件
file_to_delete = os.path.join(source_dir, file_to_move)
if os.path.exists(file_to_delete):
    os.remove(file_to_delete)
    print(f"Deleted: {file_to_move} from {source_dir}")
else:
    print(f"File not found: {file_to_move} in {source_dir}")
# Out:
# Moved: index_daily_auction.parquet to D:\workspace\xiaoyao\data
# File not found: index_daily_auction.parquet in D:\workspace\xiaoyao\redis\parquet
